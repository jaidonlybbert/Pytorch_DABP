# %% [markdown]
# <a href="https://colab.research.google.com/github/jaidonlybbert/EEP596/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem 1: Image Classification on Imbalanced Dataset

# %% [markdown]
# ## Q1: Prepare CIFAR-50 Dataset
#
# Download dataset to your Google Drive from https://drive.google.com/drive/folders/1WGUKBP5Eta9DAltK1WtvRbX43iwP08DU?usp=sharing
#
# Unzip the files.

# %%
# todo: you can change to your download location
from google.colab import drive
drive.mount('/content/gdrive')
# !mkdir ./data
# !mkdir ./data/cifar50
# !unzip /content/gdrive/MyDrive/EEP596/cifar50.zip -d ./data/cifar50
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/cifar50/images/sunflower/train_23323.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23431.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23457.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23464.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23507.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23533.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23624.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23707.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23713.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23801.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23814.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23830.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23874.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23902.jpg
#   inflating: ./data/cifar50/images/sunflower/train_23959.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24002.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24016.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24035.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24139.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24149.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24172.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24310.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24360.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24434.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2450.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24695.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24818.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24860.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24922.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24925.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24935.jpg
#   inflating: ./data/cifar50/images/sunflower/train_24958.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2550.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2644.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2653.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2662.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2707.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2749.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2751.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2817.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2819.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2856.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2857.jpg
#   inflating: ./data/cifar50/images/sunflower/train_2975.jpg
#   inflating: ./data/cifar50/images/sunflower/train_303.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3041.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3084.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3099.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3112.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3127.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3147.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3151.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3301.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3304.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3390.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3497.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3526.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3683.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3720.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3732.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3748.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3803.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3841.jpg
#   inflating: ./data/cifar50/images/sunflower/train_3849.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4005.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4049.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4056.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4062.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4073.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4119.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4138.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4163.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4165.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4179.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4194.jpg
#   inflating: ./data/cifar50/images/sunflower/train_423.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4292.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4311.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4320.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4325.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4326.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4402.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4600.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4805.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4816.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4859.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4889.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4910.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4967.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4976.jpg
#   inflating: ./data/cifar50/images/sunflower/train_4985.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5.jpg
#   inflating: ./data/cifar50/images/sunflower/train_511.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5180.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5194.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5232.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5297.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5307.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5408.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5423.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5440.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5509.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5513.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5520.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5610.jpg
#   inflating: ./data/cifar50/images/sunflower/train_567.jpg
#   inflating: ./data/cifar50/images/sunflower/train_570.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5705.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5762.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5776.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5784.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5795.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5812.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5832.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5861.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5917.jpg
#   inflating: ./data/cifar50/images/sunflower/train_5975.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6017.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6142.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6164.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6181.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6248.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6261.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6316.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6326.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6452.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6474.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6479.jpg
#   inflating: ./data/cifar50/images/sunflower/train_651.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6514.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6525.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6641.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6687.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6692.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6760.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6797.jpg
#   inflating: ./data/cifar50/images/sunflower/train_699.jpg
#   inflating: ./data/cifar50/images/sunflower/train_6990.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7031.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7039.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7080.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7094.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7101.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7218.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7289.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7299.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7403.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7419.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7504.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7563.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7579.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7657.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7665.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7687.jpg
#   inflating: ./data/cifar50/images/sunflower/train_77.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7711.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7909.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7951.jpg
#   inflating: ./data/cifar50/images/sunflower/train_7973.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8104.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8152.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8184.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8211.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8224.jpg
#   inflating: ./data/cifar50/images/sunflower/train_825.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8309.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8376.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8381.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8407.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8410.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8431.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8435.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8598.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8696.jpg
#   inflating: ./data/cifar50/images/sunflower/train_8717.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9070.jpg
#   inflating: ./data/cifar50/images/sunflower/train_920.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9277.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9287.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9288.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9313.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9417.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9418.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9428.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9488.jpg
#   inflating: ./data/cifar50/images/sunflower/train_957.jpg
#   inflating: ./data/cifar50/images/sunflower/train_959.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9743.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9773.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9846.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9855.jpg
#   inflating: ./data/cifar50/images/sunflower/train_9857.jpg
#    creating: ./data/cifar50/images/table/
#   inflating: ./data/cifar50/images/table/test_1018.jpg
#   inflating: ./data/cifar50/images/table/test_1086.jpg
#   inflating: ./data/cifar50/images/table/test_1091.jpg
#   inflating: ./data/cifar50/images/table/test_1104.jpg
#   inflating: ./data/cifar50/images/table/test_1116.jpg
#   inflating: ./data/cifar50/images/table/test_1142.jpg
#   inflating: ./data/cifar50/images/table/test_1217.jpg
#   inflating: ./data/cifar50/images/table/test_1309.jpg
#   inflating: ./data/cifar50/images/table/test_136.jpg
#   inflating: ./data/cifar50/images/table/test_1390.jpg
#   inflating: ./data/cifar50/images/table/test_1397.jpg
#   inflating: ./data/cifar50/images/table/test_1416.jpg
#   inflating: ./data/cifar50/images/table/test_1438.jpg
#   inflating: ./data/cifar50/images/table/test_1493.jpg
#   inflating: ./data/cifar50/images/table/test_1515.jpg
#   inflating: ./data/cifar50/images/table/test_1582.jpg
#   inflating: ./data/cifar50/images/table/test_1640.jpg
#   inflating: ./data/cifar50/images/table/test_1659.jpg
#   inflating: ./data/cifar50/images/table/test_1695.jpg
#   inflating: ./data/cifar50/images/table/test_1706.jpg
#   inflating: ./data/cifar50/images/table/test_1750.jpg
#   inflating: ./data/cifar50/images/table/test_1755.jpg
#   inflating: ./data/cifar50/images/table/test_1788.jpg
#   inflating: ./data/cifar50/images/table/test_1821.jpg
#   inflating: ./data/cifar50/images/table/test_1916.jpg
#   inflating: ./data/cifar50/images/table/test_1917.jpg
#   inflating: ./data/cifar50/images/table/test_1930.jpg
#   inflating: ./data/cifar50/images/table/test_1989.jpg
#   inflating: ./data/cifar50/images/table/test_2089.jpg
#   inflating: ./data/cifar50/images/table/test_2116.jpg
#   inflating: ./data/cifar50/images/table/test_2145.jpg
#   inflating: ./data/cifar50/images/table/test_2268.jpg
#   inflating: ./data/cifar50/images/table/test_2352.jpg
#   inflating: ./data/cifar50/images/table/test_2381.jpg
#   inflating: ./data/cifar50/images/table/test_2486.jpg
#   inflating: ./data/cifar50/images/table/test_2704.jpg
#   inflating: ./data/cifar50/images/table/test_2743.jpg
#   inflating: ./data/cifar50/images/table/test_2787.jpg
#   inflating: ./data/cifar50/images/table/test_2953.jpg
#   inflating: ./data/cifar50/images/table/test_2968.jpg
#   inflating: ./data/cifar50/images/table/test_2986.jpg
#   inflating: ./data/cifar50/images/table/test_300.jpg
#   inflating: ./data/cifar50/images/table/test_3060.jpg
#   inflating: ./data/cifar50/images/table/test_321.jpg
#   inflating: ./data/cifar50/images/table/test_3265.jpg
#   inflating: ./data/cifar50/images/table/test_3295.jpg
#   inflating: ./data/cifar50/images/table/test_3315.jpg
#   inflating: ./data/cifar50/images/table/test_3362.jpg
#   inflating: ./data/cifar50/images/table/test_3439.jpg
#   inflating: ./data/cifar50/images/table/test_3455.jpg
#   inflating: ./data/cifar50/images/table/test_3471.jpg
#   inflating: ./data/cifar50/images/table/test_3496.jpg
#   inflating: ./data/cifar50/images/table/test_3500.jpg
#   inflating: ./data/cifar50/images/table/test_3514.jpg
#   inflating: ./data/cifar50/images/table/test_3529.jpg
#   inflating: ./data/cifar50/images/table/test_3557.jpg
#   inflating: ./data/cifar50/images/table/test_3558.jpg
#   inflating: ./data/cifar50/images/table/test_3562.jpg
#   inflating: ./data/cifar50/images/table/test_3594.jpg
#   inflating: ./data/cifar50/images/table/test_3845.jpg
#   inflating: ./data/cifar50/images/table/test_3870.jpg
#   inflating: ./data/cifar50/images/table/test_3912.jpg
#   inflating: ./data/cifar50/images/table/test_3971.jpg
#   inflating: ./data/cifar50/images/table/test_3991.jpg
#   inflating: ./data/cifar50/images/table/test_4004.jpg
#   inflating: ./data/cifar50/images/table/test_4068.jpg
#   inflating: ./data/cifar50/images/table/test_4082.jpg
#   inflating: ./data/cifar50/images/table/test_4089.jpg
#   inflating: ./data/cifar50/images/table/test_4102.jpg
#   inflating: ./data/cifar50/images/table/test_4156.jpg
#   inflating: ./data/cifar50/images/table/test_4160.jpg
#   inflating: ./data/cifar50/images/table/test_4169.jpg
#   inflating: ./data/cifar50/images/table/test_422.jpg
#   inflating: ./data/cifar50/images/table/test_4298.jpg
#   inflating: ./data/cifar50/images/table/test_4353.jpg
#   inflating: ./data/cifar50/images/table/test_4357.jpg
#   inflating: ./data/cifar50/images/table/test_4385.jpg
#   inflating: ./data/cifar50/images/table/test_4473.jpg
#   inflating: ./data/cifar50/images/table/test_448.jpg
#   inflating: ./data/cifar50/images/table/test_4531.jpg
#   inflating: ./data/cifar50/images/table/test_4579.jpg
#   inflating: ./data/cifar50/images/table/test_4601.jpg
#   inflating: ./data/cifar50/images/table/test_4634.jpg
#   inflating: ./data/cifar50/images/table/test_4662.jpg
#   inflating: ./data/cifar50/images/table/test_4686.jpg
#   inflating: ./data/cifar50/images/table/test_4688.jpg
#   inflating: ./data/cifar50/images/table/test_4920.jpg
#   inflating: ./data/cifar50/images/table/test_4957.jpg
#   inflating: ./data/cifar50/images/table/test_504.jpg
#   inflating: ./data/cifar50/images/table/test_530.jpg
#   inflating: ./data/cifar50/images/table/test_553.jpg
#   inflating: ./data/cifar50/images/table/test_580.jpg
#   inflating: ./data/cifar50/images/table/test_619.jpg
#   inflating: ./data/cifar50/images/table/test_634.jpg
#   inflating: ./data/cifar50/images/table/test_726.jpg
#   inflating: ./data/cifar50/images/table/test_765.jpg
#   inflating: ./data/cifar50/images/table/test_786.jpg
#   inflating: ./data/cifar50/images/table/test_789.jpg
#   inflating: ./data/cifar50/images/table/test_811.jpg
#   inflating: ./data/cifar50/images/table/test_966.jpg
#   inflating: ./data/cifar50/images/table/train_10.jpg
#   inflating: ./data/cifar50/images/table/train_10003.jpg
#   inflating: ./data/cifar50/images/table/train_10025.jpg
#   inflating: ./data/cifar50/images/table/train_1004.jpg
#   inflating: ./data/cifar50/images/table/train_10130.jpg
#   inflating: ./data/cifar50/images/table/train_1016.jpg
#   inflating: ./data/cifar50/images/table/train_10273.jpg
#   inflating: ./data/cifar50/images/table/train_10308.jpg
#   inflating: ./data/cifar50/images/table/train_10344.jpg
#   inflating: ./data/cifar50/images/table/train_10369.jpg
#   inflating: ./data/cifar50/images/table/train_10380.jpg
#   inflating: ./data/cifar50/images/table/train_10467.jpg
#   inflating: ./data/cifar50/images/table/train_10485.jpg
#   inflating: ./data/cifar50/images/table/train_10536.jpg
#   inflating: ./data/cifar50/images/table/train_10547.jpg
#   inflating: ./data/cifar50/images/table/train_10591.jpg
#   inflating: ./data/cifar50/images/table/train_10662.jpg
#   inflating: ./data/cifar50/images/table/train_10664.jpg
#   inflating: ./data/cifar50/images/table/train_10690.jpg
#   inflating: ./data/cifar50/images/table/train_10754.jpg
#   inflating: ./data/cifar50/images/table/train_10825.jpg
#   inflating: ./data/cifar50/images/table/train_10850.jpg
#   inflating: ./data/cifar50/images/table/train_1087.jpg
#   inflating: ./data/cifar50/images/table/train_10873.jpg
#   inflating: ./data/cifar50/images/table/train_10885.jpg
#   inflating: ./data/cifar50/images/table/train_1090.jpg
#   inflating: ./data/cifar50/images/table/train_10990.jpg
#   inflating: ./data/cifar50/images/table/train_11021.jpg
#   inflating: ./data/cifar50/images/table/train_11171.jpg
#   inflating: ./data/cifar50/images/table/train_11182.jpg
#   inflating: ./data/cifar50/images/table/train_1119.jpg
#   inflating: ./data/cifar50/images/table/train_11221.jpg
#   inflating: ./data/cifar50/images/table/train_11261.jpg
#   inflating: ./data/cifar50/images/table/train_11306.jpg
#   inflating: ./data/cifar50/images/table/train_11425.jpg
#   inflating: ./data/cifar50/images/table/train_11506.jpg
#   inflating: ./data/cifar50/images/table/train_11597.jpg
#   inflating: ./data/cifar50/images/table/train_11612.jpg
#   inflating: ./data/cifar50/images/table/train_11648.jpg
#   inflating: ./data/cifar50/images/table/train_11654.jpg
#   inflating: ./data/cifar50/images/table/train_1167.jpg
#   inflating: ./data/cifar50/images/table/train_11776.jpg
#   inflating: ./data/cifar50/images/table/train_11909.jpg
#   inflating: ./data/cifar50/images/table/train_11938.jpg
#   inflating: ./data/cifar50/images/table/train_11988.jpg
#   inflating: ./data/cifar50/images/table/train_12308.jpg
#   inflating: ./data/cifar50/images/table/train_12330.jpg
#   inflating: ./data/cifar50/images/table/train_12332.jpg
#   inflating: ./data/cifar50/images/table/train_12380.jpg
#   inflating: ./data/cifar50/images/table/train_12489.jpg
#   inflating: ./data/cifar50/images/table/train_12499.jpg
#   inflating: ./data/cifar50/images/table/train_12606.jpg
#   inflating: ./data/cifar50/images/table/train_12641.jpg
#   inflating: ./data/cifar50/images/table/train_12646.jpg
#   inflating: ./data/cifar50/images/table/train_12782.jpg
#   inflating: ./data/cifar50/images/table/train_12831.jpg
#   inflating: ./data/cifar50/images/table/train_12847.jpg
#   inflating: ./data/cifar50/images/table/train_12881.jpg
#   inflating: ./data/cifar50/images/table/train_12926.jpg
#   inflating: ./data/cifar50/images/table/train_12938.jpg
#   inflating: ./data/cifar50/images/table/train_1306.jpg
#   inflating: ./data/cifar50/images/table/train_13083.jpg
#   inflating: ./data/cifar50/images/table/train_13398.jpg
#   inflating: ./data/cifar50/images/table/train_13474.jpg
#   inflating: ./data/cifar50/images/table/train_13479.jpg
#   inflating: ./data/cifar50/images/table/train_13510.jpg
#   inflating: ./data/cifar50/images/table/train_13515.jpg
#   inflating: ./data/cifar50/images/table/train_13603.jpg
#   inflating: ./data/cifar50/images/table/train_13640.jpg
#   inflating: ./data/cifar50/images/table/train_13730.jpg
#   inflating: ./data/cifar50/images/table/train_13754.jpg
#   inflating: ./data/cifar50/images/table/train_13825.jpg
#   inflating: ./data/cifar50/images/table/train_13835.jpg
#   inflating: ./data/cifar50/images/table/train_1385.jpg
#   inflating: ./data/cifar50/images/table/train_13866.jpg
#   inflating: ./data/cifar50/images/table/train_139.jpg
#   inflating: ./data/cifar50/images/table/train_13912.jpg
#   inflating: ./data/cifar50/images/table/train_13915.jpg
#   inflating: ./data/cifar50/images/table/train_13937.jpg
#   inflating: ./data/cifar50/images/table/train_14013.jpg
#   inflating: ./data/cifar50/images/table/train_14079.jpg
#   inflating: ./data/cifar50/images/table/train_14088.jpg
#   inflating: ./data/cifar50/images/table/train_14098.jpg
#   inflating: ./data/cifar50/images/table/train_1411.jpg
#   inflating: ./data/cifar50/images/table/train_14189.jpg
#   inflating: ./data/cifar50/images/table/train_1422.jpg
#   inflating: ./data/cifar50/images/table/train_14260.jpg
#   inflating: ./data/cifar50/images/table/train_14266.jpg
#   inflating: ./data/cifar50/images/table/train_14312.jpg
#   inflating: ./data/cifar50/images/table/train_14317.jpg
#   inflating: ./data/cifar50/images/table/train_14358.jpg
#   inflating: ./data/cifar50/images/table/train_1436.jpg
#   inflating: ./data/cifar50/images/table/train_14393.jpg
#   inflating: ./data/cifar50/images/table/train_14489.jpg
#   inflating: ./data/cifar50/images/table/train_14512.jpg
#   inflating: ./data/cifar50/images/table/train_14517.jpg
#   inflating: ./data/cifar50/images/table/train_14572.jpg
#   inflating: ./data/cifar50/images/table/train_14685.jpg
#   inflating: ./data/cifar50/images/table/train_14700.jpg
#   inflating: ./data/cifar50/images/table/train_14718.jpg
#   inflating: ./data/cifar50/images/table/train_14772.jpg
#   inflating: ./data/cifar50/images/table/train_14780.jpg
#   inflating: ./data/cifar50/images/table/train_1480.jpg
#   inflating: ./data/cifar50/images/table/train_14806.jpg
#   inflating: ./data/cifar50/images/table/train_14855.jpg
#   inflating: ./data/cifar50/images/table/train_14909.jpg
#   inflating: ./data/cifar50/images/table/train_15109.jpg
#   inflating: ./data/cifar50/images/table/train_15184.jpg
#   inflating: ./data/cifar50/images/table/train_15226.jpg
#   inflating: ./data/cifar50/images/table/train_15228.jpg
#   inflating: ./data/cifar50/images/table/train_15245.jpg
#   inflating: ./data/cifar50/images/table/train_15273.jpg
#   inflating: ./data/cifar50/images/table/train_1532.jpg
#   inflating: ./data/cifar50/images/table/train_15343.jpg
#   inflating: ./data/cifar50/images/table/train_15407.jpg
#   inflating: ./data/cifar50/images/table/train_15427.jpg
#   inflating: ./data/cifar50/images/table/train_15447.jpg
#   inflating: ./data/cifar50/images/table/train_15461.jpg
#   inflating: ./data/cifar50/images/table/train_15560.jpg
#   inflating: ./data/cifar50/images/table/train_15662.jpg
#   inflating: ./data/cifar50/images/table/train_15669.jpg
#   inflating: ./data/cifar50/images/table/train_15747.jpg
#   inflating: ./data/cifar50/images/table/train_15876.jpg
#   inflating: ./data/cifar50/images/table/train_15895.jpg
#   inflating: ./data/cifar50/images/table/train_15919.jpg
#   inflating: ./data/cifar50/images/table/train_15951.jpg
#   inflating: ./data/cifar50/images/table/train_15959.jpg
#   inflating: ./data/cifar50/images/table/train_16002.jpg
#   inflating: ./data/cifar50/images/table/train_1602.jpg
#   inflating: ./data/cifar50/images/table/train_16073.jpg
#   inflating: ./data/cifar50/images/table/train_16089.jpg
#   inflating: ./data/cifar50/images/table/train_16127.jpg
#   inflating: ./data/cifar50/images/table/train_16226.jpg
#   inflating: ./data/cifar50/images/table/train_16266.jpg
#   inflating: ./data/cifar50/images/table/train_16291.jpg
#   inflating: ./data/cifar50/images/table/train_16330.jpg
#   inflating: ./data/cifar50/images/table/train_16366.jpg
#   inflating: ./data/cifar50/images/table/train_16392.jpg
#   inflating: ./data/cifar50/images/table/train_16429.jpg
#   inflating: ./data/cifar50/images/table/train_1645.jpg
#   inflating: ./data/cifar50/images/table/train_16506.jpg
#   inflating: ./data/cifar50/images/table/train_16562.jpg
#   inflating: ./data/cifar50/images/table/train_16629.jpg
#   inflating: ./data/cifar50/images/table/train_16705.jpg
#   inflating: ./data/cifar50/images/table/train_16740.jpg
#   inflating: ./data/cifar50/images/table/train_16744.jpg
#   inflating: ./data/cifar50/images/table/train_16787.jpg
#   inflating: ./data/cifar50/images/table/train_1679.jpg
#   inflating: ./data/cifar50/images/table/train_16852.jpg
#   inflating: ./data/cifar50/images/table/train_16861.jpg
#   inflating: ./data/cifar50/images/table/train_16907.jpg
#   inflating: ./data/cifar50/images/table/train_1692.jpg
#   inflating: ./data/cifar50/images/table/train_17075.jpg
#   inflating: ./data/cifar50/images/table/train_17128.jpg
#   inflating: ./data/cifar50/images/table/train_17290.jpg
#   inflating: ./data/cifar50/images/table/train_17331.jpg
#   inflating: ./data/cifar50/images/table/train_17342.jpg
#   inflating: ./data/cifar50/images/table/train_17390.jpg
#   inflating: ./data/cifar50/images/table/train_174.jpg
#   inflating: ./data/cifar50/images/table/train_17402.jpg
#   inflating: ./data/cifar50/images/table/train_17409.jpg
#   inflating: ./data/cifar50/images/table/train_17411.jpg
#   inflating: ./data/cifar50/images/table/train_17464.jpg
#   inflating: ./data/cifar50/images/table/train_17556.jpg
#   inflating: ./data/cifar50/images/table/train_17557.jpg
#   inflating: ./data/cifar50/images/table/train_17586.jpg
#   inflating: ./data/cifar50/images/table/train_17706.jpg
#   inflating: ./data/cifar50/images/table/train_17732.jpg
#   inflating: ./data/cifar50/images/table/train_17754.jpg
#   inflating: ./data/cifar50/images/table/train_17759.jpg
#   inflating: ./data/cifar50/images/table/train_17764.jpg
#   inflating: ./data/cifar50/images/table/train_17788.jpg
#   inflating: ./data/cifar50/images/table/train_1779.jpg
#   inflating: ./data/cifar50/images/table/train_17856.jpg
#   inflating: ./data/cifar50/images/table/train_17959.jpg
#   inflating: ./data/cifar50/images/table/train_1798.jpg
#   inflating: ./data/cifar50/images/table/train_18.jpg
#   inflating: ./data/cifar50/images/table/train_18000.jpg
#   inflating: ./data/cifar50/images/table/train_18020.jpg
#   inflating: ./data/cifar50/images/table/train_18044.jpg
#   inflating: ./data/cifar50/images/table/train_18087.jpg
#   inflating: ./data/cifar50/images/table/train_18097.jpg
#   inflating: ./data/cifar50/images/table/train_18099.jpg
#   inflating: ./data/cifar50/images/table/train_18118.jpg
#   inflating: ./data/cifar50/images/table/train_1819.jpg
#   inflating: ./data/cifar50/images/table/train_18257.jpg
#   inflating: ./data/cifar50/images/table/train_18305.jpg
#   inflating: ./data/cifar50/images/table/train_18307.jpg
#   inflating: ./data/cifar50/images/table/train_18325.jpg
#   inflating: ./data/cifar50/images/table/train_18354.jpg
#   inflating: ./data/cifar50/images/table/train_18381.jpg
#   inflating: ./data/cifar50/images/table/train_18394.jpg
#   inflating: ./data/cifar50/images/table/train_18402.jpg
#   inflating: ./data/cifar50/images/table/train_18457.jpg
#   inflating: ./data/cifar50/images/table/train_18502.jpg
#   inflating: ./data/cifar50/images/table/train_18616.jpg
#   inflating: ./data/cifar50/images/table/train_18632.jpg
#   inflating: ./data/cifar50/images/table/train_18714.jpg
#   inflating: ./data/cifar50/images/table/train_18776.jpg
#   inflating: ./data/cifar50/images/table/train_18905.jpg
#   inflating: ./data/cifar50/images/table/train_18911.jpg
#   inflating: ./data/cifar50/images/table/train_1894.jpg
#   inflating: ./data/cifar50/images/table/train_18991.jpg
#   inflating: ./data/cifar50/images/table/train_19069.jpg
#   inflating: ./data/cifar50/images/table/train_1907.jpg
#   inflating: ./data/cifar50/images/table/train_19113.jpg
#   inflating: ./data/cifar50/images/table/train_19163.jpg
#   inflating: ./data/cifar50/images/table/train_19185.jpg
#   inflating: ./data/cifar50/images/table/train_19202.jpg
#   inflating: ./data/cifar50/images/table/train_19222.jpg
#   inflating: ./data/cifar50/images/table/train_19237.jpg
#   inflating: ./data/cifar50/images/table/train_19260.jpg
#   inflating: ./data/cifar50/images/table/train_19299.jpg
#   inflating: ./data/cifar50/images/table/train_19483.jpg
#   inflating: ./data/cifar50/images/table/train_19485.jpg
#   inflating: ./data/cifar50/images/table/train_19540.jpg
#   inflating: ./data/cifar50/images/table/train_1955.jpg
#   inflating: ./data/cifar50/images/table/train_19622.jpg
#   inflating: ./data/cifar50/images/table/train_19627.jpg
#   inflating: ./data/cifar50/images/table/train_19849.jpg
#   inflating: ./data/cifar50/images/table/train_19871.jpg
#   inflating: ./data/cifar50/images/table/train_1998.jpg
#   inflating: ./data/cifar50/images/table/train_2008.jpg
#   inflating: ./data/cifar50/images/table/train_20102.jpg
#   inflating: ./data/cifar50/images/table/train_20187.jpg
#   inflating: ./data/cifar50/images/table/train_20218.jpg
#   inflating: ./data/cifar50/images/table/train_20223.jpg
#   inflating: ./data/cifar50/images/table/train_20242.jpg
#   inflating: ./data/cifar50/images/table/train_20259.jpg
#   inflating: ./data/cifar50/images/table/train_20319.jpg
#   inflating: ./data/cifar50/images/table/train_20373.jpg
#   inflating: ./data/cifar50/images/table/train_2038.jpg
#   inflating: ./data/cifar50/images/table/train_20521.jpg
#   inflating: ./data/cifar50/images/table/train_20522.jpg
#   inflating: ./data/cifar50/images/table/train_20567.jpg
#   inflating: ./data/cifar50/images/table/train_20718.jpg
#   inflating: ./data/cifar50/images/table/train_20733.jpg
#   inflating: ./data/cifar50/images/table/train_20751.jpg
#   inflating: ./data/cifar50/images/table/train_20806.jpg
#   inflating: ./data/cifar50/images/table/train_20817.jpg
#   inflating: ./data/cifar50/images/table/train_20819.jpg
#   inflating: ./data/cifar50/images/table/train_20829.jpg
#   inflating: ./data/cifar50/images/table/train_20830.jpg
#   inflating: ./data/cifar50/images/table/train_2084.jpg
#   inflating: ./data/cifar50/images/table/train_20858.jpg
#   inflating: ./data/cifar50/images/table/train_21047.jpg
#   inflating: ./data/cifar50/images/table/train_21120.jpg
#   inflating: ./data/cifar50/images/table/train_21135.jpg
#   inflating: ./data/cifar50/images/table/train_21145.jpg
#   inflating: ./data/cifar50/images/table/train_21149.jpg
#   inflating: ./data/cifar50/images/table/train_21150.jpg
#   inflating: ./data/cifar50/images/table/train_21194.jpg
#   inflating: ./data/cifar50/images/table/train_21224.jpg
#   inflating: ./data/cifar50/images/table/train_21251.jpg
#   inflating: ./data/cifar50/images/table/train_21288.jpg
#   inflating: ./data/cifar50/images/table/train_2130.jpg
#   inflating: ./data/cifar50/images/table/train_21362.jpg
#   inflating: ./data/cifar50/images/table/train_21383.jpg
#   inflating: ./data/cifar50/images/table/train_21449.jpg
#   inflating: ./data/cifar50/images/table/train_21493.jpg
#   inflating: ./data/cifar50/images/table/train_21497.jpg
#   inflating: ./data/cifar50/images/table/train_21525.jpg
#   inflating: ./data/cifar50/images/table/train_21526.jpg
#   inflating: ./data/cifar50/images/table/train_21591.jpg
#   inflating: ./data/cifar50/images/table/train_21615.jpg
#   inflating: ./data/cifar50/images/table/train_21620.jpg
#   inflating: ./data/cifar50/images/table/train_21722.jpg
#   inflating: ./data/cifar50/images/table/train_21748.jpg
#   inflating: ./data/cifar50/images/table/train_21773.jpg
#   inflating: ./data/cifar50/images/table/train_22029.jpg
#   inflating: ./data/cifar50/images/table/train_22241.jpg
#   inflating: ./data/cifar50/images/table/train_22256.jpg
#   inflating: ./data/cifar50/images/table/train_22289.jpg
#   inflating: ./data/cifar50/images/table/train_22290.jpg
#   inflating: ./data/cifar50/images/table/train_22394.jpg
#   inflating: ./data/cifar50/images/table/train_22429.jpg
#   inflating: ./data/cifar50/images/table/train_22432.jpg
#   inflating: ./data/cifar50/images/table/train_22467.jpg
#   inflating: ./data/cifar50/images/table/train_22471.jpg
#   inflating: ./data/cifar50/images/table/train_22475.jpg
#   inflating: ./data/cifar50/images/table/train_22487.jpg
#   inflating: ./data/cifar50/images/table/train_22576.jpg
#   inflating: ./data/cifar50/images/table/train_22662.jpg
#   inflating: ./data/cifar50/images/table/train_22680.jpg
#   inflating: ./data/cifar50/images/table/train_22687.jpg
#   inflating: ./data/cifar50/images/table/train_22691.jpg
#   inflating: ./data/cifar50/images/table/train_22695.jpg
#   inflating: ./data/cifar50/images/table/train_22890.jpg
#   inflating: ./data/cifar50/images/table/train_22905.jpg
#   inflating: ./data/cifar50/images/table/train_22923.jpg
#   inflating: ./data/cifar50/images/table/train_22936.jpg
#   inflating: ./data/cifar50/images/table/train_22951.jpg
#   inflating: ./data/cifar50/images/table/train_23123.jpg
#   inflating: ./data/cifar50/images/table/train_23131.jpg
#   inflating: ./data/cifar50/images/table/train_23135.jpg
#   inflating: ./data/cifar50/images/table/train_23149.jpg
#   inflating: ./data/cifar50/images/table/train_23187.jpg
#   inflating: ./data/cifar50/images/table/train_23306.jpg
#   inflating: ./data/cifar50/images/table/train_23348.jpg
#   inflating: ./data/cifar50/images/table/train_23442.jpg
#   inflating: ./data/cifar50/images/table/train_23487.jpg
#   inflating: ./data/cifar50/images/table/train_23555.jpg
#   inflating: ./data/cifar50/images/table/train_23570.jpg
#   inflating: ./data/cifar50/images/table/train_23637.jpg
#   inflating: ./data/cifar50/images/table/train_23740.jpg
#   inflating: ./data/cifar50/images/table/train_23751.jpg
#   inflating: ./data/cifar50/images/table/train_23779.jpg
#   inflating: ./data/cifar50/images/table/train_23798.jpg
#   inflating: ./data/cifar50/images/table/train_23816.jpg
#   inflating: ./data/cifar50/images/table/train_23825.jpg
#   inflating: ./data/cifar50/images/table/train_23832.jpg
#   inflating: ./data/cifar50/images/table/train_23883.jpg
#   inflating: ./data/cifar50/images/table/train_23982.jpg
#   inflating: ./data/cifar50/images/table/train_24044.jpg
#   inflating: ./data/cifar50/images/table/train_24085.jpg
#   inflating: ./data/cifar50/images/table/train_24148.jpg
#   inflating: ./data/cifar50/images/table/train_24190.jpg
#   inflating: ./data/cifar50/images/table/train_24230.jpg
#   inflating: ./data/cifar50/images/table/train_24234.jpg
#   inflating: ./data/cifar50/images/table/train_24248.jpg
#   inflating: ./data/cifar50/images/table/train_24269.jpg
#   inflating: ./data/cifar50/images/table/train_24284.jpg
#   inflating: ./data/cifar50/images/table/train_24337.jpg
#   inflating: ./data/cifar50/images/table/train_2436.jpg
#   inflating: ./data/cifar50/images/table/train_24443.jpg
#   inflating: ./data/cifar50/images/table/train_24614.jpg
#   inflating: ./data/cifar50/images/table/train_24658.jpg
#   inflating: ./data/cifar50/images/table/train_24671.jpg
#   inflating: ./data/cifar50/images/table/train_24675.jpg
#   inflating: ./data/cifar50/images/table/train_2469.jpg
#   inflating: ./data/cifar50/images/table/train_24690.jpg
#   inflating: ./data/cifar50/images/table/train_24701.jpg
#   inflating: ./data/cifar50/images/table/train_24727.jpg
#   inflating: ./data/cifar50/images/table/train_24730.jpg
#   inflating: ./data/cifar50/images/table/train_24763.jpg
#   inflating: ./data/cifar50/images/table/train_24797.jpg
#   inflating: ./data/cifar50/images/table/train_24951.jpg
#   inflating: ./data/cifar50/images/table/train_2537.jpg
#   inflating: ./data/cifar50/images/table/train_259.jpg
#   inflating: ./data/cifar50/images/table/train_2639.jpg
#   inflating: ./data/cifar50/images/table/train_270.jpg
#   inflating: ./data/cifar50/images/table/train_271.jpg
#   inflating: ./data/cifar50/images/table/train_2790.jpg
#   inflating: ./data/cifar50/images/table/train_2809.jpg
#   inflating: ./data/cifar50/images/table/train_2816.jpg
#   inflating: ./data/cifar50/images/table/train_2839.jpg
#   inflating: ./data/cifar50/images/table/train_2859.jpg
#   inflating: ./data/cifar50/images/table/train_2924.jpg
#   inflating: ./data/cifar50/images/table/train_297.jpg
#   inflating: ./data/cifar50/images/table/train_2972.jpg
#   inflating: ./data/cifar50/images/table/train_3013.jpg
#   inflating: ./data/cifar50/images/table/train_3051.jpg
#   inflating: ./data/cifar50/images/table/train_308.jpg
#   inflating: ./data/cifar50/images/table/train_3250.jpg
#   inflating: ./data/cifar50/images/table/train_3288.jpg
#   inflating: ./data/cifar50/images/table/train_3319.jpg
#   inflating: ./data/cifar50/images/table/train_3372.jpg
#   inflating: ./data/cifar50/images/table/train_3427.jpg
#   inflating: ./data/cifar50/images/table/train_3480.jpg
#   inflating: ./data/cifar50/images/table/train_3534.jpg
#   inflating: ./data/cifar50/images/table/train_3597.jpg
#   inflating: ./data/cifar50/images/table/train_365.jpg
#   inflating: ./data/cifar50/images/table/train_3862.jpg
#   inflating: ./data/cifar50/images/table/train_3876.jpg
#   inflating: ./data/cifar50/images/table/train_3891.jpg
#   inflating: ./data/cifar50/images/table/train_3999.jpg
#   inflating: ./data/cifar50/images/table/train_4089.jpg
#   inflating: ./data/cifar50/images/table/train_4129.jpg
#   inflating: ./data/cifar50/images/table/train_4135.jpg
#   inflating: ./data/cifar50/images/table/train_4143.jpg
#   inflating: ./data/cifar50/images/table/train_417.jpg
#   inflating: ./data/cifar50/images/table/train_4218.jpg
#   inflating: ./data/cifar50/images/table/train_426.jpg
#   inflating: ./data/cifar50/images/table/train_4275.jpg
#   inflating: ./data/cifar50/images/table/train_4284.jpg
#   inflating: ./data/cifar50/images/table/train_4308.jpg
#   inflating: ./data/cifar50/images/table/train_4349.jpg
#   inflating: ./data/cifar50/images/table/train_44.jpg
#   inflating: ./data/cifar50/images/table/train_4407.jpg
#   inflating: ./data/cifar50/images/table/train_4409.jpg
#   inflating: ./data/cifar50/images/table/train_4549.jpg
#   inflating: ./data/cifar50/images/table/train_4565.jpg
#   inflating: ./data/cifar50/images/table/train_4608.jpg
#   inflating: ./data/cifar50/images/table/train_4615.jpg
#   inflating: ./data/cifar50/images/table/train_4682.jpg
#   inflating: ./data/cifar50/images/table/train_4688.jpg
#   inflating: ./data/cifar50/images/table/train_4722.jpg
#   inflating: ./data/cifar50/images/table/train_4757.jpg
#   inflating: ./data/cifar50/images/table/train_4785.jpg
#   inflating: ./data/cifar50/images/table/train_4806.jpg
#   inflating: ./data/cifar50/images/table/train_4820.jpg
#   inflating: ./data/cifar50/images/table/train_484.jpg
#   inflating: ./data/cifar50/images/table/train_4919.jpg
#   inflating: ./data/cifar50/images/table/train_492.jpg
#   inflating: ./data/cifar50/images/table/train_5004.jpg
#   inflating: ./data/cifar50/images/table/train_5080.jpg
#   inflating: ./data/cifar50/images/table/train_5089.jpg
#   inflating: ./data/cifar50/images/table/train_512.jpg
#   inflating: ./data/cifar50/images/table/train_514.jpg
#   inflating: ./data/cifar50/images/table/train_5140.jpg
#   inflating: ./data/cifar50/images/table/train_5209.jpg
#   inflating: ./data/cifar50/images/table/train_5227.jpg
#   inflating: ./data/cifar50/images/table/train_5314.jpg
#   inflating: ./data/cifar50/images/table/train_5429.jpg
#   inflating: ./data/cifar50/images/table/train_5441.jpg
#   inflating: ./data/cifar50/images/table/train_5504.jpg
#   inflating: ./data/cifar50/images/table/train_5526.jpg
#   inflating: ./data/cifar50/images/table/train_5563.jpg
#   inflating: ./data/cifar50/images/table/train_558.jpg
#   inflating: ./data/cifar50/images/table/train_5607.jpg
#   inflating: ./data/cifar50/images/table/train_5675.jpg
#   inflating: ./data/cifar50/images/table/train_5693.jpg
#   inflating: ./data/cifar50/images/table/train_5724.jpg
#   inflating: ./data/cifar50/images/table/train_5747.jpg
#   inflating: ./data/cifar50/images/table/train_5788.jpg
#   inflating: ./data/cifar50/images/table/train_5904.jpg
#   inflating: ./data/cifar50/images/table/train_6043.jpg
#   inflating: ./data/cifar50/images/table/train_6046.jpg
#   inflating: ./data/cifar50/images/table/train_6059.jpg
#   inflating: ./data/cifar50/images/table/train_6166.jpg
#   inflating: ./data/cifar50/images/table/train_6187.jpg
#   inflating: ./data/cifar50/images/table/train_6215.jpg
#   inflating: ./data/cifar50/images/table/train_6244.jpg
#   inflating: ./data/cifar50/images/table/train_6276.jpg
#   inflating: ./data/cifar50/images/table/train_6333.jpg
#   inflating: ./data/cifar50/images/table/train_6347.jpg
#   inflating: ./data/cifar50/images/table/train_6373.jpg
#   inflating: ./data/cifar50/images/table/train_6444.jpg
#   inflating: ./data/cifar50/images/table/train_6454.jpg
#   inflating: ./data/cifar50/images/table/train_6504.jpg
#   inflating: ./data/cifar50/images/table/train_6605.jpg
#   inflating: ./data/cifar50/images/table/train_6613.jpg
#   inflating: ./data/cifar50/images/table/train_6655.jpg
#   inflating: ./data/cifar50/images/table/train_6659.jpg
#   inflating: ./data/cifar50/images/table/train_6679.jpg
#   inflating: ./data/cifar50/images/table/train_6710.jpg
#   inflating: ./data/cifar50/images/table/train_6726.jpg
#   inflating: ./data/cifar50/images/table/train_6748.jpg
#   inflating: ./data/cifar50/images/table/train_6807.jpg
#   inflating: ./data/cifar50/images/table/train_6844.jpg
#   inflating: ./data/cifar50/images/table/train_6877.jpg
#   inflating: ./data/cifar50/images/table/train_6880.jpg
#   inflating: ./data/cifar50/images/table/train_6930.jpg
#   inflating: ./data/cifar50/images/table/train_6976.jpg
#   inflating: ./data/cifar50/images/table/train_702.jpg
#   inflating: ./data/cifar50/images/table/train_7090.jpg
#   inflating: ./data/cifar50/images/table/train_7185.jpg
#   inflating: ./data/cifar50/images/table/train_7272.jpg
#   inflating: ./data/cifar50/images/table/train_7296.jpg
#   inflating: ./data/cifar50/images/table/train_731.jpg
#   inflating: ./data/cifar50/images/table/train_7385.jpg
#   inflating: ./data/cifar50/images/table/train_7492.jpg
#   inflating: ./data/cifar50/images/table/train_7508.jpg
#   inflating: ./data/cifar50/images/table/train_751.jpg
#   inflating: ./data/cifar50/images/table/train_755.jpg
#   inflating: ./data/cifar50/images/table/train_7653.jpg
#   inflating: ./data/cifar50/images/table/train_7668.jpg
#   inflating: ./data/cifar50/images/table/train_7672.jpg
#   inflating: ./data/cifar50/images/table/train_7721.jpg
#   inflating: ./data/cifar50/images/table/train_7805.jpg
#   inflating: ./data/cifar50/images/table/train_7833.jpg
#   inflating: ./data/cifar50/images/table/train_7871.jpg
#   inflating: ./data/cifar50/images/table/train_7876.jpg
#   inflating: ./data/cifar50/images/table/train_7898.jpg
#   inflating: ./data/cifar50/images/table/train_7979.jpg
#   inflating: ./data/cifar50/images/table/train_8020.jpg
#   inflating: ./data/cifar50/images/table/train_8025.jpg
#   inflating: ./data/cifar50/images/table/train_8032.jpg
#   inflating: ./data/cifar50/images/table/train_8049.jpg
#   inflating: ./data/cifar50/images/table/train_8055.jpg
#   inflating: ./data/cifar50/images/table/train_8215.jpg
#   inflating: ./data/cifar50/images/table/train_8235.jpg
#   inflating: ./data/cifar50/images/table/train_8247.jpg
#   inflating: ./data/cifar50/images/table/train_8263.jpg
#   inflating: ./data/cifar50/images/table/train_8273.jpg
#   inflating: ./data/cifar50/images/table/train_8305.jpg
#   inflating: ./data/cifar50/images/table/train_8343.jpg
#   inflating: ./data/cifar50/images/table/train_8367.jpg
#   inflating: ./data/cifar50/images/table/train_8388.jpg
#   inflating: ./data/cifar50/images/table/train_8406.jpg
#   inflating: ./data/cifar50/images/table/train_8415.jpg
#   inflating: ./data/cifar50/images/table/train_8427.jpg
#   inflating: ./data/cifar50/images/table/train_8447.jpg
#   inflating: ./data/cifar50/images/table/train_8450.jpg
#   inflating: ./data/cifar50/images/table/train_8558.jpg
#   inflating: ./data/cifar50/images/table/train_8575.jpg
#   inflating: ./data/cifar50/images/table/train_8645.jpg
#   inflating: ./data/cifar50/images/table/train_881.jpg
#   inflating: ./data/cifar50/images/table/train_8855.jpg
#   inflating: ./data/cifar50/images/table/train_8945.jpg
#   inflating: ./data/cifar50/images/table/train_8961.jpg
#   inflating: ./data/cifar50/images/table/train_9047.jpg
#   inflating: ./data/cifar50/images/table/train_9243.jpg
#   inflating: ./data/cifar50/images/table/train_935.jpg
#   inflating: ./data/cifar50/images/table/train_9352.jpg
#   inflating: ./data/cifar50/images/table/train_938.jpg
#   inflating: ./data/cifar50/images/table/train_9481.jpg
#   inflating: ./data/cifar50/images/table/train_9665.jpg
#   inflating: ./data/cifar50/images/table/train_9675.jpg
#   inflating: ./data/cifar50/images/table/train_9763.jpg
#    creating: ./data/cifar50/images/telephone/
#   inflating: ./data/cifar50/images/telephone/test_1026.jpg
#   inflating: ./data/cifar50/images/telephone/test_1037.jpg
#   inflating: ./data/cifar50/images/telephone/test_1081.jpg
#   inflating: ./data/cifar50/images/telephone/test_1186.jpg
#   inflating: ./data/cifar50/images/telephone/test_1223.jpg
#   inflating: ./data/cifar50/images/telephone/test_1261.jpg
#   inflating: ./data/cifar50/images/telephone/test_1335.jpg
#   inflating: ./data/cifar50/images/telephone/test_144.jpg
#   inflating: ./data/cifar50/images/telephone/test_1496.jpg
#   inflating: ./data/cifar50/images/telephone/test_1514.jpg
#   inflating: ./data/cifar50/images/telephone/test_1516.jpg
#   inflating: ./data/cifar50/images/telephone/test_152.jpg
#   inflating: ./data/cifar50/images/telephone/test_1536.jpg
#   inflating: ./data/cifar50/images/telephone/test_1609.jpg
#   inflating: ./data/cifar50/images/telephone/test_1800.jpg
#   inflating: ./data/cifar50/images/telephone/test_1804.jpg
# ...
#   inflating: ./data/cifar50/images/woman/train_20270.jpg
#   inflating: ./data/cifar50/images/woman/train_20333.jpg
#   inflating: ./data/cifar50/images/woman/train_20383.jpg
#   inflating: ./data/cifar50/images/woman/train_20389.jpg
#   inflating: ./data/cifar50/images/woman/train_20490.jpg
#   inflating: ./data/cifar50/images/woman/train_20509.jpg
#   inflating: ./data/cifar50/images/woman/train_20527.jpg
#   inflating: ./data/cifar50/images/woman/train_20538.jpg
#   inflating: ./data/cifar50/images/woman/train_20552.jpg
#   inflating: ./data/cifar50/images/woman/train_20581.jpg
#   inflating: ./data/cifar50/images/woman/train_2060.jpg
#   inflating: ./data/cifar50/images/woman/train_20731.jpg
#   inflating: ./data/cifar50/images/woman/train_20736.jpg
#   inflating: ./data/cifar50/images/woman/train_20746.jpg
#   inflating: ./data/cifar50/images/woman/train_20784.jpg
#   inflating: ./data/cifar50/images/woman/train_20798.jpg
#   inflating: ./data/cifar50/images/woman/train_20800.jpg
#   inflating: ./data/cifar50/images/woman/train_20843.jpg
#   inflating: ./data/cifar50/images/woman/train_2092.jpg
#   inflating: ./data/cifar50/images/woman/train_2094.jpg
#   inflating: ./data/cifar50/images/woman/train_20943.jpg
#   inflating: ./data/cifar50/images/woman/train_20960.jpg
#   inflating: ./data/cifar50/images/woman/train_21004.jpg
#   inflating: ./data/cifar50/images/woman/train_21010.jpg
#   inflating: ./data/cifar50/images/woman/train_21084.jpg
#   inflating: ./data/cifar50/images/woman/train_21174.jpg
#   inflating: ./data/cifar50/images/woman/train_21207.jpg
#   inflating: ./data/cifar50/images/woman/train_21269.jpg
#   inflating: ./data/cifar50/images/woman/train_21302.jpg
#   inflating: ./data/cifar50/images/woman/train_21313.jpg
#   inflating: ./data/cifar50/images/woman/train_21379.jpg
#   inflating: ./data/cifar50/images/woman/train_21384.jpg
#   inflating: ./data/cifar50/images/woman/train_2141.jpg
#   inflating: ./data/cifar50/images/woman/train_21428.jpg
#   inflating: ./data/cifar50/images/woman/train_21474.jpg
#   inflating: ./data/cifar50/images/woman/train_21483.jpg
#   inflating: ./data/cifar50/images/woman/train_21676.jpg
#   inflating: ./data/cifar50/images/woman/train_21756.jpg
#   inflating: ./data/cifar50/images/woman/train_21832.jpg
#   inflating: ./data/cifar50/images/woman/train_21849.jpg
#   inflating: ./data/cifar50/images/woman/train_21981.jpg
#   inflating: ./data/cifar50/images/woman/train_21995.jpg
#   inflating: ./data/cifar50/images/woman/train_21996.jpg
#   inflating: ./data/cifar50/images/woman/train_22062.jpg
#   inflating: ./data/cifar50/images/woman/train_22198.jpg
#   inflating: ./data/cifar50/images/woman/train_22204.jpg
#   inflating: ./data/cifar50/images/woman/train_22259.jpg
#   inflating: ./data/cifar50/images/woman/train_22343.jpg
#   inflating: ./data/cifar50/images/woman/train_22384.jpg
#   inflating: ./data/cifar50/images/woman/train_22552.jpg
#   inflating: ./data/cifar50/images/woman/train_22597.jpg
#   inflating: ./data/cifar50/images/woman/train_22619.jpg
#   inflating: ./data/cifar50/images/woman/train_22724.jpg
#   inflating: ./data/cifar50/images/woman/train_22745.jpg
#   inflating: ./data/cifar50/images/woman/train_22755.jpg
#   inflating: ./data/cifar50/images/woman/train_22756.jpg
#   inflating: ./data/cifar50/images/woman/train_22780.jpg
#   inflating: ./data/cifar50/images/woman/train_22855.jpg
#   inflating: ./data/cifar50/images/woman/train_22935.jpg
#   inflating: ./data/cifar50/images/woman/train_23023.jpg
#   inflating: ./data/cifar50/images/woman/train_23027.jpg
#   inflating: ./data/cifar50/images/woman/train_23076.jpg
#   inflating: ./data/cifar50/images/woman/train_23106.jpg
#   inflating: ./data/cifar50/images/woman/train_23155.jpg
#   inflating: ./data/cifar50/images/woman/train_23161.jpg
#   inflating: ./data/cifar50/images/woman/train_23200.jpg
#   inflating: ./data/cifar50/images/woman/train_23256.jpg
#   inflating: ./data/cifar50/images/woman/train_23281.jpg
#   inflating: ./data/cifar50/images/woman/train_23322.jpg
#   inflating: ./data/cifar50/images/woman/train_23337.jpg
#   inflating: ./data/cifar50/images/woman/train_23361.jpg
#   inflating: ./data/cifar50/images/woman/train_23380.jpg
#   inflating: ./data/cifar50/images/woman/train_2349.jpg
#   inflating: ./data/cifar50/images/woman/train_23540.jpg
#   inflating: ./data/cifar50/images/woman/train_23696.jpg
#   inflating: ./data/cifar50/images/woman/train_23725.jpg
#   inflating: ./data/cifar50/images/woman/train_23774.jpg
#   inflating: ./data/cifar50/images/woman/train_23864.jpg
#   inflating: ./data/cifar50/images/woman/train_23890.jpg
#   inflating: ./data/cifar50/images/woman/train_23928.jpg
#   inflating: ./data/cifar50/images/woman/train_23953.jpg
#   inflating: ./data/cifar50/images/woman/train_23980.jpg
#   inflating: ./data/cifar50/images/woman/train_24052.jpg
#   inflating: ./data/cifar50/images/woman/train_241.jpg
#   inflating: ./data/cifar50/images/woman/train_24132.jpg
#   inflating: ./data/cifar50/images/woman/train_24156.jpg
#   inflating: ./data/cifar50/images/woman/train_24158.jpg
#   inflating: ./data/cifar50/images/woman/train_24239.jpg
#   inflating: ./data/cifar50/images/woman/train_24246.jpg
#   inflating: ./data/cifar50/images/woman/train_24266.jpg
#   inflating: ./data/cifar50/images/woman/train_24268.jpg
#   inflating: ./data/cifar50/images/woman/train_24293.jpg
#   inflating: ./data/cifar50/images/woman/train_24519.jpg
#   inflating: ./data/cifar50/images/woman/train_24584.jpg
#   inflating: ./data/cifar50/images/woman/train_24723.jpg
#   inflating: ./data/cifar50/images/woman/train_24729.jpg
#   inflating: ./data/cifar50/images/woman/train_24750.jpg
#   inflating: ./data/cifar50/images/woman/train_24751.jpg
#   inflating: ./data/cifar50/images/woman/train_2480.jpg
#   inflating: ./data/cifar50/images/woman/train_24842.jpg
#   inflating: ./data/cifar50/images/woman/train_24888.jpg
#   inflating: ./data/cifar50/images/woman/train_24908.jpg
#   inflating: ./data/cifar50/images/woman/train_24926.jpg
#   inflating: ./data/cifar50/images/woman/train_24965.jpg
#   inflating: ./data/cifar50/images/woman/train_2497.jpg
#   inflating: ./data/cifar50/images/woman/train_2504.jpg
#   inflating: ./data/cifar50/images/woman/train_2528.jpg
#   inflating: ./data/cifar50/images/woman/train_2541.jpg
#   inflating: ./data/cifar50/images/woman/train_2672.jpg
#   inflating: ./data/cifar50/images/woman/train_2674.jpg
#   inflating: ./data/cifar50/images/woman/train_27.jpg
#   inflating: ./data/cifar50/images/woman/train_2752.jpg
#   inflating: ./data/cifar50/images/woman/train_2754.jpg
#   inflating: ./data/cifar50/images/woman/train_276.jpg
#   inflating: ./data/cifar50/images/woman/train_2837.jpg
#   inflating: ./data/cifar50/images/woman/train_289.jpg
#   inflating: ./data/cifar50/images/woman/train_2891.jpg
#   inflating: ./data/cifar50/images/woman/train_2979.jpg
#   inflating: ./data/cifar50/images/woman/train_3026.jpg
#   inflating: ./data/cifar50/images/woman/train_3065.jpg
#   inflating: ./data/cifar50/images/woman/train_3091.jpg
#   inflating: ./data/cifar50/images/woman/train_310.jpg
#   inflating: ./data/cifar50/images/woman/train_3175.jpg
#   inflating: ./data/cifar50/images/woman/train_3180.jpg
#   inflating: ./data/cifar50/images/woman/train_319.jpg
#   inflating: ./data/cifar50/images/woman/train_3283.jpg
#   inflating: ./data/cifar50/images/woman/train_3339.jpg
#   inflating: ./data/cifar50/images/woman/train_335.jpg
#   inflating: ./data/cifar50/images/woman/train_3355.jpg
#   inflating: ./data/cifar50/images/woman/train_343.jpg
#   inflating: ./data/cifar50/images/woman/train_3529.jpg
#   inflating: ./data/cifar50/images/woman/train_3537.jpg
#   inflating: ./data/cifar50/images/woman/train_356.jpg
#   inflating: ./data/cifar50/images/woman/train_3566.jpg
#   inflating: ./data/cifar50/images/woman/train_3618.jpg
#   inflating: ./data/cifar50/images/woman/train_3619.jpg
#   inflating: ./data/cifar50/images/woman/train_3643.jpg
#   inflating: ./data/cifar50/images/woman/train_369.jpg
#   inflating: ./data/cifar50/images/woman/train_3778.jpg
#   inflating: ./data/cifar50/images/woman/train_3917.jpg
#   inflating: ./data/cifar50/images/woman/train_4085.jpg
#   inflating: ./data/cifar50/images/woman/train_4094.jpg
#   inflating: ./data/cifar50/images/woman/train_4139.jpg
#   inflating: ./data/cifar50/images/woman/train_4157.jpg
#   inflating: ./data/cifar50/images/woman/train_4210.jpg
#   inflating: ./data/cifar50/images/woman/train_4269.jpg
#   inflating: ./data/cifar50/images/woman/train_4288.jpg
#   inflating: ./data/cifar50/images/woman/train_431.jpg
#   inflating: ./data/cifar50/images/woman/train_4347.jpg
#   inflating: ./data/cifar50/images/woman/train_4364.jpg
#   inflating: ./data/cifar50/images/woman/train_4394.jpg
#   inflating: ./data/cifar50/images/woman/train_4527.jpg
#   inflating: ./data/cifar50/images/woman/train_453.jpg
#   inflating: ./data/cifar50/images/woman/train_4638.jpg
#   inflating: ./data/cifar50/images/woman/train_4719.jpg
#   inflating: ./data/cifar50/images/woman/train_4774.jpg
#   inflating: ./data/cifar50/images/woman/train_478.jpg
#   inflating: ./data/cifar50/images/woman/train_4821.jpg
#   inflating: ./data/cifar50/images/woman/train_4850.jpg
#   inflating: ./data/cifar50/images/woman/train_4925.jpg
#   inflating: ./data/cifar50/images/woman/train_4928.jpg
#   inflating: ./data/cifar50/images/woman/train_4935.jpg
#   inflating: ./data/cifar50/images/woman/train_4936.jpg
#   inflating: ./data/cifar50/images/woman/train_4971.jpg
#   inflating: ./data/cifar50/images/woman/train_5022.jpg
#   inflating: ./data/cifar50/images/woman/train_507.jpg
#   inflating: ./data/cifar50/images/woman/train_5170.jpg
#   inflating: ./data/cifar50/images/woman/train_5200.jpg
#   inflating: ./data/cifar50/images/woman/train_5223.jpg
#   inflating: ./data/cifar50/images/woman/train_5225.jpg
#   inflating: ./data/cifar50/images/woman/train_5305.jpg
#   inflating: ./data/cifar50/images/woman/train_5395.jpg
#   inflating: ./data/cifar50/images/woman/train_5409.jpg
#   inflating: ./data/cifar50/images/woman/train_5414.jpg
#   inflating: ./data/cifar50/images/woman/train_5531.jpg
#   inflating: ./data/cifar50/images/woman/train_5599.jpg
#   inflating: ./data/cifar50/images/woman/train_5613.jpg
#   inflating: ./data/cifar50/images/woman/train_5695.jpg
#   inflating: ./data/cifar50/images/woman/train_5723.jpg
#   inflating: ./data/cifar50/images/woman/train_573.jpg
#   inflating: ./data/cifar50/images/woman/train_5815.jpg
#   inflating: ./data/cifar50/images/woman/train_5833.jpg
#   inflating: ./data/cifar50/images/woman/train_5865.jpg
#   inflating: ./data/cifar50/images/woman/train_5898.jpg
#   inflating: ./data/cifar50/images/woman/train_5961.jpg
#   inflating: ./data/cifar50/images/woman/train_5971.jpg
#   inflating: ./data/cifar50/images/woman/train_6021.jpg
#   inflating: ./data/cifar50/images/woman/train_6035.jpg
#   inflating: ./data/cifar50/images/woman/train_6065.jpg
#   inflating: ./data/cifar50/images/woman/train_6136.jpg
#   inflating: ./data/cifar50/images/woman/train_6141.jpg
#   inflating: ./data/cifar50/images/woman/train_6146.jpg
#   inflating: ./data/cifar50/images/woman/train_6155.jpg
#   inflating: ./data/cifar50/images/woman/train_6193.jpg
#   inflating: ./data/cifar50/images/woman/train_6202.jpg
#   inflating: ./data/cifar50/images/woman/train_6203.jpg
#   inflating: ./data/cifar50/images/woman/train_6205.jpg
#   inflating: ./data/cifar50/images/woman/train_6271.jpg
#   inflating: ./data/cifar50/images/woman/train_6311.jpg
#   inflating: ./data/cifar50/images/woman/train_6313.jpg
#   inflating: ./data/cifar50/images/woman/train_632.jpg
#   inflating: ./data/cifar50/images/woman/train_6339.jpg
#   inflating: ./data/cifar50/images/woman/train_6402.jpg
#   inflating: ./data/cifar50/images/woman/train_6408.jpg
#   inflating: ./data/cifar50/images/woman/train_6448.jpg
#   inflating: ./data/cifar50/images/woman/train_647.jpg
#   inflating: ./data/cifar50/images/woman/train_6509.jpg
#   inflating: ./data/cifar50/images/woman/train_6559.jpg
#   inflating: ./data/cifar50/images/woman/train_658.jpg
#   inflating: ./data/cifar50/images/woman/train_6586.jpg
#   inflating: ./data/cifar50/images/woman/train_6587.jpg
#   inflating: ./data/cifar50/images/woman/train_663.jpg
#   inflating: ./data/cifar50/images/woman/train_6722.jpg
#   inflating: ./data/cifar50/images/woman/train_6776.jpg
#   inflating: ./data/cifar50/images/woman/train_6782.jpg
#   inflating: ./data/cifar50/images/woman/train_6819.jpg
#   inflating: ./data/cifar50/images/woman/train_6857.jpg
#   inflating: ./data/cifar50/images/woman/train_6878.jpg
#   inflating: ./data/cifar50/images/woman/train_7038.jpg
#   inflating: ./data/cifar50/images/woman/train_7041.jpg
#   inflating: ./data/cifar50/images/woman/train_7097.jpg
#   inflating: ./data/cifar50/images/woman/train_7208.jpg
#   inflating: ./data/cifar50/images/woman/train_722.jpg
#   inflating: ./data/cifar50/images/woman/train_7339.jpg
#   inflating: ./data/cifar50/images/woman/train_7408.jpg
#   inflating: ./data/cifar50/images/woman/train_7471.jpg
#   inflating: ./data/cifar50/images/woman/train_7568.jpg
#   inflating: ./data/cifar50/images/woman/train_7587.jpg
#   inflating: ./data/cifar50/images/woman/train_7631.jpg
#   inflating: ./data/cifar50/images/woman/train_7644.jpg
#   inflating: ./data/cifar50/images/woman/train_7752.jpg
#   inflating: ./data/cifar50/images/woman/train_785.jpg
#   inflating: ./data/cifar50/images/woman/train_7900.jpg
#   inflating: ./data/cifar50/images/woman/train_7923.jpg
#   inflating: ./data/cifar50/images/woman/train_7946.jpg
#   inflating: ./data/cifar50/images/woman/train_8043.jpg
#   inflating: ./data/cifar50/images/woman/train_8068.jpg
#   inflating: ./data/cifar50/images/woman/train_8114.jpg
#   inflating: ./data/cifar50/images/woman/train_8227.jpg
#   inflating: ./data/cifar50/images/woman/train_8334.jpg
#   inflating: ./data/cifar50/images/woman/train_8429.jpg
#   inflating: ./data/cifar50/images/woman/train_8433.jpg
#   inflating: ./data/cifar50/images/woman/train_8618.jpg
#   inflating: ./data/cifar50/images/woman/train_8768.jpg
#   inflating: ./data/cifar50/images/woman/train_879.jpg
#   inflating: ./data/cifar50/images/woman/train_8843.jpg
#   inflating: ./data/cifar50/images/woman/train_89.jpg
#   inflating: ./data/cifar50/images/woman/train_9032.jpg
#   inflating: ./data/cifar50/images/woman/train_9073.jpg
#   inflating: ./data/cifar50/images/woman/train_9089.jpg
#   inflating: ./data/cifar50/images/woman/train_9159.jpg
#   inflating: ./data/cifar50/images/woman/train_9230.jpg
#   inflating: ./data/cifar50/images/woman/train_9235.jpg
#   inflating: ./data/cifar50/images/woman/train_924.jpg
#   inflating: ./data/cifar50/images/woman/train_9259.jpg
#   inflating: ./data/cifar50/images/woman/train_9340.jpg
#   inflating: ./data/cifar50/images/woman/train_9396.jpg
#   inflating: ./data/cifar50/images/woman/train_9456.jpg
#   inflating: ./data/cifar50/images/woman/train_9460.jpg
#   inflating: ./data/cifar50/images/woman/train_9466.jpg
#   inflating: ./data/cifar50/images/woman/train_9472.jpg
#   inflating: ./data/cifar50/images/woman/train_9507.jpg
#   inflating: ./data/cifar50/images/woman/train_9508.jpg
#   inflating: ./data/cifar50/images/woman/train_952.jpg
#   inflating: ./data/cifar50/images/woman/train_9548.jpg
#   inflating: ./data/cifar50/images/woman/train_9593.jpg
#   inflating: ./data/cifar50/images/woman/train_9633.jpg
#   inflating: ./data/cifar50/images/woman/train_9658.jpg
#   inflating: ./data/cifar50/images/woman/train_9679.jpg
#   inflating: ./data/cifar50/images/woman/train_9711.jpg
#   inflating: ./data/cifar50/images/woman/train_9840.jpg
#   inflating: ./data/cifar50/images/woman/train_9948.jpg
#   inflating: ./data/cifar50/images/woman/train_9957.jpg
#   inflating: ./data/cifar50/images/woman/train_9975.jpg

# %%
# todo: you can change to your download location

# !mkdir ./data/cifar50_imbalance_0.02
# !unzip /content/gdrive/MyDrive/EEP596/cifar50_imbalance_0.02.zip -d ./data/cifar50_imbalance_0.02
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4763.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4764.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4765.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4766.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4767.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4768.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4769.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4770.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4771.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4772.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4773.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4774.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4775.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4776.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4777.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4778.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4779.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4780.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4781.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4782.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4783.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4784.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4785.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4786.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4787.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4788.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4789.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4790.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4791.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4792.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4793.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4794.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4795.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4796.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4797.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4798.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4799.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4800.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4801.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4802.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4803.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4804.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4805.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4806.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4807.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4808.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4809.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4810.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4811.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4812.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4813.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4814.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4815.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4816.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4817.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4818.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4819.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4820.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4821.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4822.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4823.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4824.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4825.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4826.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4827.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4828.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4829.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4830.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4831.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4832.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4833.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4834.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4835.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4836.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4837.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4838.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4839.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4840.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4841.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4842.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4843.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4844.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4845.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4846.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4847.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4848.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4849.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4850.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4851.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4852.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/flatfish/train_4853.jpg
#    creating: ./data/cifar50_imbalance_0.02/images/fox/
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1040.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_113.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1145.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1148.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1152.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1194.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1238.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1252.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1363.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1395.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1425.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1543.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1663.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_167.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_176.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1780.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1782.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1783.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1802.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1861.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1891.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1926.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1970.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1971.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_1995.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2058.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2091.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2096.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2102.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2115.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2132.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2179.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2277.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2317.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2320.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2344.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2408.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2412.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2468.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2514.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2791.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2843.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2901.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2936.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2942.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_2965.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3039.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3082.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3083.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3245.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3266.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3283.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3353.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_338.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3412.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3524.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3586.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3632.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3643.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3659.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3680.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3709.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3776.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3804.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3836.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3916.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_3983.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4008.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4072.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4077.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4091.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4101.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4123.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4125.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4221.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4235.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4338.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4366.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4384.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4390.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4393.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4408.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4583.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4740.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4759.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4850.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_487.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_4923.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_493.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_569.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_605.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_659.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_699.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_714.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_718.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_750.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_816.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_845.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_884.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/test_895.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4854.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4855.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4856.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4857.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4858.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4859.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4860.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4861.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4862.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4863.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4864.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4865.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4866.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4867.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4868.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4869.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4870.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4871.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4872.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4873.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4874.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4875.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4876.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4877.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4878.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4879.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4880.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4881.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4882.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4883.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4884.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4885.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4886.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4887.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4888.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4889.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4890.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4891.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4892.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4893.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4894.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4895.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4896.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4897.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4898.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4899.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4900.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4901.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4902.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4903.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4904.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4905.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4906.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4907.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4908.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4909.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4910.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4911.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4912.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4913.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4914.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4915.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4916.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4917.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4918.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4919.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4920.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4921.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4922.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4923.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4924.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4925.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4926.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4927.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4928.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4929.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4930.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4931.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4932.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4933.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4934.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4935.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4936.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4937.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4938.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4939.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4940.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4941.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4942.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4943.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4944.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4945.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4946.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4947.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4948.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4949.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4950.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4951.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4952.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4953.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4954.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4955.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4956.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4957.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4958.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4959.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4960.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4961.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4962.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4963.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4964.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4965.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4966.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4967.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4968.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4969.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4970.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4971.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4972.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4973.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4974.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4975.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4976.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4977.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4978.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4979.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4980.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4981.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4982.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/fox/train_4983.jpg
#    creating: ./data/cifar50_imbalance_0.02/images/hamster/
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1020.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1041.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_110.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1174.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_118.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1292.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1347.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1348.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1352.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1393.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1459.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1487.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1542.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1554.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1595.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1601.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_164.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1702.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1897.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_1968.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2150.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_219.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2239.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2386.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_247.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2498.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2557.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_256.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2604.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2650.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2662.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2746.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_281.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_282.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2825.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2830.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2831.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_2894.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3009.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3017.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3037.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3074.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3079.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3154.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3228.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3262.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3279.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3301.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_332.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3322.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3326.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3341.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3394.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3458.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3481.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3546.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3600.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3674.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3685.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3751.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3876.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3889.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_3898.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4067.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_414.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4148.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_416.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4193.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4274.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4343.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4433.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4464.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_451.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4548.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_455.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4632.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4656.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4687.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4701.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4753.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4797.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4825.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4866.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4896.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_4949.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_497.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_507.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_521.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_541.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_596.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_606.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_631.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_69.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_780.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_926.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_950.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_964.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_968.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_977.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/test_997.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4984.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4985.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4986.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4987.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4988.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4989.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4990.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4991.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4992.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4993.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4994.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4995.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4996.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4997.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4998.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_4999.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5000.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5001.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5002.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5003.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5004.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5005.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5006.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5007.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5008.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5009.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5010.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5011.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5012.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5013.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5014.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5015.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5016.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5017.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5018.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5019.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5020.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5021.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5022.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5023.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5024.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5025.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5026.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5027.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5028.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5029.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5030.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5031.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5032.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5033.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5034.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5035.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5036.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5037.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5038.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5039.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5040.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5041.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5042.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5043.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5044.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5045.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5046.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5047.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5048.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5049.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5050.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5051.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5052.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5053.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5054.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5055.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5056.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5057.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5058.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5059.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5060.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5061.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5062.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5063.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5064.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5065.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5066.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5067.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5068.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5069.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5070.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5071.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5072.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5073.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5074.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5075.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5076.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5077.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5078.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5079.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5080.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5081.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5082.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5083.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5084.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5085.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5086.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5087.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5088.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5089.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5090.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5091.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5092.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5093.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5094.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5095.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5096.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5097.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5098.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5099.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5100.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5101.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5102.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/hamster/train_5103.jpg
#    creating: ./data/cifar50_imbalance_0.02/images/kangaroo/
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1002.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1045.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1109.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1114.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1127.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1158.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1177.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1351.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1366.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1372.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1392.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_141.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1413.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1437.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1476.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1485.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1508.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1549.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1637.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1657.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1726.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1771.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1811.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1840.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1893.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1906.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1947.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1953.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_1964.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2028.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2037.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2121.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2135.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2212.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2229.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2271.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_234.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_245.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2480.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2503.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_251.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2547.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2596.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2768.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_285.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_288.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2886.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_2908.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3044.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3177.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3314.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3323.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3438.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3469.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3507.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3520.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3550.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3614.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3626.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_374.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3830.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_3973.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_398.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4020.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4076.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4152.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4181.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4214.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4285.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4326.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4355.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4401.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4431.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4469.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4508.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4529.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4538.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4599.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4685.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4692.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4699.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4719.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4838.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4878.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4882.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4889.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_4916.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_555.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_590.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_592.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_611.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_613.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_665.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_666.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_694.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_849.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_852.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_888.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_973.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/test_986.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5104.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5105.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5106.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5107.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5108.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5109.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5110.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5111.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5112.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/kangaroo/train_5113.jpg
# ...
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1427.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_146.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1482.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_149.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1556.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1584.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1689.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1711.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1768.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1769.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1776.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_180.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1888.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_1954.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2005.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2010.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_206.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_211.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2126.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2164.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2206.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2276.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2303.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2334.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2379.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2610.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2622.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2801.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_287.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_2915.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3020.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3059.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3062.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3108.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3125.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_317.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3191.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3282.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3320.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3420.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3425.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3432.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3503.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3518.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3548.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3591.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3609.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3610.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3693.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3695.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3718.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3780.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3787.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_382.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3909.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_3999.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4037.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4096.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4207.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_426.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4345.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4400.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4403.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_442.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4435.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4459.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4496.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4530.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_454.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4564.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4666.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4670.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_470.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4708.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4721.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4824.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4840.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4893.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_4991.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_505.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_539.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_548.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_568.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_624.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_647.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_677.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_683.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_793.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_814.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_860.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_886.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/test_996.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6409.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6410.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6411.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6412.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6413.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6414.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6415.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6416.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6417.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6418.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/willow_tree/train_6419.jpg
#    creating: ./data/cifar50_imbalance_0.02/images/woman/
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1001.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1058.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1092.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1169.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1224.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1277.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1308.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1400.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1404.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1417.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1433.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1567.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1608.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1676.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1714.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1744.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1912.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1934.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1961.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_1983.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_204.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2085.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2142.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2156.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_216.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2188.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2207.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2219.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_228.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2290.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2362.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2375.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2407.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2449.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2500.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2517.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2555.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2598.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_260.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2663.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2669.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2750.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2757.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_2802.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_297.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3005.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3029.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_304.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3160.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3299.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3384.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3544.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3569.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3598.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3635.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3743.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3752.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_381.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3813.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3874.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_3883.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4063.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4115.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4157.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4198.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4226.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_432.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4323.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4331.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_435.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4451.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4479.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4491.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4518.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4528.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4565.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4659.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4746.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4756.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4770.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4781.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4863.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4871.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4887.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4909.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_4924.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_563.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_585.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_623.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_674.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_685.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_737.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_822.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_832.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_84.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_937.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_963.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_97.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_987.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/test_998.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6420.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6421.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6422.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6423.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6424.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6425.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6426.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6427.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6428.jpg
#   inflating: ./data/cifar50_imbalance_0.02/images/woman/train_6429.jpg

# %% [markdown]
# Load and print label files to know the format of the provided labels.
# - `cifar50_train.json`
# - `cifar50_imbalance_0.02_train.json`

# %%
# todo: load json files and print.
import json

def load_cifar_set(filepath: str) -> dict:
  with open(filepath) as fhand:
    data = json.load(fhand)

  print(type(data))
  print(data.keys())
  print(data['annotations'][0])
  print(data['annotations'][1])
  print(data['num_classes'])

  annotations = data['annotations']
  print(f"There are {len(annotations)} images in the set.")

  return annotations

fpath = "./data/cifar50/cifar50_train.json"

annotations = load_cifar_set(fpath)

# create an array of distinct class labels
# the cross entropy criterion expects a class index 0-49
class_names = []
for a in annotations:
  if (a['category']) not in class_names:
    class_names.append(a['category'])

print(f"There are {len(class_names)} unique classes.")
# Out:
# <class 'dict'>
# dict_keys(['annotations', 'num_classes'])
# {'fpath': 'data\\cifar50\\images\\apple\\train_0.jpg', 'image_id': 0, 'category_id': 0, 'category': 'apple'}
# {'fpath': 'data\\cifar50\\images\\telephone\\train_1.jpg', 'image_id': 1, 'category_id': 86, 'category': 'telephone'}
# 50
# There are 25000 images in the set.
# There are 50 unique classes.

# %% [markdown]
# Show some images with labels (class names) from dataset.

# %% [markdown]
# Preparing Pytorch dataset and dataloader

# %%
import os
import typing
import torch
import numpy as np
import math
import random
from torchvision.io import read_image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

class Cifar50_Dataset(Dataset):
  """Defines a custom Pytorch dataset as outlined by the Pytorch tutorial
  at https://pytorch.org/tutorials/beginner/basics/data_tutorial.html
  """
  def __init__(self, annotations: dict, transform=None, target_transform=None):
    self.annotations = annotations
    self.image_dir = '.'
    self.transform = transform
    self.target_transform = target_transform

  def __len__(self):
    return len(self.annotations)

  def __getitem__(self, idx):
    img_path = os.path.join(self.image_dir, self.annotations[idx]['fpath'].replace('\\', '/'))
    image = read_image(img_path)
    label = class_names.index(self.annotations[idx]['category'])
    if self.transform:
      image = self.transform(image)
    if self.target_transform:
      label = self.target_transform(label)
    
    return image, label

transform = transforms.Compose(
    [
        transforms.ConvertImageDtype(torch.float32),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

def split_data(fullset: list, train_length: float, valid_length: float, test_length: float) -> list:
  """Splits list into train, validation, and test lists. 
  """
  res = []
  shuffled = fullset
  random.shuffle(fullset)

  print(len(shuffled))

  first_split_index = math.ceil(len(shuffled) * train_length)
  second_split_index = first_split_index + math.ceil(len(shuffled) * valid_length)

  print(first_split_index, second_split_index)

  res.append(shuffled[:first_split_index])
  res.append(shuffled[first_split_index:second_split_index])
  res.append(shuffled[second_split_index:])

  return res

train_annotations, valid_annotations, test_annotations = split_data(annotations, 0.8, 0.1, 0.1)

cifar50_trainset = Cifar50_Dataset(train_annotations, transform=transform)
cifar50_validset = Cifar50_Dataset(valid_annotations, transform=transform)
cifar50_testset = Cifar50_Dataset(test_annotations, transform=transform)

print(len(cifar50_trainset), len(cifar50_validset), len(cifar50_testset))

cifar50_trainloader = DataLoader(cifar50_trainset, batch_size=64, shuffle=True)
cifar50_validloader = DataLoader(cifar50_validset, batch_size=64, shuffle=True)
cifar50_testloader = DataLoader(cifar50_testset, batch_size=64, shuffle=True)

features, labels = next(iter(cifar50_trainloader))
print(f"Feature batch shape: {features.size()}")
print(f"Feature batch dtype: {features.dtype}")
print(f"Labels batch shape: {len(labels)}")
print(f"Example image tensor\n{features[0]}")
# Out:
# 25000
# 20000 22500
# 20000 2500 2500
# Feature batch shape: torch.Size([64, 3, 32, 32])
# Feature batch dtype: torch.float32
# Labels batch shape: 64
# Example image tensor
# tensor([[[-0.4588, -0.3176, -0.2941,  ...,  0.1686,  0.1608,  0.1137],
#          [-0.2863, -0.2549, -0.2392,  ...,  0.1294,  0.1373,  0.1216],
#          [-0.0667, -0.0824, -0.0824,  ...,  0.0510,  0.0667,  0.0980],
#          ...,
#          [-0.0118,  0.0196,  0.1294,  ...,  0.0510,  0.0353,  0.0510],
#          [-0.1059, -0.0275,  0.1059,  ...,  0.0275,  0.0275,  0.0431],
#          [-0.1373, -0.0824,  0.0275,  ...,  0.0667,  0.0824,  0.0745]],
#
#         [[-0.0824,  0.0275, -0.0353,  ...,  0.0588,  0.0431,  0.0039],
#          [-0.0039,  0.0039, -0.0353,  ..., -0.0039,  0.0196,  0.0039],
#          [ 0.0353,  0.0039,  0.0118,  ..., -0.0902, -0.0824, -0.0431],
#          ...,
#          [ 0.1373,  0.1373,  0.1608,  ...,  0.0353,  0.0196,  0.0510],
#          [ 0.1137,  0.1216,  0.1686,  ...,  0.0118,  0.0039,  0.0353],
#          [ 0.1059,  0.0980,  0.0980,  ...,  0.0431,  0.0588,  0.0667]],
#
#         [[-0.1765, -0.0745, -0.1216,  ..., -0.0275,  0.0196, -0.0039],
#          [-0.0824, -0.0824, -0.1216,  ..., -0.0824, -0.0196, -0.0196],
#          [-0.0196, -0.0588, -0.0667,  ..., -0.1843, -0.1373, -0.0745],
#          ...,
#          [-0.1137, -0.1216, -0.0980,  ..., -0.2863, -0.2784, -0.2471],
#          [-0.0588, -0.0510, -0.0196,  ..., -0.2863, -0.2549, -0.2078],
#          [-0.0196, -0.0431, -0.0667,  ..., -0.2157, -0.1843, -0.1686]]])

# %% [markdown]
# Display Example Images

# %%
def cifar50_imshow(img):
  img = img / 2 + 0.5
  npimg = img.numpy()
  return np.transpose(npimg, (1, 2, 0))

img = features[0].squeeze()
label = labels[0]

fig, axs = plt.subplots(5, 5, figsize = (12, 12))

# loop through subplots and add mnist images
for i, ax in enumerate(axs.flat):
  # Images are (32, 32, 3) uint8
  img = features[i].squeeze()
  label = class_names[labels[i]]
  ax.imshow(cifar50_imshow(img))
  ax.axis('off')
  ax.set_title(f'{label}')

# %% [markdown]
# ## Q2: Train CNNs.
#
# #### Use the CNN in HW2 to train the model on the balanced CIFAR50 dataset.
#
# Train the CNN on the balanced CIFAR50 training set. Evaluate and report the classification accuracies on the testing set.
#
# Note: You can use any network configurations you implemented in HW2.

# %% [markdown]
# # Data Augmentation

# %%
# todo
from torch.utils.data import ConcatDataset

transform1 = transforms.Compose(
    [
        transforms.ConvertImageDtype(torch.float32),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])


# Shifting: randomly shift the images up/down and left/right by within 10%.
transform2 = transforms.Compose(
    [
        transform1,
        transforms.RandomAffine(0, (0.2, 0.2))
    ])

# Rotating: randomly rotate the images by some angles.
transform3 = transforms.Compose(
    [
        transform1,
        transforms.RandomAffine(60)
    ])

# Flipping: horizontally flip the images.
transform4 = transforms.Compose(
    [
        transform1,
        transforms.RandomHorizontalFlip(1.0)
    ])

# Adding Noise: randomly add some small Gaussian noise to the images.
transform5 = transforms.Compose(
    [
        transform1,
        transforms.GaussianBlur(3)
    ]
)

transform_list = [transform1, transform2, transform3, transform4, transform5]
augmented_dataset = []
for t in transform_list:
  augmented_dataset.append(Cifar50_Dataset(train_annotations, transform=t))

cifar_train_dataset = ConcatDataset(augmented_dataset)
cifar50_trainloader = DataLoader(cifar_train_dataset, batch_size=64, shuffle=True)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"There are {len(cifar_train_dataset)} images in the training set.")
print(f"Training device: {device}")
# Out:
# There are 100000 images in the training set.
# Training device: cuda:0

# %% [markdown]
# Visualize Augmented Data

# %%
# Visualize augmented data
fig, axs = plt.subplots(5, 5, figsize = (12, 12))

print(augmented_dataset[0][0][0].size())

# loop through subplots and add images
for i, ax in enumerate(axs.flat):
  ax.imshow(cifar50_imshow(augmented_dataset[int(i/5)][i%5][0]))
  ax.axis('off')
  ax.set_title(f'{class_names[augmented_dataset[int(i/5)][i%5][1]]}')
# Out:
# torch.Size([3, 32, 32])

# %% [markdown]
# Define CNN

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNN1(nn.Module):
  def __init__(self):
    super().__init__()
    # TODO: define your CNN
    self.cv1 = nn.Conv2d(3, 16, 3)
    self.batchnorm1 = nn.BatchNorm2d(16)
    self.cv2 = nn.Conv2d(16, 32, 3)
    self.batchnorm2 = nn.BatchNorm2d(32)
    self.cv3 = nn.Conv2d(32, 64, 3)
    self.batchnorm3 = nn.BatchNorm2d(64)
    self.cv4 = nn.Conv2d(64, 64, 2)
    self.batchnorm4 = nn.BatchNorm2d(64)
    self.cv5 = nn.Conv2d(64, 64, 2)
    self.batchnorm5 = nn.BatchNorm2d(64)

    self.fc1 = nn.Linear(256, 200)
    self.fc2 = nn.Linear(200, 128)
    self.fc3 = nn.Linear(128, 100)
    self.fc4 = nn.Linear(100, 56)
    self.fc5 = nn.Linear(56, 50)

    self.dropout = nn.Dropout(0.3)
  

  def forward(self, x):
    # TODO: define your forward function
    x = F.max_pool2d(F.relu(self.cv1(x)), 2)
    x = self.batchnorm1(x)
    x = F.max_pool2d(F.relu(self.cv2(x)), 2)
    x = self.batchnorm2(x)
    x = F.relu(self.cv3(x))
    x = self.batchnorm3(x)
    x = F.relu(self.cv4(x))
    x = self.batchnorm4(x)
    x = F.relu(self.cv5(x))
    x = self.batchnorm5(x)

    x = x.view(-1, self.num_flat_features(x))
    x = self.dropout(F.relu(self.fc1(x)))
    x = self.dropout(F.relu(self.fc2(x)))
    x = self.dropout(F.relu(self.fc3(x)))
    x = self.dropout(F.relu(self.fc4(x)))
    x = self.fc5(x)

    return x

  def num_flat_features(self, x):
    size = x.size()[1:]
    num_features=1
    for s in size:
      num_features *= s
    return num_features

cnn1 = CNN1().to(device)  # operate on GPU

# %% [markdown]
# Define loss function and optimizer

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn1.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

# %% [markdown]
# Define test and training functions

# %%
def train(cnn, suppress_print=False):
  accumulated_loss = 0.0 # accumulated loss for avg loss calculation
  avg_loss = 0.0 # average loss over all training steps
  passes = 0 # number of passes

  for batch, (X, train_label) in enumerate(cifar50_trainloader):
    dev_images = X.to(device)
    dev_train_labels = train_label.to(device)
    pred = cnn(dev_images)

    loss = criterion(pred, dev_train_labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if batch % 100 == 0 and not suppress_print:
      print(f"Loss: {loss.item()}")

    accumulated_loss += loss.cpu().detach().numpy()
    passes += 1

  avg_loss = accumulated_loss / passes

  return avg_loss

def test(cnn, dataloader):
  total, correct = 0, 0
  accumulated_loss = 0.0
  passes = 0

  with torch.no_grad():
    for batch, (X, label) in enumerate(dataloader):
      dev_images = X.to(device)
      dev_labels = label.to(device)
      pred = cnn(dev_images)
      loss = criterion(pred, dev_labels)

      _, predicted = torch.max(pred.data, 1)

      total += dev_labels.size(0)
      correct += (predicted == dev_labels).sum().item()

      accumulated_loss += loss.cpu().detach().numpy()
      passes += 1

  accuracy = 100*correct/total
  loss = accumulated_loss / passes

  return loss, accuracy

# %% [markdown]
# Train the network

# %%
avg_loss = train(cnn1)

print(f"Average Loss: {avg_loss:.3f}")
# Out:
# Loss: 3.906571626663208
# Loss: 3.680274486541748
# Loss: 3.487281084060669
# Loss: 3.56805419921875
# Loss: 3.474163770675659
# Loss: 3.191136360168457
# Loss: 3.1748528480529785
# Loss: 3.047518730163574
# Loss: 3.265296697616577
# Loss: 3.1092896461486816
# Loss: 3.036414384841919
# Loss: 3.2293646335601807
# Loss: 3.0883922576904297
# Loss: 3.087677001953125
# Loss: 2.8995559215545654
# Loss: 2.8711206912994385
# Average Loss: 3.315

# %% [markdown]
# Test the network

# %%
avg_loss, avg_accuracy = test(cnn1, cifar50_testloader)

print(f"Average Loss: {avg_loss:.3f}")
print(f"Average Accuracy: {avg_accuracy:.3f}%")
# Out:
# Average Loss: 2.998
# Average Accuracy: 19.080%

# %% [markdown]
# Train Epochs

# %%
"""
Training loop
"""
cnn2 = CNN1().to(device)  # operate on GPU
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn2.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

EPOCHS = 15

valid_loss = []
valid_accuracy = []
train_loss = []

for epoch in range(EPOCHS):
  print(f"EPOCH: {epoch+1}")

  cnn2.train(True)
  train_loss.append(train(cnn2, suppress_print=True))

  cnn2.train(False)
  loss, acc = test(cnn2, cifar50_validloader)
  valid_loss.append(loss)
  valid_accuracy.append(acc)

print(f"Validation loss: {valid_loss}")
print(f"Training loss: {train_loss}")
print(f"Validation accuracy: {valid_accuracy}")
# Out:
# EPOCH: 1
# EPOCH: 2
# EPOCH: 3
# EPOCH: 4
# EPOCH: 5
# EPOCH: 6
# EPOCH: 7
# EPOCH: 8
# EPOCH: 9
# EPOCH: 10
# EPOCH: 11
# EPOCH: 12
# EPOCH: 13
# EPOCH: 14
# EPOCH: 15
# Validation loss: [2.8668058097362517, 2.5916833519935607, 2.4610540121793747, 2.386222612857819, 2.274041959643364, 2.252659207582474, 2.224441850185394, 2.1105932533740996, 2.134927347302437, 2.079976800084114, 2.0397269994020464, 2.0142943143844603, 2.040282866358757, 2.0171609610319137, 2.003353440761566]
# Training loss: [3.311668916306889, 2.941209097512624, 2.759828288968526, 2.6277457334563583, 2.531555191035158, 2.4536515267629007, 2.386696647774006, 2.341002909632272, 2.2869295173170316, 2.2566592867223405, 2.227116685911241, 2.1937160883206093, 2.169679718145711, 2.1507780436743396, 2.1337581318460512]
# Training accuracy: [21.6, 28.96, 32.72, 34.28, 37.68, 38.6, 39.12, 41.76, 41.52, 43.16, 43.6, 44.96, 44.84, 44.64, 45.4]

# %% [markdown]
# Plot loss over epochs

# %%
def plot_loss_and_accuracy(train_loss, valid_loss, valid_accuracy):
  fig, axs = plt.subplots(1, 2, figsize=(10,5))

  axs[0].plot(valid_loss, label="Validation Loss")
  axs[0].plot(train_loss, label="Training Loss")
  axs[0].set_title("Validation and Test Loss vs Epochs")
  axs[0].set_xlabel("Epochs")
  axs[0].set_ylabel("Loss")
  axs[0].legend()

  axs[1].plot(valid_accuracy, label="Validation Acc.")
  axs[1].set_title("Validation Accuracy vs Epochs")
  axs[1].set_xlabel("Epochs")
  axs[1].set_ylabel("Accuracy")
  axs[1].legend()

# %%
plot_loss_and_accuracy(train_loss, valid_loss, valid_accuracy)

# %% [markdown]
# Apply model to testing set

# %%
loss, acc = test(cnn2, cifar50_testloader)
print(f"Test accuracy: {acc:.2f}%")
# Out:
# Test accuracy: 46.44%

# %% [markdown]
# #### Use the same CNN above to train the model on the imbalanced CIFAR50 dataset.
#
# Train the CNN on the imbalanced CIFAR50 training set. Evaluate and report the classification accuracies on the testing set.

# %% [markdown]
# Load JSON

# %%
# todo: load json files and print.
import json

print("Training data details:")
fpath = "./data/cifar50_imbalance_0.02/cifar50_imbalance_0.02_train.json"
train_data = load_cifar_set(fpath)

print("\nTesting data details:")
fpath = "./data/cifar50_imbalance_0.02/cifar50_imbalance_0.02_test.json"
test_data = load_cifar_set(fpath)
# Out:
# Training data details:
# <class 'dict'>
# dict_keys(['annotations', 'num_classes'])
# {'fpath': 'data\\cifar50_imbalance_0.02\\images\\apple\\train_0.jpg', 'image_id': 0, 'category_id': 0, 'category': 'apple'}
# {'fpath': 'data\\cifar50_imbalance_0.02\\images\\apple\\train_1.jpg', 'image_id': 1, 'category_id': 0, 'category': 'apple'}
# 50
# There are 6430 images in the set.
#
# Testing data details:
# <class 'dict'>
# dict_keys(['annotations', 'num_classes'])
# {'fpath': 'data\\cifar50_imbalance_0.02\\images\\seal\\test_0.jpg', 'image_id': 0, 'category_id': 72, 'category': 'seal'}
# {'fpath': 'data\\cifar50_imbalance_0.02\\images\\tulip\\test_1.jpg', 'image_id': 1, 'category_id': 92, 'category': 'tulip'}
# 50
# There are 5000 images in the set.

# %% [markdown]
# Prepare data

# %%
# Split testing set into validation and testing sets
random.shuffle(test_data)
validation_set = test_data[:2500]
testing_set = test_data[2500:]

# Augment training data
augmented_dataset = []
for t in transform_list:
  augmented_dataset.append(Cifar50_Dataset(train_data, transform=t))

# Create dataloaders
cifar_train_dataset = ConcatDataset(augmented_dataset)
cifar_valid_dataset = Cifar50_Dataset(validation_set, transform=transform)
cifar_test_dataset = Cifar50_Dataset(testing_set, transform=transform)
cifar50_trainloader = DataLoader(cifar_train_dataset, batch_size=64, shuffle=True)
cifar50_validloader = DataLoader(cifar_valid_dataset, batch_size=64, shuffle=True)
cifar50_testloader = DataLoader(cifar_test_dataset, batch_size=64, shuffle=True)

# Print info about the data size and shape
print(len(cifar_train_dataset), len(cifar_valid_dataset), len(cifar_test_dataset))
features, labels = next(iter(cifar50_trainloader))
print(f"Feature batch shape: {features.size()}")
print(f"Feature batch dtype: {features.dtype}")
print(f"Labels batch shape: {len(labels)}")
print(f"Example image tensor\n{features[0]}")
# Out:
# 32150 2500 2500
# Feature batch shape: torch.Size([64, 3, 32, 32])
# Feature batch dtype: torch.float32
# Labels batch shape: 64
# Example image tensor
# tensor([[[0.7647, 0.7490, 0.8745,  ..., 0.8196, 0.7412, 0.7333],
#          [0.8196, 0.6235, 0.4902,  ..., 0.6392, 0.7647, 0.8902],
#          [0.9216, 0.9059, 0.8039,  ..., 0.9843, 1.0000, 0.9765],
#          ...,
#          [1.0000, 1.0000, 0.9686,  ..., 0.9922, 1.0000, 0.9843],
#          [0.9529, 0.9922, 0.9608,  ..., 1.0000, 0.9922, 0.9765],
#          [0.9765, 0.9451, 0.9922,  ..., 1.0000, 0.9922, 0.9686]],
#
#         [[0.7725, 0.7490, 0.8745,  ..., 0.8275, 0.7412, 0.7176],
#          [0.8353, 0.6392, 0.4980,  ..., 0.6314, 0.7647, 0.8745],
#          [0.9608, 0.9451, 0.8353,  ..., 0.9686, 0.9922, 0.9608],
#          ...,
#          [0.9922, 0.9922, 0.9529,  ..., 1.0000, 1.0000, 0.9843],
#          [0.9686, 0.9922, 0.9765,  ..., 1.0000, 1.0000, 0.9922],
#          [1.0000, 0.9843, 1.0000,  ..., 1.0000, 1.0000, 1.0000]],
#
#         [[0.7333, 0.7333, 0.8902,  ..., 0.8667, 0.7569, 0.7412],
#          [0.8275, 0.6314, 0.5137,  ..., 0.6706, 0.7804, 0.8980],
#          [0.9922, 0.9765, 0.8588,  ..., 1.0000, 1.0000, 0.9686],
#          ...,
#          [0.9843, 0.9843, 0.9765,  ..., 0.9843, 0.9843, 0.9843],
#          [0.9294, 0.9765, 0.9686,  ..., 0.9843, 0.9843, 0.9686],
#          [0.9686, 0.9529, 0.9843,  ..., 1.0000, 0.9686, 0.9608]]])

# %% [markdown]
# Visualize some augmented data

# %%
# Visualize augmented data
fig, axs = plt.subplots(5, 5, figsize = (12, 12))

print(augmented_dataset[0][0][0].size())

# loop through subplots and add images
for i, ax in enumerate(axs.flat):
  ax.imshow(cifar50_imshow(augmented_dataset[int(i/5)][i%5][0]))
  ax.axis('off')
  ax.set_title(f'{class_names[augmented_dataset[int(i/5)][i%5][1]]}')
# Out:
# torch.Size([3, 32, 32])

# %% [markdown]
# Train and test

# %%
"""
Training loop
"""
cnn3 = CNN1().to(device)  # operate on GPU
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn3.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

def train_epochs(cnn, number_of_epochs=1) -> list:
  valid_loss = []
  valid_accuracy = []
  train_loss = []

  for epoch in range(number_of_epochs):
    print(f"EPOCH: {epoch+1}")

    cnn.train(True)
    train_loss.append(train(cnn, suppress_print=True))

    cnn.train(False)
    loss, acc = test(cnn, cifar50_validloader)
    valid_loss.append(loss)
    valid_accuracy.append(acc)

  return train_loss, valid_loss, valid_accuracy

train_loss, valid_loss, valid_accuracy = train_epochs(cnn3, 15)

print(f"Validation loss: {valid_loss}")
print(f"Training loss: {train_loss}")
print(f"Validation accuracy: {valid_accuracy}")
# Out:
# EPOCH: 1
# EPOCH: 2
# EPOCH: 3
# EPOCH: 4
# EPOCH: 5
# EPOCH: 6
# EPOCH: 7
# EPOCH: 8
# EPOCH: 9
# EPOCH: 10
# EPOCH: 11
# EPOCH: 12
# EPOCH: 13
# EPOCH: 14
# EPOCH: 15
# Validation loss: [3.890994703769684, 3.7328952670097353, 3.6708414912223817, 3.521867710351944, 3.5215343475341796, 3.472111815214157, 3.486863148212433, 3.4188153058290482, 3.4523437321186066, 3.3527851164340974, 3.517610949277878, 3.4653733253479, 3.391483759880066, 3.3972854614257812, 3.2729989141225815]
# Training loss: [3.1491486092448, 2.783746769603631, 2.6107412114532047, 2.4825263459450206, 2.3636590249495764, 2.2619499416047963, 2.1794407891468786, 2.1168086640166477, 2.0520051070757463, 1.9979855424130175, 1.9443994405018405, 1.895258410550491, 1.8549252243686623, 1.8171934078986318, 1.7708663272099276]
# Validation accuracy: [10.32, 13.36, 16.96, 19.04, 19.6, 20.8, 21.84, 21.08, 23.08, 24.56, 24.48, 25.24, 25.64, 25.56, 27.08]

# %% [markdown]
# Plot results

# %%
plot_loss_and_accuracy(train_loss, valid_loss, valid_accuracy)

# %%
# Test accuracy
loss, acc = test(cnn3, cifar50_testloader)

print(f"Test accuracy: {acc:.2f}")
# Out:
# Test accuracy: 27.28

# %% [markdown]
# ## Implement Tricks for LTR
#
# Before starting this question, please read the paper on Canvas: Bag of tricks for long-tailed visual recognition with deep convolutional neural networks.
#
# According to this paper, select at least **three** tricks to implement on the imbalanced CIFAR50 training.

# %% [markdown]
# Trick 1 - Deferred re-balancing by re-weighting, cost-sensitive cross entropy loss

# %%
# DRW CS_CE - Calculate class weights
print(cifar_train_dataset[0][1])

weights = torch.zeros(50)
category_counts = []

category_ids = [annotation[1] for annotation in cifar_train_dataset]

for class_idx, weight in enumerate(weights):
  category_counts.append(len([id for id in category_ids if class_idx == id]))

min_class_size = min(category_counts)

print(min_class_size)
print(category_counts)
weights = torch.FloatTensor([min_class_size / category_count for category_count in category_counts])
print(weights)
# Out:
# 0
# 50
# [2500, 80, 70, 825, 55, 95, 1820, 105, 130, 155, 90, 195, 320, 475, 1045, 965, 110, 270, 120, 1435, 1970, 1130, 50, 600, 145, 65, 345, 1225, 405, 555, 180, 2130, 60, 170, 650, 705, 75, 760, 215, 510, 890, 375, 295, 435, 1555, 2310, 1680, 230, 250, 1325]
# tensor([0.0200, 0.6250, 0.7143, 0.0606, 0.9091, 0.5263, 0.0275, 0.4762, 0.3846,
#         0.3226, 0.5556, 0.2564, 0.1562, 0.1053, 0.0478, 0.0518, 0.4545, 0.1852,
#         0.4167, 0.0348, 0.0254, 0.0442, 1.0000, 0.0833, 0.3448, 0.7692, 0.1449,
#         0.0408, 0.1235, 0.0901, 0.2778, 0.0235, 0.8333, 0.2941, 0.0769, 0.0709,
#         0.6667, 0.0658, 0.2326, 0.0980, 0.0562, 0.1333, 0.1695, 0.1149, 0.0322,
#         0.0216, 0.0298, 0.2174, 0.2000, 0.0377])

# %%
cnn4 = CNN1().to(device)  # operate on GPU
criterion = nn.CrossEntropyLoss(weight=weights)
optimizer = optim.Adam(cnn4.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

# %%
def train_cs_ce(cnn, dataloader, suppress_print=False):
  """
  Train with class-sensitive cross entropy loss
  """

  accumulated_loss = 0.0 # accumulated loss for avg loss calculation
  avg_loss = 0.0 # average loss over all training steps
  passes = 0 # number of passes

  for batch, (X, train_label) in enumerate(dataloader):
    dev_images = X.to(device)
    dev_train_labels = train_label.to(device)
    pred = cnn(dev_images)

    loss = criterion(pred, dev_train_labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if batch % 100 == 0 and not suppress_print:
      print(f"Loss: {loss.item()}")

    accumulated_loss += loss.cpu().detach().numpy()
    passes += 1

  avg_loss = accumulated_loss / passes

  return avg_loss

# %%
"""
Training loop
"""

def train_epochs(cnn, number_of_epochs=1) -> list:
  valid_loss = []
  valid_accuracy = []
  train_loss = []

  for epoch in range(number_of_epochs):
    print(f"EPOCH: {epoch+1}")

    cnn.train(True)
    train_loss.append(train_cs_ce(cnn, cifar50_trainloader, suppress_print=True))

    cnn.train(False)
    loss, acc = test(cnn, cifar50_validloader)
    valid_loss.append(loss)
    valid_accuracy.append(acc)

  return train_loss, valid_loss, valid_accuracy

train_loss, valid_loss, valid_accuracy = train_epochs(cnn4, 15)

print(f"Validation loss: {valid_loss}")
print(f"Training loss: {train_loss}")
print(f"Validation accuracy: {valid_accuracy}")
# Out:
# EPOCH: 1
# EPOCH: 2
# EPOCH: 3
# EPOCH: 4
# EPOCH: 5
# EPOCH: 6
# EPOCH: 7
# EPOCH: 8
# EPOCH: 9
# EPOCH: 10
# EPOCH: 11
# EPOCH: 12
# EPOCH: 13
# EPOCH: 14
# EPOCH: 15
# Validation loss: [2.4238418340682983, 2.3787734657526016, 2.2553758442401888, 2.2150293081998824, 2.323913726210594, 2.1051238805055617, 2.1019887775182724, 2.066529980301857, 2.038404279947281, 2.090451490879059, 2.037244662642479, 2.105600556731224, 1.958125102519989, 2.010767126083374, 2.210860076546669]
# Training loss: [2.7562001711263444, 2.557814000513607, 2.428261650636935, 2.327701411308191, 2.229939158732137, 2.178225436149695, 2.117514093082172, 2.0349262781417408, 1.97550348732799, 1.9455832532419564, 1.868507523125353, 1.810045804459447, 1.7864527591882042, 1.7301891695577116, 1.6924300416589926]
# Training accuracy: [14.72, 14.88, 16.56, 16.72, 17.04, 18.44, 19.84, 19.56, 21.36, 21.72, 21.92, 22.16, 23.24, 22.68, 22.32]

# %%
plot_loss_and_accuracy(train_loss, valid_loss, valid_accuracy)

# %%
# Test accuracy
loss, acc = test(cnn4, cifar50_testloader)

print(f"Test accuracy: {acc:.2f}")
# Out:
# Test accuracy: 21.24

# %% [markdown]
# Trick 2 - Deferred rebalancing by resampling

# %%
from torch.utils.data.sampler import WeightedRandomSampler
import torch

# probability of any one sample = (1/# of classes)(1/# of samples in class)

samples = [annotation[0] for annotation in cifar_train_dataset]
targets = [annotation[1] for annotation in cifar_train_dataset]

weights = [(1/50)*(1/category_counts[target]) for target in targets]

print(len(weights))

print(len(samples), len(targets))
# Out:
# 32150
# 32150 32150

# %%
print(sum(weights))

sampler = WeightedRandomSampler(weights, len(weights))

cifar50_trainloader = DataLoader(cifar_train_dataset, batch_size=64, sampler=sampler)
# Out:
# 1.000000000000014

# %%
cnn5 = CNN1().to(device)  # operate on GPU
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn5.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

# %%
"""
Training loop
"""

def train_epochs(cnn, number_of_epochs=1) -> list:
  valid_loss = []
  valid_accuracy = []
  train_loss = []

  for epoch in range(number_of_epochs):
    print(f"EPOCH: {epoch+1}")

    cnn.train(True)
    train_loss.append(train(cnn, suppress_print=True))

    cnn.train(False)
    loss, acc = test(cnn, cifar50_validloader)
    valid_loss.append(loss)
    valid_accuracy.append(acc)

  return train_loss, valid_loss, valid_accuracy

train_loss, valid_loss, valid_accuracy = train_epochs(cnn5, 15)

print(f"Validation loss: {valid_loss}")
print(f"Training loss: {train_loss}")
print(f"Validation accuracy: {valid_accuracy}")
# Out:
# EPOCH: 1
# EPOCH: 2
# EPOCH: 3
# EPOCH: 4
# EPOCH: 5
# EPOCH: 6
# EPOCH: 7
# EPOCH: 8
# EPOCH: 9
# EPOCH: 10
# EPOCH: 11
# EPOCH: 12
# EPOCH: 13
# EPOCH: 14
# EPOCH: 15
# Validation loss: [3.1774423599243162, 3.104245752096176, 3.1430574476718904, 3.1626265823841093, 3.1860530406236647, 3.155971872806549, 3.270059198141098, 3.303467535972595, 3.4249262690544127, 3.506323146820068, 3.459036707878113, 3.4093912303447724, 3.3709110498428343, 3.416180354356766, 3.385328769683838]
# Training loss: [3.4331621109372814, 2.9927693498774506, 2.7538354534278096, 2.5351262315367133, 2.3432313180111985, 2.2121206593086895, 2.122821531523293, 2.034977215184843, 1.954462808595737, 1.9083283750958755, 1.8392794110902972, 1.813343584893001, 1.7776998658303476, 1.7477015344570455, 1.6897857132299283]
# Validation accuracy: [14.44, 19.24, 19.68, 22.32, 22.96, 23.36, 23.32, 24.44, 24.36, 24.52, 25.28, 26.08, 25.96, 26.36, 26.48]

# %%
plot_loss_and_accuracy(train_loss, valid_loss, valid_accuracy)

# %%
# Test accuracy
loss, acc = test(cnn5, cifar50_testloader)

print(f"Test accuracy: {acc:.2f}")
# Out:
# Test accuracy: 27.04

# %% [markdown]
# Trick 3 - Input Mixing

# %%
class Cifar50_Dataset_Mixup(Dataset):
  """Defines a custom Pytorch dataset as outlined by the Pytorch tutorial
  at https://pytorch.org/tutorials/beginner/basics/data_tutorial.html

  With Input Mixup added - implementation credit to Ta-Ying Cheng "Enhancing Neural Networks with Mixup in PyTorch"
  https://towardsdatascience.com/enhancing-neural-networks-with-mixup-in-pytorch-5129d261bc4a 
  """
  def __init__(self, annotations: dict, transform=None, target_transform=None):
    self.annotations = annotations
    self.image_dir = '.'
    self.transform = transform
    self.target_transform = target_transform

  def __len__(self):
    return len(self.annotations)

  def __getitem__(self, idx):
    img_path = os.path.join(self.image_dir, self.annotations[idx]['fpath'].replace('\\', '/'))
    image = read_image(img_path)
    label_idx = class_names.index(self.annotations[idx]['category'])

    # Mixup requires label as a vector
    label = torch.zeros(50)
    label[label_idx] = 1.

    if self.transform:
      image = self.transform(image)
    if self.target_transform:
      label = self.target_transform(label)

    # Perform mixup on every 5th sample
    if idx % 5 == 0:
      mixup_idx = random.randint(0, len(self.annotations)-1)
      mixup_label_idx = class_names.index(self.annotations[mixup_idx]['category'])
      # Mixup requires label as a vector
      mixup_label = torch.zeros(50)
      mixup_label[mixup_label_idx] = 1.
      mixup_img_path = os.path.join(self.image_dir, self.annotations[mixup_idx]['fpath'].replace('\\', '/'))
      mixup_img = read_image(mixup_img_path)

      if self.transform:
        mixup_img = self.transform(mixup_img)

      # Apply mixup formula
      alpha = 0.2
      lam = np.random.beta(alpha, alpha)
      image = lam * image + (1 - lam) * mixup_img
      label = lam * label + (1 - lam) * mixup_label

    return image, label


# Input mixup by adding another set to the augmented data
transform_list = [transform1, transform2, transform3, transform4, transform5]
augmented_dataset = []
for t in transform_list:
  augmented_dataset.append(Cifar50_Dataset_Mixup(train_data, transform=t))

cifar_train_dataset = ConcatDataset(augmented_dataset)
cifar50_trainloader = DataLoader(cifar_train_dataset, batch_size=64, shuffle=True)

print(f"There are {len(cifar_train_dataset)} images in the training set.")
# Out:
# There are 32150 images in the training set.

# %%
cnn6 = CNN1().to(device)  # operate on GPU
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(cnn6.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

# %%
train_loss, valid_loss, valid_accuracy = train_epochs(cnn6, 15)

print(f"Validation loss: {valid_loss}")
print(f"Training loss: {train_loss}")
print(f"Validation accuracy: {valid_accuracy}")
# Out:
# EPOCH: 1
# EPOCH: 2
# EPOCH: 3
# EPOCH: 4
# EPOCH: 5
# EPOCH: 6
# EPOCH: 7
# EPOCH: 8
# EPOCH: 9
# EPOCH: 10
# EPOCH: 11
# EPOCH: 12
# EPOCH: 13
# EPOCH: 14
# EPOCH: 15
# Validation loss: [3.985571378469467, 3.7803162217140196, 3.691430228948593, 3.509197562932968, 3.5381737768650057, 3.420160734653473, 3.406078165769577, 3.4482760310173033, 3.3339059114456178, 3.3498363733291625, 3.3796468555927275, 3.333812081813812, 3.3236318469047545, 3.2649973034858704, 3.308069610595703]
# Training loss: [3.146222418866622, 2.8197549654996656, 2.644497510690101, 2.5144858289191547, 2.4102747397678748, 2.321814865762623, 2.2120335590294293, 2.1737795684257035, 2.1084941701434006, 2.0517528929245876, 1.9949127821988661, 1.9599749103455135, 1.906148931852155, 1.8831278976815833, 1.8497485021947628]
# Validation accuracy: [9.0, 12.88, 15.08, 16.8, 18.36, 20.0, 21.84, 21.4, 23.76, 24.4, 23.84, 24.92, 26.68, 26.88, 26.24]

# %%
plot_loss_and_accuracy(train_loss, valid_loss, valid_accuracy)

# %%
# Test accuracy
loss, acc = test(cnn6, cifar50_testloader)

print(f"Test accuracy: {acc:.2f}")
# Out:
# Test accuracy: 27.00

# %% [markdown]
# Paste performance above to this table
#
# |          | Baseline | Trick1 |Trick2| Trick|
# |----------|:-----:|:-----------:|:-----------:|:-----------:|
# | Test Accuracy (%) |27.28|21.24|27.04|27.00|

# %% [markdown]
# # Problem 2: Transfer Learning and Domain Adaptation

# %% [markdown]
# The goal of domain adaptation is to transfer the knowledge of a model to a different but related data distribution. The model is trained on a source dataset and applied to a target dataset (usually unlabeled). For Problem 3, the model will be trained on regular MNIST images, but we want to get good performance on MNIST with random color (without any labels).

# %% [markdown]
# **Problem Statement** Given a labelled source domain (MNIST) and an unlabelled target domain (MNIST-M). We would like to train a classifier or a predictor which would give accurate predictions on the target domain.
#
# **Assumptions** Probability distribution of source domain is not equal to the probability distribution of target domain. The conditional probability distribution of the labels given an instance from the source domain is equal to the conditional probability distribution of the labels given an instance from the target domain. Source dataset is labelled. Target dataset is unlabelled.
#
# **Approach** Here, we adopt the DABP method mentioned in the paper “Unsupervised Domain Adaptation by Backpropagation”.
#
# * Feature Extractor (green): This is a neural network that will learn to perform the transformation on the source and target distribution.
# * Label Classifier (blue): This is a neural network that will learn to perform the classification on the transformed source distribution. Since, the source domain is labelled.
# * Domain Classifier (red): This is a neural network that will predict whether the output of the Feature Extractor is from the source distribution or the target distribution.

# %% [markdown]
# By using the above three components, the Feature Extractor will learn to produce discriminative and domain-invariant features.

# %%
# download the codes from Git
# !git clone https://github.com/Haotian-Zhang/Pytorch_DABP.git
# Out:
# Cloning into 'Pytorch_DABP'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 34 (delta 12), reused 22 (delta 7), pack-reused 0
# Unpacking objects: 100% (34/34), done.

# %% [markdown]
# Train the DABP model by running `main.py` and answer the following questions.

# %%
# %cd ../Pytorch_DABP
# %pwd
# Out:
# c:\Users\jaido\source\Pytorch_DABP
# 'c:\\Users\\jaido\\source\\Pytorch_DABP'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import importlib
importlib.reload(main)
import main

print(main.save_name)

main.main()
# Out:
# first_run
# Running GPU : 0
# Source-only training
# Epoch : 0
# c:\Users\jaido\source\Pytorch_DABP\model.py:38: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# [1568/60000 (3%)]	Class Loss: 2.302680
# [3168/60000 (6%)]	Class Loss: 2.300898
# [4768/60000 (9%)]	Class Loss: 2.295592
# [6368/60000 (12%)]	Class Loss: 2.293720
# [7968/60000 (14%)]	Class Loss: 2.276191
# [9568/60000 (17%)]	Class Loss: 2.118767
# [11168/60000 (20%)]	Class Loss: 2.175305
# [12768/60000 (23%)]	Class Loss: 1.806384
# [14368/60000 (26%)]	Class Loss: 1.703221
# [15968/60000 (29%)]	Class Loss: 1.640110
# [17568/60000 (32%)]	Class Loss: 1.541000
# [19168/60000 (35%)]	Class Loss: 1.593842
# [20768/60000 (38%)]	Class Loss: 1.583765
# [22368/60000 (41%)]	Class Loss: 1.530124
# [23968/60000 (44%)]	Class Loss: 1.670804
# [25568/60000 (46%)]	Class Loss: 1.726074
# [27168/60000 (49%)]	Class Loss: 1.676134
# [28768/60000 (52%)]	Class Loss: 1.505171
# [30368/60000 (55%)]	Class Loss: 1.522153
# [31968/60000 (58%)]	Class Loss: 1.517901
# [33568/60000 (61%)]	Class Loss: 1.505684
# [35168/60000 (64%)]	Class Loss: 1.470978
# [36768/60000 (67%)]	Class Loss: 1.485664
# [38368/60000 (70%)]	Class Loss: 1.527517
# [39968/60000 (73%)]	Class Loss: 1.473820
# [41568/60000 (76%)]	Class Loss: 1.509313
# [43168/60000 (78%)]	Class Loss: 1.549203
# [44768/60000 (81%)]	Class Loss: 1.462518
# [46368/60000 (84%)]	Class Loss: 1.491811
# [47968/60000 (87%)]	Class Loss: 1.540260
# [49568/60000 (90%)]	Class Loss: 1.501848
# [51168/60000 (93%)]	Class Loss: 1.512375
# [52768/60000 (96%)]	Class Loss: 1.461312
# [54368/60000 (99%)]	Class Loss: 1.461186
# Epoch : 1
# [1568/60000 (3%)]	Class Loss: 1.523642
# [3168/60000 (6%)]	Class Loss: 1.501212
# [4768/60000 (9%)]	Class Loss: 1.518942
# [6368/60000 (12%)]	Class Loss: 1.461306
# [7968/60000 (14%)]	Class Loss: 1.492210
# [9568/60000 (17%)]	Class Loss: 1.516846
# [11168/60000 (20%)]	Class Loss: 1.493145
# [12768/60000 (23%)]	Class Loss: 1.495528
# [14368/60000 (26%)]	Class Loss: 1.468628
# [15968/60000 (29%)]	Class Loss: 1.494925
# [17568/60000 (32%)]	Class Loss: 1.467860
# [19168/60000 (35%)]	Class Loss: 1.550152
# [20768/60000 (38%)]	Class Loss: 1.463000
# [22368/60000 (41%)]	Class Loss: 1.552900
# [23968/60000 (44%)]	Class Loss: 1.487832
# [25568/60000 (46%)]	Class Loss: 1.481062
# [27168/60000 (49%)]	Class Loss: 1.487446
# [28768/60000 (52%)]	Class Loss: 1.466080
# [30368/60000 (55%)]	Class Loss: 1.486833
# [31968/60000 (58%)]	Class Loss: 1.461286
# [33568/60000 (61%)]	Class Loss: 1.461277
# [35168/60000 (64%)]	Class Loss: 1.463541
# [36768/60000 (67%)]	Class Loss: 1.487521
# [38368/60000 (70%)]	Class Loss: 1.498757
# [39968/60000 (73%)]	Class Loss: 1.461221
# [41568/60000 (76%)]	Class Loss: 1.498137
# [43168/60000 (78%)]	Class Loss: 1.491661
# [44768/60000 (81%)]	Class Loss: 1.465329
# [46368/60000 (84%)]	Class Loss: 1.464335
# [47968/60000 (87%)]	Class Loss: 1.463913
# [49568/60000 (90%)]	Class Loss: 1.480465
# [51168/60000 (93%)]	Class Loss: 1.522220
# [52768/60000 (96%)]	Class Loss: 1.479205
# [54368/60000 (99%)]	Class Loss: 1.492450
# Epoch : 2
# [1568/60000 (3%)]	Class Loss: 1.491548
# [3168/60000 (6%)]	Class Loss: 1.503372
# [4768/60000 (9%)]	Class Loss: 1.484668
# [6368/60000 (12%)]	Class Loss: 1.520424
# [7968/60000 (14%)]	Class Loss: 1.492716
# [9568/60000 (17%)]	Class Loss: 1.461198
# [11168/60000 (20%)]	Class Loss: 1.489406
# [12768/60000 (23%)]	Class Loss: 1.477357
# [14368/60000 (26%)]	Class Loss: 1.474160
# [15968/60000 (29%)]	Class Loss: 1.506289
# [17568/60000 (32%)]	Class Loss: 1.492728
# [19168/60000 (35%)]	Class Loss: 1.472238
# [20768/60000 (38%)]	Class Loss: 1.491159
# [22368/60000 (41%)]	Class Loss: 1.492343
# [23968/60000 (44%)]	Class Loss: 1.488775
# [25568/60000 (46%)]	Class Loss: 1.485300
# [27168/60000 (49%)]	Class Loss: 1.465806
# [28768/60000 (52%)]	Class Loss: 1.485742
# [30368/60000 (55%)]	Class Loss: 1.463349
# [31968/60000 (58%)]	Class Loss: 1.461166
# [33568/60000 (61%)]	Class Loss: 1.461226
# [35168/60000 (64%)]	Class Loss: 1.493134
# [36768/60000 (67%)]	Class Loss: 1.461245
# [38368/60000 (70%)]	Class Loss: 1.522729
# [39968/60000 (73%)]	Class Loss: 1.462226
# [41568/60000 (76%)]	Class Loss: 1.461164
# [43168/60000 (78%)]	Class Loss: 1.461701
# [44768/60000 (81%)]	Class Loss: 1.461163
# [46368/60000 (84%)]	Class Loss: 1.481945
# [47968/60000 (87%)]	Class Loss: 1.528207
# [49568/60000 (90%)]	Class Loss: 1.492296
# [51168/60000 (93%)]	Class Loss: 1.462069
# [52768/60000 (96%)]	Class Loss: 1.461218
# [54368/60000 (99%)]	Class Loss: 1.461158
# Epoch : 3
# [1568/60000 (3%)]	Class Loss: 1.464848
# [3168/60000 (6%)]	Class Loss: 1.492738
# [4768/60000 (9%)]	Class Loss: 1.507932
# [6368/60000 (12%)]	Class Loss: 1.461170
# [7968/60000 (14%)]	Class Loss: 1.473078
# [9568/60000 (17%)]	Class Loss: 1.544157
# [11168/60000 (20%)]	Class Loss: 1.494561
# [12768/60000 (23%)]	Class Loss: 1.461309
# [14368/60000 (26%)]	Class Loss: 1.461172
# [15968/60000 (29%)]	Class Loss: 1.467735
# [17568/60000 (32%)]	Class Loss: 1.502680
# [19168/60000 (35%)]	Class Loss: 1.474373
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461836
# [23968/60000 (44%)]	Class Loss: 1.461349
# [25568/60000 (46%)]	Class Loss: 1.530883
# [27168/60000 (49%)]	Class Loss: 1.461154
# [28768/60000 (52%)]	Class Loss: 1.461273
# [30368/60000 (55%)]	Class Loss: 1.501094
# [31968/60000 (58%)]	Class Loss: 1.490873
# [33568/60000 (61%)]	Class Loss: 1.461152
# [35168/60000 (64%)]	Class Loss: 1.492374
# [36768/60000 (67%)]	Class Loss: 1.490851
# [38368/60000 (70%)]	Class Loss: 1.461164
# [39968/60000 (73%)]	Class Loss: 1.505946
# [41568/60000 (76%)]	Class Loss: 1.461211
# [43168/60000 (78%)]	Class Loss: 1.463206
# [44768/60000 (81%)]	Class Loss: 1.524752
# [46368/60000 (84%)]	Class Loss: 1.523442
# [47968/60000 (87%)]	Class Loss: 1.464179
# [49568/60000 (90%)]	Class Loss: 1.462646
# [51168/60000 (93%)]	Class Loss: 1.501675
# [52768/60000 (96%)]	Class Loss: 1.461246
# [54368/60000 (99%)]	Class Loss: 1.522827
# Epoch : 4
# [1568/60000 (3%)]	Class Loss: 1.461162
# [3168/60000 (6%)]	Class Loss: 1.504461
# [4768/60000 (9%)]	Class Loss: 1.462622
# [6368/60000 (12%)]	Class Loss: 1.553430
# [7968/60000 (14%)]	Class Loss: 1.482898
# [9568/60000 (17%)]	Class Loss: 1.497257
# [11168/60000 (20%)]	Class Loss: 1.461179
# [12768/60000 (23%)]	Class Loss: 1.461638
# [14368/60000 (26%)]	Class Loss: 1.465119
# [15968/60000 (29%)]	Class Loss: 1.464853
# [17568/60000 (32%)]	Class Loss: 1.461345
# [19168/60000 (35%)]	Class Loss: 1.466443
# [20768/60000 (38%)]	Class Loss: 1.461218
# [22368/60000 (41%)]	Class Loss: 1.461781
# [23968/60000 (44%)]	Class Loss: 1.461153
# [25568/60000 (46%)]	Class Loss: 1.462684
# [27168/60000 (49%)]	Class Loss: 1.461435
# [28768/60000 (52%)]	Class Loss: 1.461205
# [30368/60000 (55%)]	Class Loss: 1.461154
# [31968/60000 (58%)]	Class Loss: 1.461223
# [33568/60000 (61%)]	Class Loss: 1.503268
# [35168/60000 (64%)]	Class Loss: 1.468869
# [36768/60000 (67%)]	Class Loss: 1.461176
# [38368/60000 (70%)]	Class Loss: 1.486553
# [39968/60000 (73%)]	Class Loss: 1.479258
# [41568/60000 (76%)]	Class Loss: 1.461160
# [43168/60000 (78%)]	Class Loss: 1.461323
# [44768/60000 (81%)]	Class Loss: 1.465383
# [46368/60000 (84%)]	Class Loss: 1.461154
# [47968/60000 (87%)]	Class Loss: 1.468658
# [49568/60000 (90%)]	Class Loss: 1.461676
# [51168/60000 (93%)]	Class Loss: 1.461351
# [52768/60000 (96%)]	Class Loss: 1.467300
# [54368/60000 (99%)]	Class Loss: 1.493820
# Epoch : 5
# [1568/60000 (3%)]	Class Loss: 1.462156
# [3168/60000 (6%)]	Class Loss: 1.461538
# [4768/60000 (9%)]	Class Loss: 1.465427
# [6368/60000 (12%)]	Class Loss: 1.520750
# [7968/60000 (14%)]	Class Loss: 1.461170
# [9568/60000 (17%)]	Class Loss: 1.512755
# [11168/60000 (20%)]	Class Loss: 1.462341
# [12768/60000 (23%)]	Class Loss: 1.473877
# [14368/60000 (26%)]	Class Loss: 1.492399
# [15968/60000 (29%)]	Class Loss: 1.461179
# [17568/60000 (32%)]	Class Loss: 1.461182
# [19168/60000 (35%)]	Class Loss: 1.461381
# [20768/60000 (38%)]	Class Loss: 1.492456
# [22368/60000 (41%)]	Class Loss: 1.461155
# [23968/60000 (44%)]	Class Loss: 1.461952
# [25568/60000 (46%)]	Class Loss: 1.492512
# [27168/60000 (49%)]	Class Loss: 1.465748
# [28768/60000 (52%)]	Class Loss: 1.462716
# [30368/60000 (55%)]	Class Loss: 1.476139
# [31968/60000 (58%)]	Class Loss: 1.461450
# [33568/60000 (61%)]	Class Loss: 1.461152
# [35168/60000 (64%)]	Class Loss: 1.477376
# [36768/60000 (67%)]	Class Loss: 1.461153
# [38368/60000 (70%)]	Class Loss: 1.463736
# [39968/60000 (73%)]	Class Loss: 1.465084
# [41568/60000 (76%)]	Class Loss: 1.461274
# [43168/60000 (78%)]	Class Loss: 1.484988
# [44768/60000 (81%)]	Class Loss: 1.518799
# [46368/60000 (84%)]	Class Loss: 1.461161
# [47968/60000 (87%)]	Class Loss: 1.461199
# [49568/60000 (90%)]	Class Loss: 1.463415
# [51168/60000 (93%)]	Class Loss: 1.466579
# [52768/60000 (96%)]	Class Loss: 1.461272
# [54368/60000 (99%)]	Class Loss: 1.461155
# Epoch : 6
# [1568/60000 (3%)]	Class Loss: 1.463487
# [3168/60000 (6%)]	Class Loss: 1.464325
# [4768/60000 (9%)]	Class Loss: 1.461402
# [6368/60000 (12%)]	Class Loss: 1.492416
# [7968/60000 (14%)]	Class Loss: 1.461301
# [9568/60000 (17%)]	Class Loss: 1.461278
# [11168/60000 (20%)]	Class Loss: 1.461173
# [12768/60000 (23%)]	Class Loss: 1.482354
# [14368/60000 (26%)]	Class Loss: 1.461198
# [15968/60000 (29%)]	Class Loss: 1.469995
# [17568/60000 (32%)]	Class Loss: 1.476158
# [19168/60000 (35%)]	Class Loss: 1.461311
# [20768/60000 (38%)]	Class Loss: 1.490611
# [22368/60000 (41%)]	Class Loss: 1.461153
# [23968/60000 (44%)]	Class Loss: 1.492411
# [25568/60000 (46%)]	Class Loss: 1.492401
# [27168/60000 (49%)]	Class Loss: 1.461982
# [28768/60000 (52%)]	Class Loss: 1.461170
# [30368/60000 (55%)]	Class Loss: 1.490237
# [31968/60000 (58%)]	Class Loss: 1.486504
# [33568/60000 (61%)]	Class Loss: 1.490443
# [35168/60000 (64%)]	Class Loss: 1.461168
# [36768/60000 (67%)]	Class Loss: 1.461157
# [38368/60000 (70%)]	Class Loss: 1.461152
# [39968/60000 (73%)]	Class Loss: 1.461170
# [41568/60000 (76%)]	Class Loss: 1.461215
# [43168/60000 (78%)]	Class Loss: 1.507243
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461719
# [47968/60000 (87%)]	Class Loss: 1.461183
# [49568/60000 (90%)]	Class Loss: 1.470882
# [51168/60000 (93%)]	Class Loss: 1.463774
# [52768/60000 (96%)]	Class Loss: 1.461152
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 7
# [1568/60000 (3%)]	Class Loss: 1.461214
# [3168/60000 (6%)]	Class Loss: 1.461214
# [4768/60000 (9%)]	Class Loss: 1.461159
# [6368/60000 (12%)]	Class Loss: 1.461414
# [7968/60000 (14%)]	Class Loss: 1.461329
# [9568/60000 (17%)]	Class Loss: 1.461156
# [11168/60000 (20%)]	Class Loss: 1.461235
# [12768/60000 (23%)]	Class Loss: 1.461208
# [14368/60000 (26%)]	Class Loss: 1.461187
# [15968/60000 (29%)]	Class Loss: 1.491303
# [17568/60000 (32%)]	Class Loss: 1.462051
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.491995
# [22368/60000 (41%)]	Class Loss: 1.461155
# [23968/60000 (44%)]	Class Loss: 1.492530
# [25568/60000 (46%)]	Class Loss: 1.461411
# [27168/60000 (49%)]	Class Loss: 1.461914
# [28768/60000 (52%)]	Class Loss: 1.466978
# [30368/60000 (55%)]	Class Loss: 1.461231
# [31968/60000 (58%)]	Class Loss: 1.461923
# [33568/60000 (61%)]	Class Loss: 1.464835
# [35168/60000 (64%)]	Class Loss: 1.461215
# [36768/60000 (67%)]	Class Loss: 1.461160
# [38368/60000 (70%)]	Class Loss: 1.461974
# [39968/60000 (73%)]	Class Loss: 1.462539
# [41568/60000 (76%)]	Class Loss: 1.461152
# [43168/60000 (78%)]	Class Loss: 1.461289
# [44768/60000 (81%)]	Class Loss: 1.461918
# [46368/60000 (84%)]	Class Loss: 1.464457
# [47968/60000 (87%)]	Class Loss: 1.464407
# [49568/60000 (90%)]	Class Loss: 1.461153
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461161
# [54368/60000 (99%)]	Class Loss: 1.461190
# Epoch : 8
# [1568/60000 (3%)]	Class Loss: 1.470277
# [3168/60000 (6%)]	Class Loss: 1.461350
# [4768/60000 (9%)]	Class Loss: 1.461152
# [6368/60000 (12%)]	Class Loss: 1.461157
# [7968/60000 (14%)]	Class Loss: 1.490640
# [9568/60000 (17%)]	Class Loss: 1.461196
# [11168/60000 (20%)]	Class Loss: 1.481573
# [12768/60000 (23%)]	Class Loss: 1.461153
# [14368/60000 (26%)]	Class Loss: 1.461152
# [15968/60000 (29%)]	Class Loss: 1.462694
# [17568/60000 (32%)]	Class Loss: 1.461195
# [19168/60000 (35%)]	Class Loss: 1.461608
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461156
# [23968/60000 (44%)]	Class Loss: 1.461156
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.484357
# [30368/60000 (55%)]	Class Loss: 1.461203
# [31968/60000 (58%)]	Class Loss: 1.461161
# [33568/60000 (61%)]	Class Loss: 1.492402
# [35168/60000 (64%)]	Class Loss: 1.478378
# [36768/60000 (67%)]	Class Loss: 1.461152
# [38368/60000 (70%)]	Class Loss: 1.490720
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.493745
# [44768/60000 (81%)]	Class Loss: 1.492402
# [46368/60000 (84%)]	Class Loss: 1.485688
# [47968/60000 (87%)]	Class Loss: 1.461160
# [49568/60000 (90%)]	Class Loss: 1.495778
# [51168/60000 (93%)]	Class Loss: 1.461668
# [52768/60000 (96%)]	Class Loss: 1.492581
# [54368/60000 (99%)]	Class Loss: 1.461159
# Epoch : 9
# [1568/60000 (3%)]	Class Loss: 1.461353
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.490651
# [6368/60000 (12%)]	Class Loss: 1.462392
# [7968/60000 (14%)]	Class Loss: 1.461249
# [9568/60000 (17%)]	Class Loss: 1.468810
# [11168/60000 (20%)]	Class Loss: 1.461157
# [12768/60000 (23%)]	Class Loss: 1.464493
# [14368/60000 (26%)]	Class Loss: 1.508704
# [15968/60000 (29%)]	Class Loss: 1.491907
# [17568/60000 (32%)]	Class Loss: 1.492252
# [19168/60000 (35%)]	Class Loss: 1.461379
# [20768/60000 (38%)]	Class Loss: 1.492757
# [22368/60000 (41%)]	Class Loss: 1.461229
# [23968/60000 (44%)]	Class Loss: 1.461480
# [25568/60000 (46%)]	Class Loss: 1.468913
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.491815
# [30368/60000 (55%)]	Class Loss: 1.461152
# [31968/60000 (58%)]	Class Loss: 1.461235
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461200
# [36768/60000 (67%)]	Class Loss: 1.461189
# [38368/60000 (70%)]	Class Loss: 1.476291
# [39968/60000 (73%)]	Class Loss: 1.461315
# [41568/60000 (76%)]	Class Loss: 1.461269
# [43168/60000 (78%)]	Class Loss: 1.461152
# [44768/60000 (81%)]	Class Loss: 1.492482
# [46368/60000 (84%)]	Class Loss: 1.463869
# [47968/60000 (87%)]	Class Loss: 1.461408
# [49568/60000 (90%)]	Class Loss: 1.463887
# [51168/60000 (93%)]	Class Loss: 1.477911
# [52768/60000 (96%)]	Class Loss: 1.461153
# [54368/60000 (99%)]	Class Loss: 1.461170
# Model test ...
# Test results on source_only :
#
# Source Accuracy: 9917/10000 (99.17%)
# Target Accuracy: 6548/10000 (65.48%)
#
# Epoch : 10
# [1568/60000 (3%)]	Class Loss: 1.461360
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461234
# [6368/60000 (12%)]	Class Loss: 1.461173
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461152
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.473531
# [14368/60000 (26%)]	Class Loss: 1.461172
# [15968/60000 (29%)]	Class Loss: 1.461301
# [17568/60000 (32%)]	Class Loss: 1.461161
# [19168/60000 (35%)]	Class Loss: 1.461434
# [20768/60000 (38%)]	Class Loss: 1.461215
# [22368/60000 (41%)]	Class Loss: 1.461313
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461158
# [27168/60000 (49%)]	Class Loss: 1.461177
# [28768/60000 (52%)]	Class Loss: 1.463962
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461156
# [33568/60000 (61%)]	Class Loss: 1.461177
# [35168/60000 (64%)]	Class Loss: 1.461171
# [36768/60000 (67%)]	Class Loss: 1.461172
# [38368/60000 (70%)]	Class Loss: 1.523677
# [39968/60000 (73%)]	Class Loss: 1.461161
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461157
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.474105
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.483333
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461233
# [54368/60000 (99%)]	Class Loss: 1.461265
# Epoch : 11
# [1568/60000 (3%)]	Class Loss: 1.461163
# [3168/60000 (6%)]	Class Loss: 1.461234
# [4768/60000 (9%)]	Class Loss: 1.467275
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.489852
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461394
# [14368/60000 (26%)]	Class Loss: 1.461166
# [15968/60000 (29%)]	Class Loss: 1.461480
# [17568/60000 (32%)]	Class Loss: 1.461223
# [19168/60000 (35%)]	Class Loss: 1.468274
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.462785
# [23968/60000 (44%)]	Class Loss: 1.461223
# [25568/60000 (46%)]	Class Loss: 1.479132
# [27168/60000 (49%)]	Class Loss: 1.483411
# [28768/60000 (52%)]	Class Loss: 1.462855
# [30368/60000 (55%)]	Class Loss: 1.464873
# [31968/60000 (58%)]	Class Loss: 1.461165
# [33568/60000 (61%)]	Class Loss: 1.469849
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461764
# [38368/60000 (70%)]	Class Loss: 1.469930
# [39968/60000 (73%)]	Class Loss: 1.461152
# [41568/60000 (76%)]	Class Loss: 1.461158
# [43168/60000 (78%)]	Class Loss: 1.487476
# [44768/60000 (81%)]	Class Loss: 1.461285
# [46368/60000 (84%)]	Class Loss: 1.461164
# [47968/60000 (87%)]	Class Loss: 1.492428
# [49568/60000 (90%)]	Class Loss: 1.461185
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461164
# [54368/60000 (99%)]	Class Loss: 1.461401
# Epoch : 12
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461201
# [6368/60000 (12%)]	Class Loss: 1.461423
# [7968/60000 (14%)]	Class Loss: 1.461288
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461172
# [12768/60000 (23%)]	Class Loss: 1.461154
# [14368/60000 (26%)]	Class Loss: 1.461272
# [15968/60000 (29%)]	Class Loss: 1.478863
# [17568/60000 (32%)]	Class Loss: 1.461161
# [19168/60000 (35%)]	Class Loss: 1.461155
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.462339
# [23968/60000 (44%)]	Class Loss: 1.461684
# [25568/60000 (46%)]	Class Loss: 1.462498
# [27168/60000 (49%)]	Class Loss: 1.474471
# [28768/60000 (52%)]	Class Loss: 1.461243
# [30368/60000 (55%)]	Class Loss: 1.461174
# [31968/60000 (58%)]	Class Loss: 1.480353
# [33568/60000 (61%)]	Class Loss: 1.461159
# [35168/60000 (64%)]	Class Loss: 1.461162
# [36768/60000 (67%)]	Class Loss: 1.477247
# [38368/60000 (70%)]	Class Loss: 1.461170
# [39968/60000 (73%)]	Class Loss: 1.462755
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.489887
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461162
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461155
# [51168/60000 (93%)]	Class Loss: 1.461161
# [52768/60000 (96%)]	Class Loss: 1.492054
# [54368/60000 (99%)]	Class Loss: 1.461155
# Epoch : 13
# [1568/60000 (3%)]	Class Loss: 1.461804
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.476885
# [7968/60000 (14%)]	Class Loss: 1.483034
# [9568/60000 (17%)]	Class Loss: 1.461439
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461168
# [14368/60000 (26%)]	Class Loss: 1.461340
# [15968/60000 (29%)]	Class Loss: 1.491610
# [17568/60000 (32%)]	Class Loss: 1.461152
# [19168/60000 (35%)]	Class Loss: 1.461158
# [20768/60000 (38%)]	Class Loss: 1.461698
# [22368/60000 (41%)]	Class Loss: 1.461193
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461152
# [28768/60000 (52%)]	Class Loss: 1.464920
# [30368/60000 (55%)]	Class Loss: 1.461159
# [31968/60000 (58%)]	Class Loss: 1.486903
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461152
# [36768/60000 (67%)]	Class Loss: 1.467683
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461191
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461245
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461432
# [47968/60000 (87%)]	Class Loss: 1.461249
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461153
# [52768/60000 (96%)]	Class Loss: 1.465181
# [54368/60000 (99%)]	Class Loss: 1.492406
# Epoch : 14
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461153
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.491921
# [7968/60000 (14%)]	Class Loss: 1.461152
# [9568/60000 (17%)]	Class Loss: 1.461164
# [11168/60000 (20%)]	Class Loss: 1.461374
# [12768/60000 (23%)]	Class Loss: 1.492401
# [14368/60000 (26%)]	Class Loss: 1.464284
# [15968/60000 (29%)]	Class Loss: 1.461283
# [17568/60000 (32%)]	Class Loss: 1.461844
# [19168/60000 (35%)]	Class Loss: 1.461156
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.492420
# [23968/60000 (44%)]	Class Loss: 1.491022
# [25568/60000 (46%)]	Class Loss: 1.461320
# [27168/60000 (49%)]	Class Loss: 1.461180
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461424
# [31968/60000 (58%)]	Class Loss: 1.462778
# [33568/60000 (61%)]	Class Loss: 1.463946
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461699
# [41568/60000 (76%)]	Class Loss: 1.461158
# [43168/60000 (78%)]	Class Loss: 1.462214
# [44768/60000 (81%)]	Class Loss: 1.461179
# [46368/60000 (84%)]	Class Loss: 1.461156
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461223
# [51168/60000 (93%)]	Class Loss: 1.465055
# [52768/60000 (96%)]	Class Loss: 1.461193
# [54368/60000 (99%)]	Class Loss: 1.461153
# Epoch : 15
# [1568/60000 (3%)]	Class Loss: 1.523644
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.483818
# [7968/60000 (14%)]	Class Loss: 1.461221
# [9568/60000 (17%)]	Class Loss: 1.461162
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461659
# [19168/60000 (35%)]	Class Loss: 1.461163
# [20768/60000 (38%)]	Class Loss: 1.491534
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461171
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461167
# [31968/60000 (58%)]	Class Loss: 1.463168
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461164
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461219
# [39968/60000 (73%)]	Class Loss: 1.461154
# [41568/60000 (76%)]	Class Loss: 1.461178
# [43168/60000 (78%)]	Class Loss: 1.461712
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461420
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.490597
# [51168/60000 (93%)]	Class Loss: 1.461159
# [52768/60000 (96%)]	Class Loss: 1.461326
# [54368/60000 (99%)]	Class Loss: 1.492703
# Epoch : 16
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.492071
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.463692
# [7968/60000 (14%)]	Class Loss: 1.461153
# [9568/60000 (17%)]	Class Loss: 1.461152
# [11168/60000 (20%)]	Class Loss: 1.461212
# [12768/60000 (23%)]	Class Loss: 1.461152
# [14368/60000 (26%)]	Class Loss: 1.461156
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461161
# [20768/60000 (38%)]	Class Loss: 1.461153
# [22368/60000 (41%)]	Class Loss: 1.463998
# [23968/60000 (44%)]	Class Loss: 1.461152
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461152
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461298
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.463822
# [35168/60000 (64%)]	Class Loss: 1.461164
# [36768/60000 (67%)]	Class Loss: 1.492413
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461203
# [41568/60000 (76%)]	Class Loss: 1.461240
# [43168/60000 (78%)]	Class Loss: 1.461172
# [44768/60000 (81%)]	Class Loss: 1.492400
# [46368/60000 (84%)]	Class Loss: 1.461175
# [47968/60000 (87%)]	Class Loss: 1.492312
# [49568/60000 (90%)]	Class Loss: 1.461345
# [51168/60000 (93%)]	Class Loss: 1.492401
# [52768/60000 (96%)]	Class Loss: 1.461190
# [54368/60000 (99%)]	Class Loss: 1.491458
# Epoch : 17
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461267
# [6368/60000 (12%)]	Class Loss: 1.461158
# [7968/60000 (14%)]	Class Loss: 1.461159
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461180
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.468998
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.465927
# [19168/60000 (35%)]	Class Loss: 1.464890
# [20768/60000 (38%)]	Class Loss: 1.461190
# [22368/60000 (41%)]	Class Loss: 1.461310
# [23968/60000 (44%)]	Class Loss: 1.491390
# [25568/60000 (46%)]	Class Loss: 1.461354
# [27168/60000 (49%)]	Class Loss: 1.461200
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461161
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.461152
# [35168/60000 (64%)]	Class Loss: 1.461211
# [36768/60000 (67%)]	Class Loss: 1.496897
# [38368/60000 (70%)]	Class Loss: 1.461154
# [39968/60000 (73%)]	Class Loss: 1.461154
# [41568/60000 (76%)]	Class Loss: 1.461191
# [43168/60000 (78%)]	Class Loss: 1.461488
# [44768/60000 (81%)]	Class Loss: 1.461178
# [46368/60000 (84%)]	Class Loss: 1.461157
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.492361
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461212
# Epoch : 18
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.492398
# [4768/60000 (9%)]	Class Loss: 1.461163
# [6368/60000 (12%)]	Class Loss: 1.493244
# [7968/60000 (14%)]	Class Loss: 1.461183
# [9568/60000 (17%)]	Class Loss: 1.461156
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461316
# [15968/60000 (29%)]	Class Loss: 1.461154
# [17568/60000 (32%)]	Class Loss: 1.461152
# [19168/60000 (35%)]	Class Loss: 1.461152
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.492390
# [23968/60000 (44%)]	Class Loss: 1.462723
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461152
# [28768/60000 (52%)]	Class Loss: 1.462667
# [30368/60000 (55%)]	Class Loss: 1.461152
# [31968/60000 (58%)]	Class Loss: 1.461402
# [33568/60000 (61%)]	Class Loss: 1.461341
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461156
# [38368/60000 (70%)]	Class Loss: 1.461152
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461152
# [44768/60000 (81%)]	Class Loss: 1.463039
# [46368/60000 (84%)]	Class Loss: 1.461161
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461196
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461230
# Epoch : 19
# [1568/60000 (3%)]	Class Loss: 1.461203
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.492325
# [6368/60000 (12%)]	Class Loss: 1.463704
# [7968/60000 (14%)]	Class Loss: 1.461306
# [9568/60000 (17%)]	Class Loss: 1.461166
# [11168/60000 (20%)]	Class Loss: 1.461163
# [12768/60000 (23%)]	Class Loss: 1.461164
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.492515
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461153
# [22368/60000 (41%)]	Class Loss: 1.461385
# [23968/60000 (44%)]	Class Loss: 1.461152
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461181
# [28768/60000 (52%)]	Class Loss: 1.461153
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461228
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461267
# [39968/60000 (73%)]	Class Loss: 1.461178
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.462338
# [47968/60000 (87%)]	Class Loss: 1.461153
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461698
# [54368/60000 (99%)]	Class Loss: 1.461151
# Model test ...
# Test results on source_only :
#
# Source Accuracy: 9927/10000 (99.27%)
# Target Accuracy: 6434/10000 (64.34%)
#
# Epoch : 20
# [1568/60000 (3%)]	Class Loss: 1.492401
# [3168/60000 (6%)]	Class Loss: 1.461183
# [4768/60000 (9%)]	Class Loss: 1.491905
# [6368/60000 (12%)]	Class Loss: 1.461161
# [7968/60000 (14%)]	Class Loss: 1.492402
# [9568/60000 (17%)]	Class Loss: 1.461155
# [11168/60000 (20%)]	Class Loss: 1.461634
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461367
# [15968/60000 (29%)]	Class Loss: 1.461404
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461183
# [20768/60000 (38%)]	Class Loss: 1.492376
# [22368/60000 (41%)]	Class Loss: 1.461183
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461153
# [27168/60000 (49%)]	Class Loss: 1.461154
# [28768/60000 (52%)]	Class Loss: 1.461164
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461161
# [33568/60000 (61%)]	Class Loss: 1.461152
# [35168/60000 (64%)]	Class Loss: 1.461303
# [36768/60000 (67%)]	Class Loss: 1.461204
# [38368/60000 (70%)]	Class Loss: 1.523487
# [39968/60000 (73%)]	Class Loss: 1.492402
# [41568/60000 (76%)]	Class Loss: 1.462134
# [43168/60000 (78%)]	Class Loss: 1.492402
# [44768/60000 (81%)]	Class Loss: 1.461161
# [46368/60000 (84%)]	Class Loss: 1.492406
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461157
# [51168/60000 (93%)]	Class Loss: 1.461158
# [52768/60000 (96%)]	Class Loss: 1.461260
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 21
# [1568/60000 (3%)]	Class Loss: 1.461166
# [3168/60000 (6%)]	Class Loss: 1.461586
# [4768/60000 (9%)]	Class Loss: 1.461152
# [6368/60000 (12%)]	Class Loss: 1.461160
# [7968/60000 (14%)]	Class Loss: 1.461531
# [9568/60000 (17%)]	Class Loss: 1.461154
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.491269
# [15968/60000 (29%)]	Class Loss: 1.461649
# [17568/60000 (32%)]	Class Loss: 1.461197
# [19168/60000 (35%)]	Class Loss: 1.461239
# [20768/60000 (38%)]	Class Loss: 1.461430
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461166
# [27168/60000 (49%)]	Class Loss: 1.461208
# [28768/60000 (52%)]	Class Loss: 1.461155
# [30368/60000 (55%)]	Class Loss: 1.461159
# [31968/60000 (58%)]	Class Loss: 1.480506
# [33568/60000 (61%)]	Class Loss: 1.461159
# [35168/60000 (64%)]	Class Loss: 1.461197
# [36768/60000 (67%)]	Class Loss: 1.492594
# [38368/60000 (70%)]	Class Loss: 1.461158
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461195
# [43168/60000 (78%)]	Class Loss: 1.461153
# [44768/60000 (81%)]	Class Loss: 1.461153
# [46368/60000 (84%)]	Class Loss: 1.461166
# [47968/60000 (87%)]	Class Loss: 1.461163
# [49568/60000 (90%)]	Class Loss: 1.461155
# [51168/60000 (93%)]	Class Loss: 1.461199
# [52768/60000 (96%)]	Class Loss: 1.461946
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 22
# [1568/60000 (3%)]	Class Loss: 1.461419
# [3168/60000 (6%)]	Class Loss: 1.461212
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461189
# [7968/60000 (14%)]	Class Loss: 1.492382
# [9568/60000 (17%)]	Class Loss: 1.461152
# [11168/60000 (20%)]	Class Loss: 1.461355
# [12768/60000 (23%)]	Class Loss: 1.461249
# [14368/60000 (26%)]	Class Loss: 1.461156
# [15968/60000 (29%)]	Class Loss: 1.492359
# [17568/60000 (32%)]	Class Loss: 1.461451
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461158
# [23968/60000 (44%)]	Class Loss: 1.461229
# [25568/60000 (46%)]	Class Loss: 1.461229
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461155
# [30368/60000 (55%)]	Class Loss: 1.492395
# [31968/60000 (58%)]	Class Loss: 1.461160
# [33568/60000 (61%)]	Class Loss: 1.461331
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.491168
# [38368/60000 (70%)]	Class Loss: 1.461376
# [39968/60000 (73%)]	Class Loss: 1.461152
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461155
# [44768/60000 (81%)]	Class Loss: 1.461314
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461347
# [52768/60000 (96%)]	Class Loss: 1.492385
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 23
# [1568/60000 (3%)]	Class Loss: 1.461155
# [3168/60000 (6%)]	Class Loss: 1.461161
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461187
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461162
# [11168/60000 (20%)]	Class Loss: 1.461157
# [12768/60000 (23%)]	Class Loss: 1.461152
# [14368/60000 (26%)]	Class Loss: 1.462338
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461153
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461192
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461248
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461152
# [28768/60000 (52%)]	Class Loss: 1.461152
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.492689
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461213
# [36768/60000 (67%)]	Class Loss: 1.461165
# [38368/60000 (70%)]	Class Loss: 1.461257
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461155
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.492404
# [46368/60000 (84%)]	Class Loss: 1.492408
# [47968/60000 (87%)]	Class Loss: 1.461153
# [49568/60000 (90%)]	Class Loss: 1.461378
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461239
# [54368/60000 (99%)]	Class Loss: 1.461166
# Epoch : 24
# [1568/60000 (3%)]	Class Loss: 1.461188
# [3168/60000 (6%)]	Class Loss: 1.461291
# [4768/60000 (9%)]	Class Loss: 1.461153
# [6368/60000 (12%)]	Class Loss: 1.463532
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461152
# [12768/60000 (23%)]	Class Loss: 1.461152
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.492355
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461305
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461160
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461152
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461160
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.461321
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461187
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461423
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461191
# [46368/60000 (84%)]	Class Loss: 1.461316
# [47968/60000 (87%)]	Class Loss: 1.461152
# [49568/60000 (90%)]	Class Loss: 1.461203
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461196
# Epoch : 25
# [1568/60000 (3%)]	Class Loss: 1.461153
# [3168/60000 (6%)]	Class Loss: 1.461154
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461165
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.492611
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461152
# [17568/60000 (32%)]	Class Loss: 1.461195
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461333
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461152
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461219
# [30368/60000 (55%)]	Class Loss: 1.461154
# [31968/60000 (58%)]	Class Loss: 1.461156
# [33568/60000 (61%)]	Class Loss: 1.461167
# [35168/60000 (64%)]	Class Loss: 1.492419
# [36768/60000 (67%)]	Class Loss: 1.485984
# [38368/60000 (70%)]	Class Loss: 1.461152
# [39968/60000 (73%)]	Class Loss: 1.461156
# [41568/60000 (76%)]	Class Loss: 1.461355
# [43168/60000 (78%)]	Class Loss: 1.461152
# [44768/60000 (81%)]	Class Loss: 1.461206
# [46368/60000 (84%)]	Class Loss: 1.461205
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.492700
# [51168/60000 (93%)]	Class Loss: 1.461243
# [52768/60000 (96%)]	Class Loss: 1.492585
# [54368/60000 (99%)]	Class Loss: 1.461181
# Epoch : 26
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461161
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.462146
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461226
# [20768/60000 (38%)]	Class Loss: 1.461152
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461368
# [30368/60000 (55%)]	Class Loss: 1.461152
# [31968/60000 (58%)]	Class Loss: 1.461160
# [33568/60000 (61%)]	Class Loss: 1.461152
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.492401
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.492400
# [41568/60000 (76%)]	Class Loss: 1.492401
# [43168/60000 (78%)]	Class Loss: 1.461152
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461193
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461251
# [52768/60000 (96%)]	Class Loss: 1.461183
# [54368/60000 (99%)]	Class Loss: 1.461157
# Epoch : 27
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461170
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461511
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461187
# [11168/60000 (20%)]	Class Loss: 1.461155
# [12768/60000 (23%)]	Class Loss: 1.461153
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461204
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461152
# [20768/60000 (38%)]	Class Loss: 1.461158
# [22368/60000 (41%)]	Class Loss: 1.461172
# [23968/60000 (44%)]	Class Loss: 1.461152
# [25568/60000 (46%)]	Class Loss: 1.461152
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461278
# [30368/60000 (55%)]	Class Loss: 1.461223
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.492401
# [35168/60000 (64%)]	Class Loss: 1.461299
# [36768/60000 (67%)]	Class Loss: 1.461177
# [38368/60000 (70%)]	Class Loss: 1.461159
# [39968/60000 (73%)]	Class Loss: 1.461155
# [41568/60000 (76%)]	Class Loss: 1.461163
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461159
# [47968/60000 (87%)]	Class Loss: 1.492398
# [49568/60000 (90%)]	Class Loss: 1.492400
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461194
# [54368/60000 (99%)]	Class Loss: 1.461182
# Epoch : 28
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.492409
# [4768/60000 (9%)]	Class Loss: 1.461220
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461155
# [9568/60000 (17%)]	Class Loss: 1.461165
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461281
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461250
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461152
# [25568/60000 (46%)]	Class Loss: 1.492427
# [27168/60000 (49%)]	Class Loss: 1.461163
# [28768/60000 (52%)]	Class Loss: 1.461423
# [30368/60000 (55%)]	Class Loss: 1.461154
# [31968/60000 (58%)]	Class Loss: 1.461152
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461152
# [36768/60000 (67%)]	Class Loss: 1.461390
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461168
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461337
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 29
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461384
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461153
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461169
# [11168/60000 (20%)]	Class Loss: 1.461154
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461248
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461171
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461193
# [22368/60000 (41%)]	Class Loss: 1.461303
# [23968/60000 (44%)]	Class Loss: 1.461192
# [25568/60000 (46%)]	Class Loss: 1.461208
# [27168/60000 (49%)]	Class Loss: 1.461153
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461162
# [39968/60000 (73%)]	Class Loss: 1.461186
# [41568/60000 (76%)]	Class Loss: 1.461152
# [43168/60000 (78%)]	Class Loss: 1.461159
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461166
# [47968/60000 (87%)]	Class Loss: 1.461192
# [49568/60000 (90%)]	Class Loss: 1.461155
# [51168/60000 (93%)]	Class Loss: 1.461154
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461152
# Model test ...
# Test results on source_only :
#
# Source Accuracy: 9932/10000 (99.32%)
# Target Accuracy: 6455/10000 (64.55%)
#
# Epoch : 30
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.491065
# [4768/60000 (9%)]	Class Loss: 1.461154
# [6368/60000 (12%)]	Class Loss: 1.461272
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461154
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461157
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461157
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461244
# [27168/60000 (49%)]	Class Loss: 1.461189
# [28768/60000 (52%)]	Class Loss: 1.461167
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461178
# [33568/60000 (61%)]	Class Loss: 1.461157
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461152
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461185
# [46368/60000 (84%)]	Class Loss: 1.461158
# [47968/60000 (87%)]	Class Loss: 1.461216
# [49568/60000 (90%)]	Class Loss: 1.461152
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.492384
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 31
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461153
# [4768/60000 (9%)]	Class Loss: 1.461191
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461185
# [9568/60000 (17%)]	Class Loss: 1.492510
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461165
# [14368/60000 (26%)]	Class Loss: 1.461167
# [15968/60000 (29%)]	Class Loss: 1.461251
# [17568/60000 (32%)]	Class Loss: 1.461156
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461160
# [22368/60000 (41%)]	Class Loss: 1.461213
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461152
# [27168/60000 (49%)]	Class Loss: 1.461152
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461158
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461160
# [36768/60000 (67%)]	Class Loss: 1.461160
# [38368/60000 (70%)]	Class Loss: 1.461190
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461160
# [46368/60000 (84%)]	Class Loss: 1.523622
# [47968/60000 (87%)]	Class Loss: 1.461176
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461473
# Epoch : 32
# [1568/60000 (3%)]	Class Loss: 1.461153
# [3168/60000 (6%)]	Class Loss: 1.461212
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461156
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461161
# [11168/60000 (20%)]	Class Loss: 1.492406
# [12768/60000 (23%)]	Class Loss: 1.461175
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461158
# [17568/60000 (32%)]	Class Loss: 1.461165
# [19168/60000 (35%)]	Class Loss: 1.491990
# [20768/60000 (38%)]	Class Loss: 1.461362
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461250
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.523650
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461199
# [33568/60000 (61%)]	Class Loss: 1.461170
# [35168/60000 (64%)]	Class Loss: 1.461215
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461285
# [41568/60000 (76%)]	Class Loss: 1.461457
# [43168/60000 (78%)]	Class Loss: 1.461161
# [44768/60000 (81%)]	Class Loss: 1.492402
# [46368/60000 (84%)]	Class Loss: 1.461311
# [47968/60000 (87%)]	Class Loss: 1.461178
# [49568/60000 (90%)]	Class Loss: 1.461154
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 33
# [1568/60000 (3%)]	Class Loss: 1.461175
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461156
# [7968/60000 (14%)]	Class Loss: 1.461152
# [9568/60000 (17%)]	Class Loss: 1.461182
# [11168/60000 (20%)]	Class Loss: 1.461153
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461154
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.492391
# [19168/60000 (35%)]	Class Loss: 1.461152
# [20768/60000 (38%)]	Class Loss: 1.461260
# [22368/60000 (41%)]	Class Loss: 1.461167
# [23968/60000 (44%)]	Class Loss: 1.461187
# [25568/60000 (46%)]	Class Loss: 1.492441
# [27168/60000 (49%)]	Class Loss: 1.461291
# [28768/60000 (52%)]	Class Loss: 1.461178
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.461154
# [35168/60000 (64%)]	Class Loss: 1.461152
# [36768/60000 (67%)]	Class Loss: 1.461185
# [38368/60000 (70%)]	Class Loss: 1.461162
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461152
# [44768/60000 (81%)]	Class Loss: 1.461155
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461171
# [49568/60000 (90%)]	Class Loss: 1.461152
# [51168/60000 (93%)]	Class Loss: 1.461151
# ...
# [15968/60000 (29%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813261
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.305660	Class Loss: 1.492399	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274885	Class Loss: 1.461623	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274414	Class Loss: 1.461153	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274436	Class Loss: 1.461174	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813261
# Epoch : 95
# [1568/60000 (3%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.274414	Class Loss: 1.461152	Domain Loss: 0.813261
# [4768/60000 (9%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.274413	Class Loss: 1.461152	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274417	Class Loss: 1.461155	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274413	Class Loss: 1.461152	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274419	Class Loss: 1.461157	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274418	Class Loss: 1.461157	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.336909	Class Loss: 1.523647	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.274414	Class Loss: 1.461153	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# Epoch : 96
# [1568/60000 (3%)]	Loss: 2.274416	Class Loss: 1.461154	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [4768/60000 (9%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274409	Class Loss: 1.461151	Domain Loss: 0.813258
# [9568/60000 (17%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274415	Class Loss: 1.461153	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274423	Class Loss: 1.461161	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# Epoch : 97
# [1568/60000 (3%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.274418	Class Loss: 1.461156	Domain Loss: 0.813262
# [4768/60000 (9%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274417	Class Loss: 1.461156	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274414	Class Loss: 1.461153	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274428	Class Loss: 1.461166	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274444	Class Loss: 1.461182	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813261
# [25568/60000 (46%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274419	Class Loss: 1.461157	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274414	Class Loss: 1.461153	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274414	Class Loss: 1.461153	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.305663	Class Loss: 1.492401	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# Epoch : 98
# [1568/60000 (3%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [4768/60000 (9%)]	Loss: 2.274420	Class Loss: 1.461159	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274414	Class Loss: 1.461152	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274324	Class Loss: 1.461151	Domain Loss: 0.813173
# [22368/60000 (41%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274413	Class Loss: 1.461152	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# Epoch : 99
# [1568/60000 (3%)]	Loss: 2.305663	Class Loss: 1.492402	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [4768/60000 (9%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274594	Class Loss: 1.461332	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813261
# [33568/60000 (61%)]	Loss: 2.274425	Class Loss: 1.461164	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274405	Class Loss: 1.461151	Domain Loss: 0.813254
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.304530	Class Loss: 1.491268	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# Model test ...
# Test Results on DANN :
#
# Source Accuracy: 9927/10000 (99.27%)
# Target Accuracy: 7914/10000 (79.14%)
# Domain Accuracy: 10000/20000 (50.00%)
#
# Save models ...
# Model is saved !!!
# Extract features to draw T-SNE plot...
# c:\Users\jaido\source\Pytorch_DABP\venv\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# c:\Users\jaido\source\Pytorch_DABP\venv\lib\site-packages\sklearn\manifold\_t_sne.py:996: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# Draw plot ...
# saved_plot/source_dann_1_source.png is saved

# %%
# import importlib
# importlib.reload(main)
import main

print(main.save_name)

main.main()
# Out:
# second_run
# Running GPU : 0
# Source-only training
# Epoch : 0
# c:\Users\jaido\source\Pytorch_DABP\model.py:38: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# [1568/60000 (3%)]	Class Loss: 2.300436
# [3168/60000 (6%)]	Class Loss: 2.300359
# [4768/60000 (9%)]	Class Loss: 2.301177
# [6368/60000 (12%)]	Class Loss: 2.297194
# [7968/60000 (14%)]	Class Loss: 2.278231
# [9568/60000 (17%)]	Class Loss: 2.177457
# [11168/60000 (20%)]	Class Loss: 2.032684
# [12768/60000 (23%)]	Class Loss: 1.888742
# [14368/60000 (26%)]	Class Loss: 1.726698
# [15968/60000 (29%)]	Class Loss: 1.761669
# [17568/60000 (32%)]	Class Loss: 1.704296
# [19168/60000 (35%)]	Class Loss: 1.558870
# [20768/60000 (38%)]	Class Loss: 1.685592
# [22368/60000 (41%)]	Class Loss: 1.665202
# [23968/60000 (44%)]	Class Loss: 1.560275
# [25568/60000 (46%)]	Class Loss: 1.578070
# [27168/60000 (49%)]	Class Loss: 1.708416
# [28768/60000 (52%)]	Class Loss: 1.587350
# [30368/60000 (55%)]	Class Loss: 1.559537
# [31968/60000 (58%)]	Class Loss: 1.550262
# [33568/60000 (61%)]	Class Loss: 1.552438
# [35168/60000 (64%)]	Class Loss: 1.556293
# [36768/60000 (67%)]	Class Loss: 1.507679
# [38368/60000 (70%)]	Class Loss: 1.609327
# [39968/60000 (73%)]	Class Loss: 1.539031
# [41568/60000 (76%)]	Class Loss: 1.620671
# [43168/60000 (78%)]	Class Loss: 1.612520
# [44768/60000 (81%)]	Class Loss: 1.580232
# [46368/60000 (84%)]	Class Loss: 1.619129
# [47968/60000 (87%)]	Class Loss: 1.470803
# [49568/60000 (90%)]	Class Loss: 1.616929
# [51168/60000 (93%)]	Class Loss: 1.588133
# [52768/60000 (96%)]	Class Loss: 1.542417
# [54368/60000 (99%)]	Class Loss: 1.631492
# Epoch : 1
# [1568/60000 (3%)]	Class Loss: 1.554332
# [3168/60000 (6%)]	Class Loss: 1.533163
# [4768/60000 (9%)]	Class Loss: 1.631967
# [6368/60000 (12%)]	Class Loss: 1.573977
# [7968/60000 (14%)]	Class Loss: 1.561864
# [9568/60000 (17%)]	Class Loss: 1.548550
# [11168/60000 (20%)]	Class Loss: 1.555035
# [12768/60000 (23%)]	Class Loss: 1.584243
# [14368/60000 (26%)]	Class Loss: 1.543122
# [15968/60000 (29%)]	Class Loss: 1.528206
# [17568/60000 (32%)]	Class Loss: 1.558727
# [19168/60000 (35%)]	Class Loss: 1.554608
# [20768/60000 (38%)]	Class Loss: 1.511483
# [22368/60000 (41%)]	Class Loss: 1.581838
# [23968/60000 (44%)]	Class Loss: 1.521750
# [25568/60000 (46%)]	Class Loss: 1.587010
# [27168/60000 (49%)]	Class Loss: 1.525690
# [28768/60000 (52%)]	Class Loss: 1.493276
# [30368/60000 (55%)]	Class Loss: 1.467032
# [31968/60000 (58%)]	Class Loss: 1.461565
# [33568/60000 (61%)]	Class Loss: 1.551124
# [35168/60000 (64%)]	Class Loss: 1.468014
# [36768/60000 (67%)]	Class Loss: 1.492517
# [38368/60000 (70%)]	Class Loss: 1.462907
# [39968/60000 (73%)]	Class Loss: 1.517246
# [41568/60000 (76%)]	Class Loss: 1.492258
# [43168/60000 (78%)]	Class Loss: 1.532743
# [44768/60000 (81%)]	Class Loss: 1.507915
# [46368/60000 (84%)]	Class Loss: 1.495624
# [47968/60000 (87%)]	Class Loss: 1.461445
# [49568/60000 (90%)]	Class Loss: 1.492587
# [51168/60000 (93%)]	Class Loss: 1.492458
# [52768/60000 (96%)]	Class Loss: 1.467177
# [54368/60000 (99%)]	Class Loss: 1.534109
# Epoch : 2
# [1568/60000 (3%)]	Class Loss: 1.521054
# [3168/60000 (6%)]	Class Loss: 1.494769
# [4768/60000 (9%)]	Class Loss: 1.492609
# [6368/60000 (12%)]	Class Loss: 1.543923
# [7968/60000 (14%)]	Class Loss: 1.463092
# [9568/60000 (17%)]	Class Loss: 1.491252
# [11168/60000 (20%)]	Class Loss: 1.475411
# [12768/60000 (23%)]	Class Loss: 1.521252
# [14368/60000 (26%)]	Class Loss: 1.494382
# [15968/60000 (29%)]	Class Loss: 1.461360
# [17568/60000 (32%)]	Class Loss: 1.494991
# [19168/60000 (35%)]	Class Loss: 1.488886
# [20768/60000 (38%)]	Class Loss: 1.461787
# [22368/60000 (41%)]	Class Loss: 1.465622
# [23968/60000 (44%)]	Class Loss: 1.462091
# [25568/60000 (46%)]	Class Loss: 1.461323
# [27168/60000 (49%)]	Class Loss: 1.503188
# [28768/60000 (52%)]	Class Loss: 1.502209
# [30368/60000 (55%)]	Class Loss: 1.498823
# [31968/60000 (58%)]	Class Loss: 1.463521
# [33568/60000 (61%)]	Class Loss: 1.495041
# [35168/60000 (64%)]	Class Loss: 1.492195
# [36768/60000 (67%)]	Class Loss: 1.483900
# [38368/60000 (70%)]	Class Loss: 1.461154
# [39968/60000 (73%)]	Class Loss: 1.461394
# [41568/60000 (76%)]	Class Loss: 1.477752
# [43168/60000 (78%)]	Class Loss: 1.481216
# [44768/60000 (81%)]	Class Loss: 1.461953
# [46368/60000 (84%)]	Class Loss: 1.500473
# [47968/60000 (87%)]	Class Loss: 1.482590
# [49568/60000 (90%)]	Class Loss: 1.461364
# [51168/60000 (93%)]	Class Loss: 1.491563
# [52768/60000 (96%)]	Class Loss: 1.461158
# [54368/60000 (99%)]	Class Loss: 1.462835
# Epoch : 3
# [1568/60000 (3%)]	Class Loss: 1.474940
# [3168/60000 (6%)]	Class Loss: 1.461611
# [4768/60000 (9%)]	Class Loss: 1.462381
# [6368/60000 (12%)]	Class Loss: 1.490375
# [7968/60000 (14%)]	Class Loss: 1.463038
# [9568/60000 (17%)]	Class Loss: 1.491348
# [11168/60000 (20%)]	Class Loss: 1.461155
# [12768/60000 (23%)]	Class Loss: 1.461988
# [14368/60000 (26%)]	Class Loss: 1.461161
# [15968/60000 (29%)]	Class Loss: 1.474958
# [17568/60000 (32%)]	Class Loss: 1.466623
# [19168/60000 (35%)]	Class Loss: 1.491972
# [20768/60000 (38%)]	Class Loss: 1.461476
# [22368/60000 (41%)]	Class Loss: 1.461273
# [23968/60000 (44%)]	Class Loss: 1.468774
# [25568/60000 (46%)]	Class Loss: 1.461171
# [27168/60000 (49%)]	Class Loss: 1.485344
# [28768/60000 (52%)]	Class Loss: 1.522272
# [30368/60000 (55%)]	Class Loss: 1.504393
# [31968/60000 (58%)]	Class Loss: 1.464388
# [33568/60000 (61%)]	Class Loss: 1.502417
# [35168/60000 (64%)]	Class Loss: 1.461331
# [36768/60000 (67%)]	Class Loss: 1.465706
# [38368/60000 (70%)]	Class Loss: 1.465272
# [39968/60000 (73%)]	Class Loss: 1.495205
# [41568/60000 (76%)]	Class Loss: 1.492411
# [43168/60000 (78%)]	Class Loss: 1.463363
# [44768/60000 (81%)]	Class Loss: 1.491215
# [46368/60000 (84%)]	Class Loss: 1.491805
# [47968/60000 (87%)]	Class Loss: 1.486374
# [49568/60000 (90%)]	Class Loss: 1.499940
# [51168/60000 (93%)]	Class Loss: 1.461527
# [52768/60000 (96%)]	Class Loss: 1.493840
# [54368/60000 (99%)]	Class Loss: 1.491926
# Epoch : 4
# [1568/60000 (3%)]	Class Loss: 1.465322
# [3168/60000 (6%)]	Class Loss: 1.489764
# [4768/60000 (9%)]	Class Loss: 1.481387
# [6368/60000 (12%)]	Class Loss: 1.461157
# [7968/60000 (14%)]	Class Loss: 1.489195
# [9568/60000 (17%)]	Class Loss: 1.471244
# [11168/60000 (20%)]	Class Loss: 1.522591
# [12768/60000 (23%)]	Class Loss: 1.461156
# [14368/60000 (26%)]	Class Loss: 1.492374
# [15968/60000 (29%)]	Class Loss: 1.495651
# [17568/60000 (32%)]	Class Loss: 1.461582
# [19168/60000 (35%)]	Class Loss: 1.461402
# [20768/60000 (38%)]	Class Loss: 1.476581
# [22368/60000 (41%)]	Class Loss: 1.461159
# [23968/60000 (44%)]	Class Loss: 1.461376
# [25568/60000 (46%)]	Class Loss: 1.461188
# [27168/60000 (49%)]	Class Loss: 1.463608
# [28768/60000 (52%)]	Class Loss: 1.461179
# [30368/60000 (55%)]	Class Loss: 1.502572
# [31968/60000 (58%)]	Class Loss: 1.461228
# [33568/60000 (61%)]	Class Loss: 1.492265
# [35168/60000 (64%)]	Class Loss: 1.461425
# [36768/60000 (67%)]	Class Loss: 1.492401
# [38368/60000 (70%)]	Class Loss: 1.461292
# [39968/60000 (73%)]	Class Loss: 1.478298
# [41568/60000 (76%)]	Class Loss: 1.474897
# [43168/60000 (78%)]	Class Loss: 1.492733
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.493694
# [47968/60000 (87%)]	Class Loss: 1.471259
# [49568/60000 (90%)]	Class Loss: 1.493486
# [51168/60000 (93%)]	Class Loss: 1.461337
# [52768/60000 (96%)]	Class Loss: 1.461153
# [54368/60000 (99%)]	Class Loss: 1.493825
# Epoch : 5
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.474773
# [4768/60000 (9%)]	Class Loss: 1.461216
# [6368/60000 (12%)]	Class Loss: 1.461166
# [7968/60000 (14%)]	Class Loss: 1.471713
# [9568/60000 (17%)]	Class Loss: 1.484566
# [11168/60000 (20%)]	Class Loss: 1.461160
# [12768/60000 (23%)]	Class Loss: 1.461210
# [14368/60000 (26%)]	Class Loss: 1.461600
# [15968/60000 (29%)]	Class Loss: 1.461167
# [17568/60000 (32%)]	Class Loss: 1.479039
# [19168/60000 (35%)]	Class Loss: 1.461154
# [20768/60000 (38%)]	Class Loss: 1.492422
# [22368/60000 (41%)]	Class Loss: 1.492401
# [23968/60000 (44%)]	Class Loss: 1.461159
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461238
# [28768/60000 (52%)]	Class Loss: 1.462072
# [30368/60000 (55%)]	Class Loss: 1.492701
# [31968/60000 (58%)]	Class Loss: 1.461163
# [33568/60000 (61%)]	Class Loss: 1.461154
# [35168/60000 (64%)]	Class Loss: 1.461415
# [36768/60000 (67%)]	Class Loss: 1.486766
# [38368/60000 (70%)]	Class Loss: 1.461155
# [39968/60000 (73%)]	Class Loss: 1.461340
# [41568/60000 (76%)]	Class Loss: 1.469784
# [43168/60000 (78%)]	Class Loss: 1.470511
# [44768/60000 (81%)]	Class Loss: 1.469426
# [46368/60000 (84%)]	Class Loss: 1.503989
# [47968/60000 (87%)]	Class Loss: 1.526458
# [49568/60000 (90%)]	Class Loss: 1.462161
# [51168/60000 (93%)]	Class Loss: 1.461158
# [52768/60000 (96%)]	Class Loss: 1.461400
# [54368/60000 (99%)]	Class Loss: 1.492394
# Epoch : 6
# [1568/60000 (3%)]	Class Loss: 1.520348
# [3168/60000 (6%)]	Class Loss: 1.463681
# [4768/60000 (9%)]	Class Loss: 1.461674
# [6368/60000 (12%)]	Class Loss: 1.461205
# [7968/60000 (14%)]	Class Loss: 1.489108
# [9568/60000 (17%)]	Class Loss: 1.463762
# [11168/60000 (20%)]	Class Loss: 1.492404
# [12768/60000 (23%)]	Class Loss: 1.461170
# [14368/60000 (26%)]	Class Loss: 1.461152
# [15968/60000 (29%)]	Class Loss: 1.492408
# [17568/60000 (32%)]	Class Loss: 1.493928
# [19168/60000 (35%)]	Class Loss: 1.470145
# [20768/60000 (38%)]	Class Loss: 1.461159
# [22368/60000 (41%)]	Class Loss: 1.486844
# [23968/60000 (44%)]	Class Loss: 1.463324
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.462155
# [28768/60000 (52%)]	Class Loss: 1.506942
# [30368/60000 (55%)]	Class Loss: 1.461154
# [31968/60000 (58%)]	Class Loss: 1.461152
# [33568/60000 (61%)]	Class Loss: 1.463969
# [35168/60000 (64%)]	Class Loss: 1.461181
# [36768/60000 (67%)]	Class Loss: 1.491803
# [38368/60000 (70%)]	Class Loss: 1.545210
# [39968/60000 (73%)]	Class Loss: 1.505361
# [41568/60000 (76%)]	Class Loss: 1.492751
# [43168/60000 (78%)]	Class Loss: 1.461349
# [44768/60000 (81%)]	Class Loss: 1.461152
# [46368/60000 (84%)]	Class Loss: 1.461163
# [47968/60000 (87%)]	Class Loss: 1.461155
# [49568/60000 (90%)]	Class Loss: 1.491293
# [51168/60000 (93%)]	Class Loss: 1.483047
# [52768/60000 (96%)]	Class Loss: 1.462258
# [54368/60000 (99%)]	Class Loss: 1.461586
# Epoch : 7
# [1568/60000 (3%)]	Class Loss: 1.461155
# [3168/60000 (6%)]	Class Loss: 1.461160
# [4768/60000 (9%)]	Class Loss: 1.477369
# [6368/60000 (12%)]	Class Loss: 1.490351
# [7968/60000 (14%)]	Class Loss: 1.463337
# [9568/60000 (17%)]	Class Loss: 1.461452
# [11168/60000 (20%)]	Class Loss: 1.461167
# [12768/60000 (23%)]	Class Loss: 1.477831
# [14368/60000 (26%)]	Class Loss: 1.471900
# [15968/60000 (29%)]	Class Loss: 1.461279
# [17568/60000 (32%)]	Class Loss: 1.461286
# [19168/60000 (35%)]	Class Loss: 1.461156
# [20768/60000 (38%)]	Class Loss: 1.466116
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461160
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.485580
# [28768/60000 (52%)]	Class Loss: 1.462661
# [30368/60000 (55%)]	Class Loss: 1.461172
# [31968/60000 (58%)]	Class Loss: 1.461802
# [33568/60000 (61%)]	Class Loss: 1.461491
# [35168/60000 (64%)]	Class Loss: 1.478799
# [36768/60000 (67%)]	Class Loss: 1.465299
# [38368/60000 (70%)]	Class Loss: 1.492667
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461189
# [43168/60000 (78%)]	Class Loss: 1.461287
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461158
# [47968/60000 (87%)]	Class Loss: 1.462659
# [49568/60000 (90%)]	Class Loss: 1.492319
# [51168/60000 (93%)]	Class Loss: 1.470406
# [52768/60000 (96%)]	Class Loss: 1.461251
# [54368/60000 (99%)]	Class Loss: 1.461154
# Epoch : 8
# [1568/60000 (3%)]	Class Loss: 1.461152
# [3168/60000 (6%)]	Class Loss: 1.461845
# [4768/60000 (9%)]	Class Loss: 1.461196
# [6368/60000 (12%)]	Class Loss: 1.461469
# [7968/60000 (14%)]	Class Loss: 1.461159
# [9568/60000 (17%)]	Class Loss: 1.461324
# [11168/60000 (20%)]	Class Loss: 1.461265
# [12768/60000 (23%)]	Class Loss: 1.461179
# [14368/60000 (26%)]	Class Loss: 1.461153
# [15968/60000 (29%)]	Class Loss: 1.461166
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461514
# [20768/60000 (38%)]	Class Loss: 1.461185
# [22368/60000 (41%)]	Class Loss: 1.461152
# [23968/60000 (44%)]	Class Loss: 1.461172
# [25568/60000 (46%)]	Class Loss: 1.462653
# [27168/60000 (49%)]	Class Loss: 1.473076
# [28768/60000 (52%)]	Class Loss: 1.461453
# [30368/60000 (55%)]	Class Loss: 1.479143
# [31968/60000 (58%)]	Class Loss: 1.461359
# [33568/60000 (61%)]	Class Loss: 1.465307
# [35168/60000 (64%)]	Class Loss: 1.461181
# [36768/60000 (67%)]	Class Loss: 1.466835
# [38368/60000 (70%)]	Class Loss: 1.461166
# [39968/60000 (73%)]	Class Loss: 1.488090
# [41568/60000 (76%)]	Class Loss: 1.481960
# [43168/60000 (78%)]	Class Loss: 1.461152
# [44768/60000 (81%)]	Class Loss: 1.461275
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461172
# [49568/60000 (90%)]	Class Loss: 1.461278
# [51168/60000 (93%)]	Class Loss: 1.461164
# [52768/60000 (96%)]	Class Loss: 1.461156
# [54368/60000 (99%)]	Class Loss: 1.466750
# Epoch : 9
# [1568/60000 (3%)]	Class Loss: 1.461504
# [3168/60000 (6%)]	Class Loss: 1.462208
# [4768/60000 (9%)]	Class Loss: 1.495773
# [6368/60000 (12%)]	Class Loss: 1.466073
# [7968/60000 (14%)]	Class Loss: 1.493282
# [9568/60000 (17%)]	Class Loss: 1.462411
# [11168/60000 (20%)]	Class Loss: 1.479459
# [12768/60000 (23%)]	Class Loss: 1.461154
# [14368/60000 (26%)]	Class Loss: 1.462866
# [15968/60000 (29%)]	Class Loss: 1.492164
# [17568/60000 (32%)]	Class Loss: 1.461168
# [19168/60000 (35%)]	Class Loss: 1.461153
# [20768/60000 (38%)]	Class Loss: 1.492218
# [22368/60000 (41%)]	Class Loss: 1.461161
# [23968/60000 (44%)]	Class Loss: 1.461152
# [25568/60000 (46%)]	Class Loss: 1.461173
# [27168/60000 (49%)]	Class Loss: 1.461160
# [28768/60000 (52%)]	Class Loss: 1.461301
# [30368/60000 (55%)]	Class Loss: 1.523789
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.519390
# [35168/60000 (64%)]	Class Loss: 1.461212
# [36768/60000 (67%)]	Class Loss: 1.461512
# [38368/60000 (70%)]	Class Loss: 1.464144
# [39968/60000 (73%)]	Class Loss: 1.466395
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461161
# [44768/60000 (81%)]	Class Loss: 1.461221
# [46368/60000 (84%)]	Class Loss: 1.489720
# [47968/60000 (87%)]	Class Loss: 1.461155
# [49568/60000 (90%)]	Class Loss: 1.461356
# [51168/60000 (93%)]	Class Loss: 1.461163
# [52768/60000 (96%)]	Class Loss: 1.461161
# [54368/60000 (99%)]	Class Loss: 1.461182
# Model test ...
# Test results on source_only :
#
# Source Accuracy: 9899/10000 (98.99%)
# Target Accuracy: 6354/10000 (63.54%)
#
# Epoch : 10
# [1568/60000 (3%)]	Class Loss: 1.516632
# [3168/60000 (6%)]	Class Loss: 1.461152
# [4768/60000 (9%)]	Class Loss: 1.461159
# [6368/60000 (12%)]	Class Loss: 1.492441
# [7968/60000 (14%)]	Class Loss: 1.478050
# [9568/60000 (17%)]	Class Loss: 1.461159
# [11168/60000 (20%)]	Class Loss: 1.461154
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461155
# [15968/60000 (29%)]	Class Loss: 1.492309
# [17568/60000 (32%)]	Class Loss: 1.461165
# [19168/60000 (35%)]	Class Loss: 1.461268
# [20768/60000 (38%)]	Class Loss: 1.461470
# [22368/60000 (41%)]	Class Loss: 1.461374
# [23968/60000 (44%)]	Class Loss: 1.461583
# [25568/60000 (46%)]	Class Loss: 1.486248
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.492388
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.463640
# [33568/60000 (61%)]	Class Loss: 1.461208
# [35168/60000 (64%)]	Class Loss: 1.474985
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.492215
# [39968/60000 (73%)]	Class Loss: 1.492404
# [41568/60000 (76%)]	Class Loss: 1.461175
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.469035
# [46368/60000 (84%)]	Class Loss: 1.461237
# [47968/60000 (87%)]	Class Loss: 1.492397
# [49568/60000 (90%)]	Class Loss: 1.463817
# [51168/60000 (93%)]	Class Loss: 1.461152
# [52768/60000 (96%)]	Class Loss: 1.461154
# [54368/60000 (99%)]	Class Loss: 1.461154
# Epoch : 11
# [1568/60000 (3%)]	Class Loss: 1.461233
# [3168/60000 (6%)]	Class Loss: 1.461156
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461155
# [7968/60000 (14%)]	Class Loss: 1.461153
# [9568/60000 (17%)]	Class Loss: 1.461197
# [11168/60000 (20%)]	Class Loss: 1.461412
# [12768/60000 (23%)]	Class Loss: 1.477901
# [14368/60000 (26%)]	Class Loss: 1.492616
# [15968/60000 (29%)]	Class Loss: 1.461159
# [17568/60000 (32%)]	Class Loss: 1.523273
# [19168/60000 (35%)]	Class Loss: 1.461152
# [20768/60000 (38%)]	Class Loss: 1.461156
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461199
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461162
# [28768/60000 (52%)]	Class Loss: 1.461936
# [30368/60000 (55%)]	Class Loss: 1.461225
# [31968/60000 (58%)]	Class Loss: 1.461241
# [33568/60000 (61%)]	Class Loss: 1.490980
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.477377
# [38368/60000 (70%)]	Class Loss: 1.461176
# [39968/60000 (73%)]	Class Loss: 1.462622
# [41568/60000 (76%)]	Class Loss: 1.464294
# [43168/60000 (78%)]	Class Loss: 1.461158
# [44768/60000 (81%)]	Class Loss: 1.474037
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461904
# [49568/60000 (90%)]	Class Loss: 1.461209
# [51168/60000 (93%)]	Class Loss: 1.465428
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461200
# Epoch : 12
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461441
# [4768/60000 (9%)]	Class Loss: 1.461152
# [6368/60000 (12%)]	Class Loss: 1.485668
# [7968/60000 (14%)]	Class Loss: 1.466768
# [9568/60000 (17%)]	Class Loss: 1.492728
# [11168/60000 (20%)]	Class Loss: 1.474450
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461186
# [15968/60000 (29%)]	Class Loss: 1.498135
# [17568/60000 (32%)]	Class Loss: 1.492407
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461336
# [22368/60000 (41%)]	Class Loss: 1.461164
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461159
# [27168/60000 (49%)]	Class Loss: 1.461156
# [28768/60000 (52%)]	Class Loss: 1.464687
# [30368/60000 (55%)]	Class Loss: 1.461219
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.462228
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461163
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461255
# [43168/60000 (78%)]	Class Loss: 1.504307
# [44768/60000 (81%)]	Class Loss: 1.461259
# [46368/60000 (84%)]	Class Loss: 1.493795
# [47968/60000 (87%)]	Class Loss: 1.461295
# [49568/60000 (90%)]	Class Loss: 1.492482
# [51168/60000 (93%)]	Class Loss: 1.461160
# [52768/60000 (96%)]	Class Loss: 1.461154
# [54368/60000 (99%)]	Class Loss: 1.461167
# Epoch : 13
# [1568/60000 (3%)]	Class Loss: 1.492031
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461227
# [7968/60000 (14%)]	Class Loss: 1.461187
# [9568/60000 (17%)]	Class Loss: 1.461667
# [11168/60000 (20%)]	Class Loss: 1.461159
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461434
# [15968/60000 (29%)]	Class Loss: 1.461156
# [17568/60000 (32%)]	Class Loss: 1.461152
# [19168/60000 (35%)]	Class Loss: 1.461178
# [20768/60000 (38%)]	Class Loss: 1.461155
# [22368/60000 (41%)]	Class Loss: 1.461279
# [23968/60000 (44%)]	Class Loss: 1.461230
# [25568/60000 (46%)]	Class Loss: 1.461556
# [27168/60000 (49%)]	Class Loss: 1.491803
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461169
# [31968/60000 (58%)]	Class Loss: 1.461168
# [33568/60000 (61%)]	Class Loss: 1.461791
# [35168/60000 (64%)]	Class Loss: 1.461330
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461157
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461154
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461152
# [51168/60000 (93%)]	Class Loss: 1.461304
# [52768/60000 (96%)]	Class Loss: 1.461806
# [54368/60000 (99%)]	Class Loss: 1.470239
# Epoch : 14
# [1568/60000 (3%)]	Class Loss: 1.462770
# [3168/60000 (6%)]	Class Loss: 1.462263
# [4768/60000 (9%)]	Class Loss: 1.461244
# [6368/60000 (12%)]	Class Loss: 1.461161
# [7968/60000 (14%)]	Class Loss: 1.461418
# [9568/60000 (17%)]	Class Loss: 1.463504
# [11168/60000 (20%)]	Class Loss: 1.462008
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461154
# [15968/60000 (29%)]	Class Loss: 1.461157
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461395
# [20768/60000 (38%)]	Class Loss: 1.461152
# [22368/60000 (41%)]	Class Loss: 1.461408
# [23968/60000 (44%)]	Class Loss: 1.461152
# [25568/60000 (46%)]	Class Loss: 1.461156
# [27168/60000 (49%)]	Class Loss: 1.461152
# [28768/60000 (52%)]	Class Loss: 1.461165
# [30368/60000 (55%)]	Class Loss: 1.461299
# [31968/60000 (58%)]	Class Loss: 1.461157
# [33568/60000 (61%)]	Class Loss: 1.461165
# [35168/60000 (64%)]	Class Loss: 1.492176
# [36768/60000 (67%)]	Class Loss: 1.487117
# [38368/60000 (70%)]	Class Loss: 1.492836
# [39968/60000 (73%)]	Class Loss: 1.461152
# [41568/60000 (76%)]	Class Loss: 1.461154
# [43168/60000 (78%)]	Class Loss: 1.461209
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.462580
# [47968/60000 (87%)]	Class Loss: 1.491533
# [49568/60000 (90%)]	Class Loss: 1.461188
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.492399
# [54368/60000 (99%)]	Class Loss: 1.461579
# Epoch : 15
# [1568/60000 (3%)]	Class Loss: 1.467053
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461168
# [9568/60000 (17%)]	Class Loss: 1.461356
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.474717
# [14368/60000 (26%)]	Class Loss: 1.461152
# [15968/60000 (29%)]	Class Loss: 1.461937
# [17568/60000 (32%)]	Class Loss: 1.461172
# [19168/60000 (35%)]	Class Loss: 1.492401
# [20768/60000 (38%)]	Class Loss: 1.461158
# [22368/60000 (41%)]	Class Loss: 1.471859
# [23968/60000 (44%)]	Class Loss: 1.461926
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461170
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.492440
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.461154
# [35168/60000 (64%)]	Class Loss: 1.461155
# [36768/60000 (67%)]	Class Loss: 1.461419
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.491961
# [41568/60000 (76%)]	Class Loss: 1.461152
# [43168/60000 (78%)]	Class Loss: 1.461680
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461153
# [47968/60000 (87%)]	Class Loss: 1.492378
# [49568/60000 (90%)]	Class Loss: 1.461213
# [51168/60000 (93%)]	Class Loss: 1.489401
# [52768/60000 (96%)]	Class Loss: 1.461203
# [54368/60000 (99%)]	Class Loss: 1.461166
# Epoch : 16
# [1568/60000 (3%)]	Class Loss: 1.461211
# [3168/60000 (6%)]	Class Loss: 1.461526
# [4768/60000 (9%)]	Class Loss: 1.468294
# [6368/60000 (12%)]	Class Loss: 1.461191
# [7968/60000 (14%)]	Class Loss: 1.461210
# [9568/60000 (17%)]	Class Loss: 1.492401
# [11168/60000 (20%)]	Class Loss: 1.461153
# [12768/60000 (23%)]	Class Loss: 1.461156
# [14368/60000 (26%)]	Class Loss: 1.461833
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461153
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461154
# [22368/60000 (41%)]	Class Loss: 1.461484
# [23968/60000 (44%)]	Class Loss: 1.515226
# [25568/60000 (46%)]	Class Loss: 1.461655
# [27168/60000 (49%)]	Class Loss: 1.461157
# [28768/60000 (52%)]	Class Loss: 1.461195
# [30368/60000 (55%)]	Class Loss: 1.492401
# [31968/60000 (58%)]	Class Loss: 1.461152
# [33568/60000 (61%)]	Class Loss: 1.461164
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461164
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461220
# [44768/60000 (81%)]	Class Loss: 1.461181
# [46368/60000 (84%)]	Class Loss: 1.461161
# [47968/60000 (87%)]	Class Loss: 1.461157
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461656
# [52768/60000 (96%)]	Class Loss: 1.480377
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 17
# [1568/60000 (3%)]	Class Loss: 1.461153
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461270
# [7968/60000 (14%)]	Class Loss: 1.461153
# [9568/60000 (17%)]	Class Loss: 1.461305
# [11168/60000 (20%)]	Class Loss: 1.461161
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461246
# [15968/60000 (29%)]	Class Loss: 1.492410
# [17568/60000 (32%)]	Class Loss: 1.461153
# [19168/60000 (35%)]	Class Loss: 1.461175
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461374
# [25568/60000 (46%)]	Class Loss: 1.461356
# [27168/60000 (49%)]	Class Loss: 1.461184
# [28768/60000 (52%)]	Class Loss: 1.461165
# [30368/60000 (55%)]	Class Loss: 1.462063
# [31968/60000 (58%)]	Class Loss: 1.461274
# [33568/60000 (61%)]	Class Loss: 1.462931
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.492407
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461152
# [41568/60000 (76%)]	Class Loss: 1.461192
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461181
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461226
# [52768/60000 (96%)]	Class Loss: 1.462257
# [54368/60000 (99%)]	Class Loss: 1.461191
# Epoch : 18
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461190
# [4768/60000 (9%)]	Class Loss: 1.462202
# [6368/60000 (12%)]	Class Loss: 1.461779
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.492373
# [11168/60000 (20%)]	Class Loss: 1.461157
# [12768/60000 (23%)]	Class Loss: 1.461152
# [14368/60000 (26%)]	Class Loss: 1.461267
# [15968/60000 (29%)]	Class Loss: 1.461320
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.492401
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461188
# [23968/60000 (44%)]	Class Loss: 1.461200
# [25568/60000 (46%)]	Class Loss: 1.461205
# [27168/60000 (49%)]	Class Loss: 1.467108
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461153
# [31968/60000 (58%)]	Class Loss: 1.461456
# [33568/60000 (61%)]	Class Loss: 1.461303
# [35168/60000 (64%)]	Class Loss: 1.461155
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461456
# [39968/60000 (73%)]	Class Loss: 1.461154
# [41568/60000 (76%)]	Class Loss: 1.461155
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461173
# [46368/60000 (84%)]	Class Loss: 1.461169
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461153
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461276
# [54368/60000 (99%)]	Class Loss: 1.461196
# Epoch : 19
# [1568/60000 (3%)]	Class Loss: 1.461193
# [3168/60000 (6%)]	Class Loss: 1.462137
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.477313
# [9568/60000 (17%)]	Class Loss: 1.461176
# [11168/60000 (20%)]	Class Loss: 1.461152
# [12768/60000 (23%)]	Class Loss: 1.461358
# [14368/60000 (26%)]	Class Loss: 1.461175
# [15968/60000 (29%)]	Class Loss: 1.461163
# [17568/60000 (32%)]	Class Loss: 1.461441
# [19168/60000 (35%)]	Class Loss: 1.461480
# [20768/60000 (38%)]	Class Loss: 1.461162
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461194
# [25568/60000 (46%)]	Class Loss: 1.461934
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.487742
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461158
# [33568/60000 (61%)]	Class Loss: 1.461506
# [35168/60000 (64%)]	Class Loss: 1.461359
# [36768/60000 (67%)]	Class Loss: 1.461280
# [38368/60000 (70%)]	Class Loss: 1.464442
# [39968/60000 (73%)]	Class Loss: 1.461158
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461172
# [46368/60000 (84%)]	Class Loss: 1.461193
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461161
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461153
# [54368/60000 (99%)]	Class Loss: 1.462103
# Model test ...
# Test results on source_only :
#
# Source Accuracy: 9916/10000 (99.16%)
# Target Accuracy: 6264/10000 (62.64%)
#
# Epoch : 20
# [1568/60000 (3%)]	Class Loss: 1.461544
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461154
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461186
# [9568/60000 (17%)]	Class Loss: 1.461168
# [11168/60000 (20%)]	Class Loss: 1.461153
# [12768/60000 (23%)]	Class Loss: 1.461181
# [14368/60000 (26%)]	Class Loss: 1.461212
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461152
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461182
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461152
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461159
# [38368/60000 (70%)]	Class Loss: 1.461158
# [39968/60000 (73%)]	Class Loss: 1.461153
# [41568/60000 (76%)]	Class Loss: 1.461173
# [43168/60000 (78%)]	Class Loss: 1.461199
# [44768/60000 (81%)]	Class Loss: 1.461278
# [46368/60000 (84%)]	Class Loss: 1.461153
# [47968/60000 (87%)]	Class Loss: 1.461164
# [49568/60000 (90%)]	Class Loss: 1.462585
# [51168/60000 (93%)]	Class Loss: 1.461282
# [52768/60000 (96%)]	Class Loss: 1.461276
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 21
# [1568/60000 (3%)]	Class Loss: 1.523709
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461152
# [6368/60000 (12%)]	Class Loss: 1.461273
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461154
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461158
# [15968/60000 (29%)]	Class Loss: 1.461720
# [17568/60000 (32%)]	Class Loss: 1.461162
# [19168/60000 (35%)]	Class Loss: 1.461168
# [20768/60000 (38%)]	Class Loss: 1.461170
# [22368/60000 (41%)]	Class Loss: 1.461209
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461217
# [27168/60000 (49%)]	Class Loss: 1.461161
# [28768/60000 (52%)]	Class Loss: 1.492400
# [30368/60000 (55%)]	Class Loss: 1.461164
# [31968/60000 (58%)]	Class Loss: 1.461238
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461153
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461623
# [39968/60000 (73%)]	Class Loss: 1.461158
# [41568/60000 (76%)]	Class Loss: 1.461168
# [43168/60000 (78%)]	Class Loss: 1.461152
# [44768/60000 (81%)]	Class Loss: 1.492447
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461202
# [51168/60000 (93%)]	Class Loss: 1.461175
# [52768/60000 (96%)]	Class Loss: 1.461154
# [54368/60000 (99%)]	Class Loss: 1.461980
# Epoch : 22
# [1568/60000 (3%)]	Class Loss: 1.461152
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461200
# [9568/60000 (17%)]	Class Loss: 1.461161
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461219
# [14368/60000 (26%)]	Class Loss: 1.461215
# [15968/60000 (29%)]	Class Loss: 1.492409
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.461158
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461217
# [25568/60000 (46%)]	Class Loss: 1.461153
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.492402
# [30368/60000 (55%)]	Class Loss: 1.519507
# [31968/60000 (58%)]	Class Loss: 1.461153
# [33568/60000 (61%)]	Class Loss: 1.492401
# [35168/60000 (64%)]	Class Loss: 1.492510
# [36768/60000 (67%)]	Class Loss: 1.461245
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.492377
# [44768/60000 (81%)]	Class Loss: 1.461152
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.492398
# [49568/60000 (90%)]	Class Loss: 1.461244
# [51168/60000 (93%)]	Class Loss: 1.461344
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.492466
# Epoch : 23
# [1568/60000 (3%)]	Class Loss: 1.461301
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461158
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461683
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461223
# [19168/60000 (35%)]	Class Loss: 1.491264
# [20768/60000 (38%)]	Class Loss: 1.461153
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461162
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.461152
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461373
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461166
# [44768/60000 (81%)]	Class Loss: 1.492724
# [46368/60000 (84%)]	Class Loss: 1.461163
# [47968/60000 (87%)]	Class Loss: 1.461152
# [49568/60000 (90%)]	Class Loss: 1.461179
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461181
# Epoch : 24
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461205
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.492254
# [9568/60000 (17%)]	Class Loss: 1.461156
# [11168/60000 (20%)]	Class Loss: 1.461152
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461221
# [15968/60000 (29%)]	Class Loss: 1.461329
# [17568/60000 (32%)]	Class Loss: 1.492407
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461186
# [23968/60000 (44%)]	Class Loss: 1.461154
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.464314
# [33568/60000 (61%)]	Class Loss: 1.491168
# [35168/60000 (64%)]	Class Loss: 1.461571
# [36768/60000 (67%)]	Class Loss: 1.461155
# [38368/60000 (70%)]	Class Loss: 1.461152
# [39968/60000 (73%)]	Class Loss: 1.461152
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.492294
# [46368/60000 (84%)]	Class Loss: 1.461201
# [47968/60000 (87%)]	Class Loss: 1.461172
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461174
# [52768/60000 (96%)]	Class Loss: 1.461151
# [54368/60000 (99%)]	Class Loss: 1.461152
# Epoch : 25
# [1568/60000 (3%)]	Class Loss: 1.461244
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461152
# [6368/60000 (12%)]	Class Loss: 1.461156
# [7968/60000 (14%)]	Class Loss: 1.461324
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461153
# [14368/60000 (26%)]	Class Loss: 1.461154
# [15968/60000 (29%)]	Class Loss: 1.461152
# [17568/60000 (32%)]	Class Loss: 1.461368
# [19168/60000 (35%)]	Class Loss: 1.461170
# [20768/60000 (38%)]	Class Loss: 1.461153
# [22368/60000 (41%)]	Class Loss: 1.461156
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461167
# [28768/60000 (52%)]	Class Loss: 1.461154
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461269
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461189
# [36768/60000 (67%)]	Class Loss: 1.461173
# [38368/60000 (70%)]	Class Loss: 1.461307
# [39968/60000 (73%)]	Class Loss: 1.461154
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461165
# [46368/60000 (84%)]	Class Loss: 1.461200
# [47968/60000 (87%)]	Class Loss: 1.461152
# [49568/60000 (90%)]	Class Loss: 1.461164
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461178
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 26
# [1568/60000 (3%)]	Class Loss: 1.461170
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461215
# [7968/60000 (14%)]	Class Loss: 1.461152
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461152
# [14368/60000 (26%)]	Class Loss: 1.461157
# [15968/60000 (29%)]	Class Loss: 1.461154
# [17568/60000 (32%)]	Class Loss: 1.461188
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461153
# [22368/60000 (41%)]	Class Loss: 1.461152
# [23968/60000 (44%)]	Class Loss: 1.461152
# [25568/60000 (46%)]	Class Loss: 1.492267
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461161
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461156
# [33568/60000 (61%)]	Class Loss: 1.461168
# [35168/60000 (64%)]	Class Loss: 1.461178
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461311
# [39968/60000 (73%)]	Class Loss: 1.461222
# [41568/60000 (76%)]	Class Loss: 1.461155
# [43168/60000 (78%)]	Class Loss: 1.461151
# [44768/60000 (81%)]	Class Loss: 1.461168
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461160
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461282
# [52768/60000 (96%)]	Class Loss: 1.461309
# [54368/60000 (99%)]	Class Loss: 1.461177
# Epoch : 27
# [1568/60000 (3%)]	Class Loss: 1.461236
# [3168/60000 (6%)]	Class Loss: 1.461181
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461152
# [7968/60000 (14%)]	Class Loss: 1.461305
# [9568/60000 (17%)]	Class Loss: 1.461270
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461151
# [15968/60000 (29%)]	Class Loss: 1.461155
# [17568/60000 (32%)]	Class Loss: 1.461151
# [19168/60000 (35%)]	Class Loss: 1.492401
# [20768/60000 (38%)]	Class Loss: 1.492401
# [22368/60000 (41%)]	Class Loss: 1.461152
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461247
# [27168/60000 (49%)]	Class Loss: 1.461194
# [28768/60000 (52%)]	Class Loss: 1.461215
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461253
# [33568/60000 (61%)]	Class Loss: 1.461157
# [35168/60000 (64%)]	Class Loss: 1.461168
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461687
# [39968/60000 (73%)]	Class Loss: 1.491890
# [41568/60000 (76%)]	Class Loss: 1.461169
# [43168/60000 (78%)]	Class Loss: 1.461152
# [44768/60000 (81%)]	Class Loss: 1.461164
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461157
# [51168/60000 (93%)]	Class Loss: 1.461218
# [52768/60000 (96%)]	Class Loss: 1.461152
# [54368/60000 (99%)]	Class Loss: 1.493135
# Epoch : 28
# [1568/60000 (3%)]	Class Loss: 1.461258
# [3168/60000 (6%)]	Class Loss: 1.461178
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461154
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.490225
# [12768/60000 (23%)]	Class Loss: 1.461166
# [14368/60000 (26%)]	Class Loss: 1.461303
# [15968/60000 (29%)]	Class Loss: 1.461157
# [17568/60000 (32%)]	Class Loss: 1.461162
# [19168/60000 (35%)]	Class Loss: 1.461152
# [20768/60000 (38%)]	Class Loss: 1.461289
# [22368/60000 (41%)]	Class Loss: 1.461228
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461151
# [28768/60000 (52%)]	Class Loss: 1.461153
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461151
# [33568/60000 (61%)]	Class Loss: 1.492297
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461157
# [38368/60000 (70%)]	Class Loss: 1.461162
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.492533
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461156
# [47968/60000 (87%)]	Class Loss: 1.462259
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461152
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 29
# [1568/60000 (3%)]	Class Loss: 1.461205
# [3168/60000 (6%)]	Class Loss: 1.461153
# [4768/60000 (9%)]	Class Loss: 1.461152
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461152
# [9568/60000 (17%)]	Class Loss: 1.461154
# [11168/60000 (20%)]	Class Loss: 1.461216
# [12768/60000 (23%)]	Class Loss: 1.461152
# [14368/60000 (26%)]	Class Loss: 1.461156
# [15968/60000 (29%)]	Class Loss: 1.461796
# [17568/60000 (32%)]	Class Loss: 1.461441
# [19168/60000 (35%)]	Class Loss: 1.461152
# [20768/60000 (38%)]	Class Loss: 1.461153
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.492502
# [25568/60000 (46%)]	Class Loss: 1.461153
# [27168/60000 (49%)]	Class Loss: 1.461161
# [28768/60000 (52%)]	Class Loss: 1.461202
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461171
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461152
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461177
# [41568/60000 (76%)]	Class Loss: 1.492400
# [43168/60000 (78%)]	Class Loss: 1.461400
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.492401
# [47968/60000 (87%)]	Class Loss: 1.461192
# [49568/60000 (90%)]	Class Loss: 1.461152
# [51168/60000 (93%)]	Class Loss: 1.492631
# [52768/60000 (96%)]	Class Loss: 1.461155
# [54368/60000 (99%)]	Class Loss: 1.461152
# Model test ...
# Test results on source_only :
#
# Source Accuracy: 9917/10000 (99.17%)
# Target Accuracy: 6223/10000 (62.23%)
#
# Epoch : 30
# [1568/60000 (3%)]	Class Loss: 1.461151
# [3168/60000 (6%)]	Class Loss: 1.461151
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461266
# [7968/60000 (14%)]	Class Loss: 1.491496
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461194
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461165
# [15968/60000 (29%)]	Class Loss: 1.461158
# [17568/60000 (32%)]	Class Loss: 1.461164
# [19168/60000 (35%)]	Class Loss: 1.461153
# [20768/60000 (38%)]	Class Loss: 1.461163
# [22368/60000 (41%)]	Class Loss: 1.461252
# [23968/60000 (44%)]	Class Loss: 1.461220
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.492401
# [28768/60000 (52%)]	Class Loss: 1.461180
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461152
# [33568/60000 (61%)]	Class Loss: 1.484901
# [35168/60000 (64%)]	Class Loss: 1.492401
# [36768/60000 (67%)]	Class Loss: 1.461192
# [38368/60000 (70%)]	Class Loss: 1.461163
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.462076
# [43168/60000 (78%)]	Class Loss: 1.461175
# [44768/60000 (81%)]	Class Loss: 1.461423
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461203
# [52768/60000 (96%)]	Class Loss: 1.461161
# [54368/60000 (99%)]	Class Loss: 1.461151
# Epoch : 31
# [1568/60000 (3%)]	Class Loss: 1.461152
# [3168/60000 (6%)]	Class Loss: 1.461199
# [4768/60000 (9%)]	Class Loss: 1.461181
# [6368/60000 (12%)]	Class Loss: 1.461151
# [7968/60000 (14%)]	Class Loss: 1.461772
# [9568/60000 (17%)]	Class Loss: 1.461152
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461151
# [14368/60000 (26%)]	Class Loss: 1.461173
# [15968/60000 (29%)]	Class Loss: 1.461151
# [17568/60000 (32%)]	Class Loss: 1.461153
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.492401
# [22368/60000 (41%)]	Class Loss: 1.461161
# [23968/60000 (44%)]	Class Loss: 1.461217
# [25568/60000 (46%)]	Class Loss: 1.461210
# [27168/60000 (49%)]	Class Loss: 1.492408
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461157
# [33568/60000 (61%)]	Class Loss: 1.463431
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.463617
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.462039
# [44768/60000 (81%)]	Class Loss: 1.461151
# [46368/60000 (84%)]	Class Loss: 1.461152
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461151
# [51168/60000 (93%)]	Class Loss: 1.461151
# [52768/60000 (96%)]	Class Loss: 1.461152
# [54368/60000 (99%)]	Class Loss: 1.461155
# Epoch : 32
# [1568/60000 (3%)]	Class Loss: 1.461167
# [3168/60000 (6%)]	Class Loss: 1.461159
# [4768/60000 (9%)]	Class Loss: 1.461151
# [6368/60000 (12%)]	Class Loss: 1.461181
# [7968/60000 (14%)]	Class Loss: 1.492422
# [9568/60000 (17%)]	Class Loss: 1.461151
# [11168/60000 (20%)]	Class Loss: 1.461151
# [12768/60000 (23%)]	Class Loss: 1.461156
# [14368/60000 (26%)]	Class Loss: 1.461384
# [15968/60000 (29%)]	Class Loss: 1.461159
# [17568/60000 (32%)]	Class Loss: 1.461221
# [19168/60000 (35%)]	Class Loss: 1.461165
# [20768/60000 (38%)]	Class Loss: 1.461151
# [22368/60000 (41%)]	Class Loss: 1.461151
# [23968/60000 (44%)]	Class Loss: 1.461151
# [25568/60000 (46%)]	Class Loss: 1.461151
# [27168/60000 (49%)]	Class Loss: 1.461164
# [28768/60000 (52%)]	Class Loss: 1.461151
# [30368/60000 (55%)]	Class Loss: 1.461151
# [31968/60000 (58%)]	Class Loss: 1.461204
# [33568/60000 (61%)]	Class Loss: 1.461151
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461151
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461235
# [41568/60000 (76%)]	Class Loss: 1.461312
# [43168/60000 (78%)]	Class Loss: 1.492396
# [44768/60000 (81%)]	Class Loss: 1.461152
# [46368/60000 (84%)]	Class Loss: 1.461177
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461220
# [51168/60000 (93%)]	Class Loss: 1.461220
# [52768/60000 (96%)]	Class Loss: 1.461631
# [54368/60000 (99%)]	Class Loss: 1.461330
# Epoch : 33
# [1568/60000 (3%)]	Class Loss: 1.461245
# [3168/60000 (6%)]	Class Loss: 1.461187
# [4768/60000 (9%)]	Class Loss: 1.461152
# [6368/60000 (12%)]	Class Loss: 1.492495
# [7968/60000 (14%)]	Class Loss: 1.461151
# [9568/60000 (17%)]	Class Loss: 1.461161
# [11168/60000 (20%)]	Class Loss: 1.461167
# [12768/60000 (23%)]	Class Loss: 1.461180
# [14368/60000 (26%)]	Class Loss: 1.461152
# [15968/60000 (29%)]	Class Loss: 1.461190
# [17568/60000 (32%)]	Class Loss: 1.461172
# [19168/60000 (35%)]	Class Loss: 1.461151
# [20768/60000 (38%)]	Class Loss: 1.461391
# [22368/60000 (41%)]	Class Loss: 1.461163
# [23968/60000 (44%)]	Class Loss: 1.461177
# [25568/60000 (46%)]	Class Loss: 1.461191
# [27168/60000 (49%)]	Class Loss: 1.461157
# [28768/60000 (52%)]	Class Loss: 1.461153
# [30368/60000 (55%)]	Class Loss: 1.461152
# [31968/60000 (58%)]	Class Loss: 1.461157
# [33568/60000 (61%)]	Class Loss: 1.461176
# [35168/60000 (64%)]	Class Loss: 1.461151
# [36768/60000 (67%)]	Class Loss: 1.461161
# [38368/60000 (70%)]	Class Loss: 1.461151
# [39968/60000 (73%)]	Class Loss: 1.461151
# [41568/60000 (76%)]	Class Loss: 1.461151
# [43168/60000 (78%)]	Class Loss: 1.461160
# [44768/60000 (81%)]	Class Loss: 1.461209
# [46368/60000 (84%)]	Class Loss: 1.461151
# [47968/60000 (87%)]	Class Loss: 1.461151
# [49568/60000 (90%)]	Class Loss: 1.461152
# [51168/60000 (93%)]	Class Loss: 1.461151
# ...
# [15968/60000 (29%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274414	Class Loss: 1.461152	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274415	Class Loss: 1.461151	Domain Loss: 0.813264
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274414	Class Loss: 1.461152	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.305664	Class Loss: 1.492401	Domain Loss: 0.813263
# [52768/60000 (96%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274424	Class Loss: 1.461162	Domain Loss: 0.813262
# Epoch : 95
# [1568/60000 (3%)]	Loss: 2.274414	Class Loss: 1.461151	Domain Loss: 0.813263
# [3168/60000 (6%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [4768/60000 (9%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813263
# [11168/60000 (20%)]	Loss: 2.305580	Class Loss: 1.492318	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274415	Class Loss: 1.461151	Domain Loss: 0.813265
# [15968/60000 (29%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.305663	Class Loss: 1.492401	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813261
# [22368/60000 (41%)]	Loss: 2.274502	Class Loss: 1.461240	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274415	Class Loss: 1.461151	Domain Loss: 0.813264
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813263
# [41568/60000 (76%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# Epoch : 96
# [1568/60000 (3%)]	Loss: 2.274414	Class Loss: 1.461153	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [4768/60000 (9%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274433	Class Loss: 1.461171	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274429	Class Loss: 1.461167	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.304333	Class Loss: 1.491071	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.305664	Class Loss: 1.492401	Domain Loss: 0.813263
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274416	Class Loss: 1.461155	Domain Loss: 0.813262
# Epoch : 97
# [1568/60000 (3%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.305663	Class Loss: 1.492401	Domain Loss: 0.813262
# [4768/60000 (9%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274426	Class Loss: 1.461165	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274414	Class Loss: 1.461151	Domain Loss: 0.813263
# [19168/60000 (35%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274443	Class Loss: 1.461151	Domain Loss: 0.813293
# [27168/60000 (49%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# Epoch : 98
# [1568/60000 (3%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.274414	Class Loss: 1.461151	Domain Loss: 0.813263
# [4768/60000 (9%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [6368/60000 (12%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274417	Class Loss: 1.461151	Domain Loss: 0.813266
# [23968/60000 (44%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.305663	Class Loss: 1.492401	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274417	Class Loss: 1.461155	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [41568/60000 (76%)]	Loss: 2.305662	Class Loss: 1.492401	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274437	Class Loss: 1.461151	Domain Loss: 0.813287
# [46368/60000 (84%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274415	Class Loss: 1.461153	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [51168/60000 (93%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# Epoch : 99
# [1568/60000 (3%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [3168/60000 (6%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [4768/60000 (9%)]	Loss: 2.274421	Class Loss: 1.461151	Domain Loss: 0.813270
# [6368/60000 (12%)]	Loss: 2.274433	Class Loss: 1.461172	Domain Loss: 0.813262
# [7968/60000 (14%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [9568/60000 (17%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [11168/60000 (20%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [12768/60000 (23%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [14368/60000 (26%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [15968/60000 (29%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [17568/60000 (32%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [19168/60000 (35%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [20768/60000 (38%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [22368/60000 (41%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [23968/60000 (44%)]	Loss: 2.274414	Class Loss: 1.461151	Domain Loss: 0.813263
# [25568/60000 (46%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [27168/60000 (49%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [28768/60000 (52%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [30368/60000 (55%)]	Loss: 2.274419	Class Loss: 1.461158	Domain Loss: 0.813262
# [31968/60000 (58%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [33568/60000 (61%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [35168/60000 (64%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [36768/60000 (67%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [38368/60000 (70%)]	Loss: 2.274415	Class Loss: 1.461153	Domain Loss: 0.813262
# [39968/60000 (73%)]	Loss: 2.274415	Class Loss: 1.461151	Domain Loss: 0.813264
# [41568/60000 (76%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [43168/60000 (78%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [44768/60000 (81%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [46368/60000 (84%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [47968/60000 (87%)]	Loss: 2.274413	Class Loss: 1.461151	Domain Loss: 0.813262
# [49568/60000 (90%)]	Loss: 2.274427	Class Loss: 1.461164	Domain Loss: 0.813263
# [51168/60000 (93%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [52768/60000 (96%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# [54368/60000 (99%)]	Loss: 2.274412	Class Loss: 1.461151	Domain Loss: 0.813262
# Model test ...
# Test Results on DANN :
#
# Source Accuracy: 9920/10000 (99.20%)
# Target Accuracy: 7922/10000 (79.22%)
# Domain Accuracy: 10000/20000 (50.00%)
#
# Save models ...
# Model is saved !!!
# Extract features to draw T-SNE plot...
# c:\Users\jaido\source\Pytorch_DABP\venv\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# c:\Users\jaido\source\Pytorch_DABP\venv\lib\site-packages\sklearn\manifold\_t_sne.py:996: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# Draw plot ...
# saved_plot/source_dann_2_source.png is saved

# %%
import importlib
importlib.reload(main)
import main

print(main.save_name)

main.main()
# Out:
# second_run
# Running GPU : 0
# Source-only training
# Epoch : 0
# c:\Users\jaido\source\Pytorch_DABP\model.py:38: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.softmax(x)
# [1568/60000 (3%)]	Class Loss: 2.300274
# [3168/60000 (6%)]	Class Loss: 2.301381
# [4768/60000 (9%)]	Class Loss: 2.298617
# [6368/60000 (12%)]	Class Loss: 2.299810
# [7968/60000 (14%)]	Class Loss: 2.295869
# [9568/60000 (17%)]	Class Loss: 2.294895
# [11168/60000 (20%)]	Class Loss: 2.274042
# [12768/60000 (23%)]	Class Loss: 1.931784
# [14368/60000 (26%)]	Class Loss: 1.806814
# [15968/60000 (29%)]	Class Loss: 1.906571
# [17568/60000 (32%)]	Class Loss: 1.684386
# [19168/60000 (35%)]	Class Loss: 1.746913
# [20768/60000 (38%)]	Class Loss: 1.812075
# [22368/60000 (41%)]	Class Loss: 1.627578
# [23968/60000 (44%)]	Class Loss: 1.706225
# [25568/60000 (46%)]	Class Loss: 1.710197
# [27168/60000 (49%)]	Class Loss: 1.655882
# [28768/60000 (52%)]	Class Loss: 1.715252
# [30368/60000 (55%)]	Class Loss: 1.679133
# [31968/60000 (58%)]	Class Loss: 1.607212
# [33568/60000 (61%)]	Class Loss: 1.801950
# [35168/60000 (64%)]	Class Loss: 1.650323
# [36768/60000 (67%)]	Class Loss: 1.716855
# [38368/60000 (70%)]	Class Loss: 1.705725
# [39968/60000 (73%)]	Class Loss: 1.700510
# [41568/60000 (76%)]	Class Loss: 1.623946
# [43168/60000 (78%)]	Class Loss: 1.708455
# [44768/60000 (81%)]	Class Loss: 1.715663
# [46368/60000 (84%)]	Class Loss: 1.620865
# [47968/60000 (87%)]	Class Loss: 1.617717
# [49568/60000 (90%)]	Class Loss: 1.626410
# [51168/60000 (93%)]	Class Loss: 1.670369
# [52768/60000 (96%)]	Class Loss: 1.659617
# [54368/60000 (99%)]	Class Loss: 1.644992
# Epoch : 1
# [1568/60000 (3%)]	Class Loss: 1.681715
# [3168/60000 (6%)]	Class Loss: 1.830084
# [4768/60000 (9%)]	Class Loss: 1.680373
# [6368/60000 (12%)]	Class Loss: 1.796556
# [7968/60000 (14%)]	Class Loss: 1.556820
# [9568/60000 (17%)]	Class Loss: 1.607316
# [11168/60000 (20%)]	Class Loss: 1.584464
# [12768/60000 (23%)]	Class Loss: 1.621765
# [14368/60000 (26%)]	Class Loss: 1.766019
# [15968/60000 (29%)]	Class Loss: 1.611062
# [17568/60000 (32%)]	Class Loss: 1.621123
# [19168/60000 (35%)]	Class Loss: 1.651886
# [20768/60000 (38%)]	Class Loss: 1.587154
# [22368/60000 (41%)]	Class Loss: 1.555616
# [23968/60000 (44%)]	Class Loss: 1.648801
# [25568/60000 (46%)]	Class Loss: 1.477174
# [27168/60000 (49%)]	Class Loss: 1.677072
# [28768/60000 (52%)]	Class Loss: 1.616436
# [30368/60000 (55%)]	Class Loss: 1.652440
# [31968/60000 (58%)]	Class Loss: 1.555387
# [33568/60000 (61%)]	Class Loss: 1.539168
# [35168/60000 (64%)]	Class Loss: 1.579759
# [36768/60000 (67%)]	Class Loss: 1.573463
# [38368/60000 (70%)]	Class Loss: 1.479920
# [39968/60000 (73%)]	Class Loss: 1.476844
# [41568/60000 (76%)]	Class Loss: 1.492913
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 7
#       3 import main
#       5 print(main.save_name)
# ----> 7 main.main()
#
# File c:\Users\jaido\source\Pytorch_DABP\main.py:22, in main()
#      19     classifier = model.Classifier().cuda()
#      20     discriminator = model.Discriminator().cuda()
# ---> 22     train.source_only(encoder, classifier, source_train_loader, target_train_loader, "source_only_2")
#      23     train.dann(encoder, classifier, discriminator, source_train_loader, target_train_loader, "dann_2")
#      25 else:
#
# File c:\Users\jaido\source\Pytorch_DABP\train.py:50, in source_only(encoder, classifier, source_train_loader, target_train_loader, save_name)
#      47 class_pred = classifier(source_feature)
#      48 class_loss = classifier_criterion(class_pred, source_label)
# ---> 50 class_loss.backward()
#      51 optimizer.step()
#      52 if (batch_idx + 1) % 50 == 0:
#
# File c:\Users\jaido\source\Pytorch_DABP\venv\lib\site-packages\torch\_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File c:\Users\jaido\source\Pytorch_DABP\venv\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# * Q1: Perform **3** experiments on training and report your source and target accuracy in the tables below. (Your result is the average of the Target Accs. based on 3 experiments)
#
# **Source Only**
#
# |                | Test1 | Test2 | Test3 |
# |----------------|:-----:|:-----:|:-----:|
# | Source Acc (%) |    |       |       |
# | Target Acc (%) |    |       |      |
#
# |          | Paper | Your Result |
# |----------|:-----:|:-----------:|
# | DABP (%) | 52.25 |          |
#
# **DANN**
#
# |                | Test1 | Test2 | Test3 |
# |----------------|:-----:|:-----:|:-----:|
# | Source Acc (%) |    |       |        |
# | Target Acc (%) |   |       |       |
#
# |          | Paper | Your Result |
# |----------|:-----:|:-----------:|
# | DABP (%) | 76.66 |          |

# %% [markdown]
# * Q2: Write your own codes to visualize the feature space by using the TSNE(perplexity=30, n_components=2, init=’pca’, n_iter=3000). Plot the feature distributions for both (1) original MNIST and MNIST-M inputs and (2) after DABP using source only (3) after DABP using dann.(**You will find useful functions inside the `utils`function.** )

# %% [markdown]
# (1) Original MNIST and MNIST-M inputs

# %%
import utils

# %% [markdown]
# (2) After DABP using source only

# %%
# todo

# %% [markdown]
#  (3) After DABP using dann

# %%
# todo

# %% [markdown]
# ## Discussions

# %% [markdown]
# (1) From the results in Q2, are the both domains closer/farther after performing the transformation? If the answer is closer, it verifies that DABP can learn discriminative and domain invariant features. If not, explain your reasons.

# %% [markdown]
# (2) List one of the main problems for the DABP method and explain why?

# %% [markdown]
# # Problem 3: GAN
# In this problem, we will train a generative adversarial network (GAN) to generate new celebrities after showing it pictures of many real celebrities.

# %%
# %matplotlib inline

# %%
from __future__ import print_function

import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Set random seed for reproducibility
manualSeed = 999
# manualSeed = random.randint(1, 10000)  # use if you want new results
print("Random Seed: ", manualSeed)
random.seed(manualSeed)
torch.manual_seed(manualSeed)

# %% [markdown]
# ### (a) Prepare CelebA Dataset
#
# we will use the [Celeb-A Faces
# dataset](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) which can
# be downloaded from the [link](https://drive.google.com/file/d/1JgNzlZKQVlVwmlVx-5y6m4Dftbia51YB/view?usp=sharing).
# The dataset will download as a file named `img_align_celeba.zip`. Once
# downloaded, create a directory named `CelebA` and extract the zip file
# into that directory. Then, set the `dataroot` input for this notebook to
# the `CelebA` directory you just created. The resulting directory
# structure should be:
#
# ```
#    /path/to/CelebA
#        -> img_align_celeba
#            -> 188242.jpg
#            -> 173822.jpg
#            -> 284702.jpg
#            -> 537394.jpg
#               ...
# ```
#
# This is an important step because we will be using the ImageFolder
# dataset class, which requires there to be subdirectories in the
# dataset’s root folder.

# %% [markdown]
# Here, we upload the data `img_align_celeba.zip` to your Google Drive and mount it to this notebook. Unzip the data as the directory structure introduced above.

# %%
# !mkdir ./CelebA
# !unzip /content/gdrive/MyDrive/img_align_celeba.zip -d ./CelebA

# %% [markdown]
# Set parameters for the implemented network.

# %%
# Root directory for dataset
dataroot = "./CelebA"

# Number of workers for dataloader
workers = 2

# Batch size during training
batch_size = 128

# Spatial size of training images. All images will be resized to this
#   size using a transformer.
image_size = 64

# Number of channels in the training images. For color images this is 3
nc = 3

# Size of z latent vector (i.e. size of generator input)
nz = 100

# Learning rate for optimizers
lr = 0.0002

# Beta1 hyperparam for Adam optimizers
beta1 = 0.5

# %% [markdown]
# Now, we can create the dataset, create the
# dataloader, set the device to run on, and finally visualize some of the
# training data.

# %%
# We can use an image folder dataset the way we have it setup.
# Create the dataset
dataset = dset.ImageFolder(root=dataroot,
                           transform=transforms.Compose([
                               transforms.Resize(image_size),
                               transforms.CenterCrop(image_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))
# Create the dataloader
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True, num_workers=workers)

# Decide which device we want to run on
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Plot some training images
real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# ### (b) GAN Implementation
#
# <h4>Weight Initialization</h4>
#
# All model weights in GAN should be randomly initialized from a Normal distribution with `mean = 0`, `stdev = 0.02`. The ``weights_init`` function takes an initialized model as input and reinitializes all convolutional, convolutional-transpose, and batch normalization layers to meet this criteria. This function is applied to the models immediately after initialization.

# %%
# custom weights initialization called on netG and netD
def weights_init(m):
  classname = m.__class__.__name__
  if classname.find('Conv') != -1:
    nn.init.normal_(m.weight.data, 0.0, 0.02)
  elif classname.find('BatchNorm') != -1:
    nn.init.normal_(m.weight.data, 1.0, 0.02)
    nn.init.constant_(m.bias.data, 0)

# %% [markdown]
# <h4>Generator</h4>
#
# The generator $G$, is designed to map the latent space vector
# $z$ to data-space. Since our data are images, converting
# $z$ to data-space means ultimately creating an RGB image with the
# same size as the training images (i.e. 3x64x64). In practice, this is
# accomplished through a series of strided two dimensional convolutional
# transpose layers, each paired with a 2D batch norm layer and a relu
# activation. The output of the generator is fed through a tanh function
# to return it to the input data range of $[-1,1]$.

# %% [markdown]
# ```
# Generator(
#   (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU()
#   (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU()
#   (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): ReLU()
#   (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU()
#   (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (13): Tanh()
# )
# ```

# %%
class Generator(nn.Module):
  def __init__(self):
    super(Generator, self).__init__()
    # todo: implement network architecture
    
  def forward(self, input):
    # todo: implement network architecture
    return x

# %% [markdown]
# Now, we can instantiate the generator and apply the ``weights_init``
# function.

# %%
# Create the generator
netG = Generator().to(device)

# Apply the weights_init function to randomly initialize all weights
#  to mean=0, stdev=0.2.
netG.apply(weights_init)

# Print the model
print(netG)

# %% [markdown]
# <h4>Discriminator</h4>
#
# The discriminator $D$ is a binary classification
# network that takes an image as input and outputs a scalar probability
# that the input image is real (as opposed to fake). Here, $D$ takes
# a 3x64x64 input image, processes it through a series of Conv2d,
# BatchNorm2d, and ReLU layers, and outputs the final probability
# through a Sigmoid activation function. This architecture can be extended
# with more layers if necessary for the problem, but there is significance
# to the use of the strided convolution, BatchNorm, and ReLUs.

# %% [markdown]
# ```
# Discriminator(
#   (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): ReLU()
#   (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (4): ReLU()
#   (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): ReLU()
#   (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (10): ReLU()
#   (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (12): Sigmoid()
# )
# ```

# %%
class Discriminator(nn.Module):
  def __init__(self):
    super(Discriminator, self).__init__()
    # TODO: implement network architecture


  def forward(self, input):
    # TODO: implement network architecture
    return x

# %% [markdown]
# Now, as with the generator, we can create the discriminator, apply the
# ``weights_init`` function, and print the model’s structure.

# %%
# Create the Discriminator
netD = Discriminator().to(device)
    
# Apply the weights_init function to randomly initialize all weights
#  to mean=0, stdev=0.2.
netD.apply(weights_init)

# Print the model
print(netD)

# %% [markdown]
# <h4>Loss Functions and Optimizers</h4>
#
# With $D$ and $G$ setup, we can specify how they learn
# through the loss functions and optimizers. We will use the Binary Cross
# Entropy loss
# ([`BCELoss`](https://pytorch.org/docs/stable/nn.html#torch.nn.BCELoss))
# function which is defined in PyTorch as:
#
# \begin{align}\ell(x, y) = L = \{l_1,\dots,l_N\}^\top, \quad l_n = - \left[ y_n \cdot \log x_n + (1 - y_n) \cdot \log (1 - x_n) \right]\end{align}
#
# Notice how this function provides the calculation of both log components
# in the objective function (i.e. $\log(D(x))$ and
# $\log(1-D(G(z)))$). We can specify what part of the BCE equation to
# use with the $y$ input. This is accomplished in the training loop
# which is coming up soon, but it is important to understand how we can
# choose which component we wish to calculate just by changing $y$
# (i.e. GT labels).
#
# Next, we define our real label as 1 and the fake label as 0. These
# labels will be used when calculating the losses of $D$ and
# $G$, and this is also the convention used in the original GAN
# paper. Finally, we set up two separate optimizers, one for $D$ and
# one for $G$. In the training loop, we will periodically input
# this fixed_noise into $G$, and over the iterations we will see
# images form out of the noise.

# %%
# Initialize BCELoss function
criterion = nn.BCELoss()

# Create batch of latent vectors that we will use to visualize
#  the progression of the generator
fixed_noise = torch.randn(64, nz, 1, 1, device=device)

# Establish convention for real and fake labels during training
real_label = 1.
fake_label = 0.

# Setup Adam optimizers for both G and D
optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))

# %%
# Training Loop

num_epochs = 100
# Lists to keep track of progress
img_list = []
G_losses = []
D_losses = []
iters = 0

print("Starting Training Loop...")
# For each epoch
for epoch in range(num_epochs):
    # For each batch in the dataloader
    for i, data in enumerate(dataloader, 0):
        
        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        ## Train with all-real batch
        netD.zero_grad()
        # Format batch
        real_cpu = data[0].to(device) # what does cpu mean?
        b_size = real_cpu.size(0)
        label = torch.full((b_size,), real_label, dtype=torch.float, device=device)
        # Forward pass real batch through D
        output = netD(real_cpu).view(-1)
        # Calculate loss on all-real batch
        errD_real = criterion(output, label)
        # Calculate gradients for D in backward pass
        errD_real.backward()
        D_x = output.mean().item()

        ## Train with all-fake batch
        # Generate batch of latent vectors
        noise = torch.randn(b_size, nz, 1, 1, device=device)
        # Generate fake image batch with G
        fake = netG(noise)
        label.fill_(fake_label)
        # Classify all fake batch with D
        output = netD(fake.detach()).view(-1)
        # Calculate D's loss on the all-fake batch
        errD_fake = criterion(output, label)
        # Calculate the gradients for this batch
        errD_fake.backward()
        D_G_z1 = output.mean().item()
        # Add the gradients from the all-real and all-fake batches
        errD = errD_real + errD_fake
        # Update D
        optimizerD.step()

        ############################
        # (2) Update G network: maximize log(D(G(z)))
        ###########################
        netG.zero_grad()
        label.fill_(real_label)  # fake labels are real for generator cost
        # Since we just updated D, perform another forward pass of all-fake batch through D
        output = netD(fake).view(-1)
        # Calculate G's loss based on this output
        errG = criterion(output, label)
        # Calculate gradients for G
        errG.backward()
        D_G_z2 = output.mean().item()
        # Update G
        optimizerG.step()
        
        # Output training stats
        if i % 50 == 0:
            print('[%d/%d][%d/%d]\tLoss_D: %.4f\tLoss_G: %.4f\tD(x): %.4f\tD(G(z)): %.4f / %.4f'
                  % (epoch, num_epochs, i, len(dataloader),
                     errD.item(), errG.item(), D_x, D_G_z1, D_G_z2))
        
        # Save Losses for plotting later
        G_losses.append(errG.item())
        D_losses.append(errD.item())
        
        # Check how the generator is doing by saving G's output on fixed_noise
        if (iters % 500 == 0) or ((epoch == num_epochs-1) and (i == len(dataloader)-1)):
            with torch.no_grad():
                fake = netG(fixed_noise).detach().cpu()
            img_list.append(vutils.make_grid(fake, padding=2, normalize=True))
            
        iters += 1

# %% [markdown]
# <h4>Training</h4>
#
# Finally, now that we have all of the parts of the GAN framework defined,
# we can train it. Be mindful that training GANs is somewhat of an art
# form, as incorrect hyperparameter settings lead to mode collapse with
# little explanation of what went wrong. Here, we will closely follow
# Algorithm 1 from Goodfellow’s paper, while abiding by some of the best
# practices shown in [`ganhacks`](https://github.com/soumith/ganhacks).
# Namely, we will construct different mini-batches for real and fake
# images, and also adjust G’s objective function to maximize
# $\log (D(G(z)))$. Training is split up into two main parts. Part 1
# updates the Discriminator and Part 2 updates the Generator.
#
# **Part 1: Train the Discriminator**
#
# Recall, the goal of training the discriminator is to maximize the
# probability of correctly classifying a given input as real or fake. In
# terms of Goodfellow, we wish to “update the discriminator by ascending
# its stochastic gradient”. Practically, we want to maximize
# $\log(D(x)) + \log(1-D(G(z)))$. Due to the separate mini-batch
# suggestion from ganhacks, we will calculate this in two steps. First, we
# will construct a batch of real samples from the training set, forward
# pass through $D$, calculate the loss ($\log(D(x))$), then
# calculate the gradients in a backward pass. Secondly, we will construct
# a batch of fake samples with the current generator, forward pass this
# batch through $D$, calculate the loss ($\log(1-D(G(z)))$),
# and *accumulate* the gradients with a backward pass. Now, with the
# gradients accumulated from both the all-real and all-fake batches, we
# call a step of the Discriminator’s optimizer.
#
# **Part 2: Train the Generator**
#
# As stated in the original paper, we want to train the Generator by
# minimizing $\log(1-D(G(z)))$ in an effort to generate better fakes.
# As mentioned, this was shown by Goodfellow to not provide sufficient
# gradients, especially early in the learning process. As a fix, we
# instead wish to maximize $\log(D(G(z)))$. In the code we accomplish
# this by: classifying the Generator output from Part 1 with the
# Discriminator, computing G’s loss *using real labels as GT*, computing
# G’s gradients in a backward pass, and finally updating G’s parameters
# with an optimizer step. It may seem counter-intuitive to use the real
# labels as GT labels for the loss function, but this allows us to use the
# $\log(x)$ part of the BCELoss (rather than the $\log(1-x)$
# part) which is exactly what we want.
#
# Finally, we will do some statistic reporting and at the end of each
# epoch we will push our fixed_noise batch through the generator to
# visually track the progress of G’s training. The training statistics
# reported are:
#
# -  **Loss_D** - discriminator loss calculated as the sum of losses for
#    the all real and all fake batches ($\log(D(x)) + \log(D(G(z)))$).
# -  **Loss_G** - generator loss calculated as $\log(D(G(z)))$
# -  **D(x)** - the average output (across the batch) of the discriminator
#    for the all real batch. This should start close to 1 then
#    theoretically converge to 0.5 when G gets better. Think about why
#    this is.
# -  **D(G(z))** - average discriminator outputs for the all fake batch.
#    The first number is before D is updated and the second number is
#    after D is updated. These numbers should start near 0 and converge to
#    0.5 as G gets better. Think about why this is.
#
# **Note:** This step might take a while, depending on how many epochs you
# run and if you removed some data from the dataset.

# %% [markdown]
# <h4>Visualization</h4>
#
# Finally, lets check out how we did. Here, we will look at three
# different results. First, we will see how D and G’s losses changed
# during training. Second, we will visualize G’s output on the fixed_noise
# batch for every epoch. And third, we will look at a batch of real data
# next to a batch of fake data from G.
#
# **Loss versus training iteration**
#
# Below is a plot of D & G’s losses versus training iterations.

# %%
plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(G_losses,label="G")
plt.plot(D_losses,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# **Visualization of G’s progression**
#
# Remember how we saved the generator’s output on the fixed_noise batch
# after every epoch of training. Now, we can visualize the training
# progression of G with an animation. Press the play button to start the
# animation.

# %%
fig = plt.figure(figsize=(8,8))
plt.axis("off")
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in img_list]
ani = animation.ArtistAnimation(fig, ims, interval=1000, repeat_delay=1000, blit=True)

HTML(ani.to_jshtml())

# %% [markdown]
# **Real Images vs. Fake Images**
#
# Finally, lets take a look at some real images and fake images side by
# side.

# %%
# Grab a batch of real images from the dataloader
real_batch = next(iter(dataloader))

# Plot the real images
plt.figure(figsize=(15,15))
plt.subplot(1,2,1)
plt.axis("off")
plt.title("Real Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=5, normalize=True).cpu(),(1,2,0)))

# Plot the fake images from the last epoch
plt.subplot(1,2,2)
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img_list[-1],(1,2,0)))
plt.show()

# %% [markdown]
# ### Change the image size to 128x128.
#
# Note: Do not overwrite the code for 64x64. Please copy the previous code and do the resizing below.

# %%
# todo

# %% [markdown]
# ### (c) Discussions

# %% [markdown]
# (1) Why does the training strategy for GAN need to be carefully designed?
#
#
#
# (2) Besides generating fake images from the noise, what other applications can you come up with for GAN?
